# %%
# imports
import os
import time
import csv
import multiprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms

# %%
# @title Set random seed

# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# for DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.
import random
import torch

def set_seed(seed=None, seed_torch=True):
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')

# In case that `DataLoader` is used
def seed_worker(worker_id):
  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

# %%
# @title Set device (GPU or CPU)

# inform the user if the notebook uses GPU or CPU.

def set_device():
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

# %%
set_seed(seed=2021)
set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.
# 'cuda'

# %%
# hyper-parameters
use_cuda = torch.cuda.is_available()
alpha = 1  # alpha for mixup augmentation
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
batch_size = 128
end_apochs = 200  # Please change this to 200
base_learning_rate = 0.01
cutout = True  # True/False if you want to use cutout augmentation
mixup = False  # True/False if you want to use mixup augmentation
n_holes = 1  # number of holes to cut out from image for cutout
length = 2  # length of the holes for cutout augmentation
torchvision_transforms = False  # True/False if you want use torchvision augmentations

# %%
class Cutout(object):
    """
    code from: https://github.com/uoguelph-mlrg/Cutout
    
    Randomly mask out one or more patches from an image.
    Args:
      n_holes (int): Number of patches to cut out of each image.
      length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length
    
    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)
        
        mask = np.ones((h, w), np.float32)
    
        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)
            
            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)
            
            mask[y1: y2, x1: x2] = 0.
        
        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask
    
        return img

# %%
# @markdown `mixup_data` Augmentation function

def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Compute the mixup data. Return mixed inputs, pairs of targets, and lambda
      - https://github.com/hongyi-zhang/mixup
    '''
    if alpha > 0.:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.
    batch_size = x.size()[0]
    
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)
    
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    
    return mixed_x, y_a, y_b, lam

# %%
# @markdown Download and prepare Data
print('==> Preparing data...')
def percentageSplit(full_dataset, percent=0.0):
    set1_size = int(percent * len(full_dataset))
    set2_size = len(full_dataset) - set1_size
    final_dataset, _ = torch.utils.data.random_split(full_dataset, [set1_size, set2_size])
    return final_dataset

# CIFAR100 normalizing
# mean = [0.5071, 0.4866, 0.4409]
# std = [0.2673, 0.2564, 0.2762]

# CIFAR10 normalizing
mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)

# torchvision transforms
transform_train = transforms.Compose([])
if torchvision_transforms:
    transform_train.transforms.append(transforms.RandomCrop(32, padding=4))
    transform_train.transforms.append(transforms.RandomHorizontalFlip())

transform_train.transforms.append(transforms.ToTensor())
transform_train.transforms.append(transforms.Normalize(mean, std))

if cutout:
    transform_train.transforms.append(Cutout(n_holes=n_holes, length=length))

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True,
    transform=transform_train)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True,
    transform=transform_test)
# Out:
# ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Object type: {type(trainset)}")
print(f"Training data shape: {trainset.data.shape}")
print(f"Test data shape: {testset.data.shape}")
print(f"Number of classes: {np.unique(trainset.targets).shape[0]}")
# Out:
# Object type: <class 'torchvision.datasets.cifar.CIFAR10'>
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)
# Number of classes: 10

# %%
# choose percentage from the trainset. set percent = 1.0 to use the whole train data
percent = 1.0
trainset = percentageSplit(trainset, percent = percent)
print(f"size of the new trainset: {len(trainset)}")
# Out:
# size of the new trainset: 50000

# %%
# Dataloader
num_workers = multiprocessing.cpu_count()

print(f'----> number of workers: {num_workers}')

trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ----> number of workers: 96

# %%
# get batch of data
batch_X, batch_Y =  next(iter(trainloader))

# %%
def plot_mixed_images(images):
    inv_normalize = transforms.Normalize(
                      mean= [-m/s for m, s in zip(mean, std)],
                      std= [1/s for s in std]
                    )
    inv_PIL = transforms.ToPILImage()
    fig = plt.figure(figsize=(10, 8))
    
    for i in range(1, len(images) + 1):
        image = images[i-1]
        ax = fig.add_subplot(1, 4, i)
        inv_tensor = inv_normalize(image).cpu()
        ax.imshow(inv_PIL(inv_tensor))
        
    plt.show()

# %%
# Mixup Visualization
if mixup:
  alpha = 0.9
  mixed_x, y_a, y_b, lam = mixup_data(batch_X.cuda(), batch_Y.cuda(), alpha=alpha, use_cuda=use_cuda)
  plot_mixed_images(mixed_x[:4])

# %%
# Mixup Visualization
if cutout:
  plot_mixed_images(batch_X[:4])

# %%
# @markdown ResNet model in PyTorch

class Bottleneck(nn.Module):
    """
    For deep networks, we use BottleNeck, which is proposed in the paper to have approximate computational complexity but save a lot of resources
    zip_channels: The compressed dimension, the final output dimension is expansion * zip_channels
    For the network structure of ResNet50/101/152, mainly because the third layer is 4 times the second layer, so expansion=4
    """
    expansion = 4

    def __init__(self, in_channels, zip_channels, stride=1):
        super(Bottleneck, self).__init__()
        out_channels = self.expansion * zip_channels
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, zip_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, zip_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

class BasicBlock(nn.Module):
    """
    For shallow networks, such as ResNet-18/34, etc., use the basic Block
    The base module is not compressed, so expansion=1
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock,self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True),
            nn.Conv2d(out_channels,out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        # If the input and output dimensions are not equal, use a 1x1 convolutional layer to change the dimension
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels),
            )
    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out


class ResNet(nn.Module):
    """
    Different ResNet architectures are unified with one layer of feature extraction and four layers of residuals, and the difference lies in the depth of each layer of residuals.
    For cifar10, the change of feature map size is as follows:
    (32, 32, 3) -> [Conv2d] -> (32, 32, 64) -> [Res1] -> (32, 32, 64) -> [Res2]
 -> (16, 16, 128) -> [Res3] -> (8, 8, 256) ->[Res4] -> (4, 4, 512) -> [AvgPool]
 -> (1, 1, 512) -> [Reshape] -> (512) -> [Linear] -> (10)
    """
    def __init__(self, block, num_blocks, num_classes=10, verbose = False):
        super(ResNet, self).__init__()
        self.verbose = verbose
        self.in_channels = 64
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        #Use the _make_layer function to generate the structure of conv2_x, conv3_x, conv4_x, conv5_x corresponding to the above table
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        # After cifar10 goes through the above structure, the feature map size here is 4 x 4 x 512 x expansion
        # So 4 x 4 average pooling is used here
        self.avg_pool = nn.AvgPool2d(kernel_size=4)
        self.classifer = nn.Linear(512 *block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # The first block needs to be downsampled
        strides = [stride] + [1]* (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            # If it is Bottleneck Block, you need to compress the input dimension of each layer, and then increase the dimension after compression
            # So the input dimension of each layer should also change accordingly
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.features(x)
        if self.verbose:
            print('block 1 output: {}'.format(out.shape))
        out = self.layer1(out)
        if self.verbose:
            print('block 2 output: {}'.format(out.shape))
        out = self.layer2(out)
        if self.verbose:
            print('block 3 output: {}'.format(out.shape))
        out = self.layer3(out)
        if self.verbose:
            print('block 4 output: {}'.format(out.shape))
        out = self.layer4(out)
        if self.verbose:
            print('block 5 output: {}'.format(out.shape))
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.classifer(out)
        return out


def ResNet18(verbose=False):
    return ResNet(BasicBlock, [2,2,2,2],verbose=verbose)

def ResNet34(verbose=False):
    return ResNet(BasicBlock, [3,4,6,3],verbose=verbose)

def ResNet50(verbose=False):
    return ResNet(Bottleneck, [3,4,6,3],verbose=verbose)

def ResNet101(verbose=False):
    return ResNet(Bottleneck, [3,4,23,3],verbose=verbose)

def ResNet152(verbose=False):
    return ResNet(Bottleneck, [3,8,36,3],verbose=verbose)

# %%
# load the Model
net = ResNet18()
print('-----> verify if model is run on random data')
y = net(Variable(torch.randn(1,3,32,32)))
print('model loaded')

result_folder = './results/'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

proc = "{}{}".format("cutout" if cutout else "", "mixup" if mixup else "") 

logname = result_folder + net.__class__.__name__ + '_' +proc+ '_size2.csv'

if use_cuda:
  net.cuda()
  net = torch.nn.DataParallel(net)
  print('Using', torch.cuda.device_count(), 'GPUs.')
  cudnn.benchmark = True
  print('Using CUDA..')
# Out:
# -----> verify if model is run on random data
# model loaded
# Using 1 GPUs.
# Using CUDA..

# %%
# optimizer and criterion

def mixup_criterion(y_a, y_b, lam):
  '''
    - Mixup criterion
    - https://github.com/hongyi-zhang/mixup
  '''
  return lambda criterion, pred: lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=base_learning_rate, weight_decay=5e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=10, min_lr=1e-5)

# %%
# Training & Test functions
def train(epoch, alpha, use_cuda=False):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):

        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        optimizer.zero_grad()
        if mixup:
        # generate mixed inputs, two one-hot label vectors and mixing coefficient
            inputs, targets_a, targets_b, lam = mixup_data(inputs, targets, alpha, use_cuda)
            inputs, targets_a, targets_b = Variable(inputs), Variable(targets_a), Variable(targets_b)
            outputs = net(inputs)
            loss_func = mixup_criterion(targets_a, targets_b, lam)
            loss = loss_func(criterion, outputs)
        else:
            inputs, targets = Variable(inputs), Variable(targets)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)

        if mixup:
            correct += lam * predicted.eq(targets_a.data).cpu().sum() + (1 - lam) * predicted.eq(targets_b.data).cpu().sum()
            # correct += lam * predicted.eq(targets_a.data).sum() + (1 - lam) * predicted.eq(targets_b.data).sum()
        else:
            correct += predicted.eq(targets.data).cpu().sum()
            # correct += predicted.eq(targets.data).sum()

        acc = 100.*(correct/total)
        
        if batch_idx % 500 == 0:
            print(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)' % (train_loss/(batch_idx+1), acc, correct, total))
        

    return (train_loss/batch_idx, acc)

# %%
def test(epoch, use_cuda=False):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            if use_cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += predicted.eq(targets.data).cpu().sum()
            # correct += predicted.eq(targets.data).sum()
            

            if batch_idx % 200 == 0:
                print(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'% (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

    # Save checkpoint.
    acc = 100.*(correct/total)
    
    if acc > best_acc:
        best_acc = acc
        checkpoint(acc, epoch)
    return (test_loss/batch_idx, acc)

# %%
# @markdown `checkpoint` and `adjust_learning_rate` functions
def checkpoint(acc, epoch):
  # Save checkpoint.
  print('Saving..')
  state = {
      'net': net.state_dict(),
      'acc': acc,
      'epoch': epoch,
      'rng_state': torch.get_rng_state()
      }
  if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')
  torch.save(state, './checkpoint/ckpt.t7')


def adjust_learning_rate(optimizer, epoch):
  """decrease the learning rate at 100 and 150 epoch"""
  lr = base_learning_rate
  if epoch <= 9 and lr > 0.1:
    # warm-up training for large minibatch
    lr = 0.1 + (base_learning_rate - 0.1) * epoch / 10.
  if epoch >= 100:
    lr /= 10
  if epoch >= 150:
    lr /= 10
  for param_group in optimizer.param_groups:
    param_group['lr'] = lr

# %%
# start training
if not os.path.exists(logname):
  with open(logname, 'w') as logfile:
    logwriter = csv.writer(logfile, delimiter=',')
    logwriter.writerow(['epoch', 'train loss', 'train acc',
                        'test loss', 'test acc'])

for epoch in range(start_epoch+1, end_apochs+1):
#   adjust_learning_rate(optimizer, epoch)
    start = time.time()

    train_loss, train_acc = train(epoch, alpha, use_cuda=use_cuda)
    test_loss, test_acc = test(epoch, use_cuda=use_cuda)

    scheduler.step(test_loss)

    end = time.time()

    time_ = int(end - start)
    h = time_ / 3600
    m = time_ % 3600 /60
    s = time_ % 60
    time_str = "%02d:%02d" % ( m, s)


    with open(logname, 'a') as logfile:
        logwriter = csv.writer(logfile, delimiter=',')
        logwriter.writerow([epoch, train_loss, train_acc.item(),test_loss, test_acc.item()])
        
    print(f"Epoch: {epoch} | Time Per Epoch: {time_str} | train acc: {train_acc:.2f} | test acc: {test_acc:.2f}% | Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# 0 391 Loss: 2.444 | Acc: 10.156% (13/128)
# 0 79 Loss: 1.575 | Acc: 42.188% (54/128)
# Saving..
# Epoch: 1 | Time Per Epoch: 00:15 | train acc: 35.26 | test acc: 43.83% | Learning Rate: 0.01
#
# Epoch: 2
# 0 391 Loss: 1.436 | Acc: 46.875% (60/128)
# 0 79 Loss: 1.305 | Acc: 53.906% (69/128)
# Saving..
# Epoch: 2 | Time Per Epoch: 00:19 | train acc: 51.44 | test acc: 52.92% | Learning Rate: 0.01
#
# Epoch: 3
# 0 391 Loss: 1.133 | Acc: 57.031% (73/128)
# 0 79 Loss: 1.170 | Acc: 59.375% (76/128)
# Saving..
# Epoch: 3 | Time Per Epoch: 00:19 | train acc: 57.96 | test acc: 59.03% | Learning Rate: 0.01
#
# Epoch: 4
# 0 391 Loss: 1.052 | Acc: 59.375% (76/128)
# 0 79 Loss: 1.205 | Acc: 57.812% (74/128)
# Epoch: 4 | Time Per Epoch: 00:19 | train acc: 62.19 | test acc: 56.07% | Learning Rate: 0.01
#
# Epoch: 5
# 0 391 Loss: 0.937 | Acc: 67.969% (87/128)
# 0 79 Loss: 0.966 | Acc: 60.156% (77/128)
# Saving..
# Epoch: 5 | Time Per Epoch: 00:19 | train acc: 64.79 | test acc: 61.83% | Learning Rate: 0.01
#
# Epoch: 6
# 0 391 Loss: 0.912 | Acc: 69.531% (89/128)
# 0 79 Loss: 1.016 | Acc: 67.969% (87/128)
# Epoch: 6 | Time Per Epoch: 00:19 | train acc: 66.07 | test acc: 61.19% | Learning Rate: 0.01
#
# Epoch: 7
# 0 391 Loss: 0.891 | Acc: 67.969% (87/128)
# 0 79 Loss: 1.098 | Acc: 58.594% (75/128)
# Epoch: 7 | Time Per Epoch: 00:19 | train acc: 67.26 | test acc: 58.65% | Learning Rate: 0.01
#
# Epoch: 8
# 0 391 Loss: 0.975 | Acc: 60.156% (77/128)
# 0 79 Loss: 0.889 | Acc: 68.750% (88/128)
# Saving..
# Epoch: 8 | Time Per Epoch: 00:19 | train acc: 68.16 | test acc: 63.54% | Learning Rate: 0.01
#
# Epoch: 9
# 0 391 Loss: 0.792 | Acc: 67.969% (87/128)
# 0 79 Loss: 1.492 | Acc: 52.344% (67/128)
# Epoch: 9 | Time Per Epoch: 00:20 | train acc: 69.46 | test acc: 55.80% | Learning Rate: 0.01
#
# Epoch: 10
# 0 391 Loss: 0.806 | Acc: 71.094% (91/128)
# 0 79 Loss: 0.955 | Acc: 67.188% (86/128)
# Saving..
# Epoch: 10 | Time Per Epoch: 00:18 | train acc: 70.42 | test acc: 65.44% | Learning Rate: 0.01
#
# Epoch: 11
# 0 391 Loss: 0.801 | Acc: 71.094% (91/128)
# 0 79 Loss: 0.978 | Acc: 66.406% (85/128)
# Epoch: 11 | Time Per Epoch: 00:20 | train acc: 71.44 | test acc: 64.41% | Learning Rate: 0.01
#
# Epoch: 12
# 0 391 Loss: 0.621 | Acc: 77.344% (99/128)
# 0 79 Loss: 1.279 | Acc: 56.250% (72/128)
# Epoch: 12 | Time Per Epoch: 00:19 | train acc: 72.27 | test acc: 56.88% | Learning Rate: 0.01
#
# Epoch: 13
# 0 391 Loss: 0.688 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.907 | Acc: 70.312% (90/128)
# Epoch: 13 | Time Per Epoch: 00:19 | train acc: 72.44 | test acc: 64.93% | Learning Rate: 0.01
#
# Epoch: 14
# 0 391 Loss: 0.728 | Acc: 76.562% (98/128)
# 0 79 Loss: 1.287 | Acc: 57.812% (74/128)
# Epoch: 14 | Time Per Epoch: 00:18 | train acc: 72.63 | test acc: 57.62% | Learning Rate: 0.01
#
# Epoch: 15
# 0 391 Loss: 0.779 | Acc: 71.875% (92/128)
# 0 79 Loss: 0.970 | Acc: 64.844% (83/128)
# Saving..
# Epoch: 15 | Time Per Epoch: 00:19 | train acc: 72.75 | test acc: 65.58% | Learning Rate: 0.01
#
# Epoch: 16
# 0 391 Loss: 0.565 | Acc: 82.812% (106/128)
# 0 79 Loss: 1.194 | Acc: 54.688% (70/128)
# Epoch: 16 | Time Per Epoch: 00:18 | train acc: 73.24 | test acc: 60.81% | Learning Rate: 0.01
#
# Epoch: 17
# 0 391 Loss: 0.866 | Acc: 69.531% (89/128)
# 0 79 Loss: 0.976 | Acc: 67.188% (86/128)
# Saving..
# Epoch: 17 | Time Per Epoch: 00:19 | train acc: 73.51 | test acc: 65.94% | Learning Rate: 0.01
#
# Epoch: 18
# 0 391 Loss: 0.635 | Acc: 74.219% (95/128)
# 0 79 Loss: 0.951 | Acc: 63.281% (81/128)
# Epoch: 18 | Time Per Epoch: 00:20 | train acc: 73.76 | test acc: 61.12% | Learning Rate: 0.01
#
# Epoch: 19
# 0 391 Loss: 0.763 | Acc: 76.562% (98/128)
# 0 79 Loss: 1.032 | Acc: 67.969% (87/128)
# Epoch: 19 | Time Per Epoch: 00:18 | train acc: 73.99 | test acc: 60.45% | Learning Rate: 0.01
#
# Epoch: 20
# 0 391 Loss: 0.763 | Acc: 74.219% (95/128)
# 0 79 Loss: 0.875 | Acc: 71.875% (92/128)
# Epoch: 20 | Time Per Epoch: 00:19 | train acc: 74.10 | test acc: 64.11% | Learning Rate: 0.01
#
# Epoch: 21
# 0 391 Loss: 0.659 | Acc: 76.562% (98/128)
# 0 79 Loss: 0.799 | Acc: 71.094% (91/128)
# Saving..
# Epoch: 21 | Time Per Epoch: 00:18 | train acc: 74.26 | test acc: 66.98% | Learning Rate: 0.01
#
# Epoch: 22
# 0 391 Loss: 0.789 | Acc: 71.094% (91/128)
# 0 79 Loss: 1.016 | Acc: 60.938% (78/128)
# Epoch: 22 | Time Per Epoch: 00:19 | train acc: 74.15 | test acc: 63.40% | Learning Rate: 0.01
#
# Epoch: 23
# 0 391 Loss: 0.716 | Acc: 74.219% (95/128)
# 0 79 Loss: 1.081 | Acc: 63.281% (81/128)
# Epoch: 23 | Time Per Epoch: 00:21 | train acc: 74.26 | test acc: 59.69% | Learning Rate: 0.01
#
# Epoch: 24
# 0 391 Loss: 0.565 | Acc: 83.594% (107/128)
# 0 79 Loss: 0.868 | Acc: 70.312% (90/128)
# Epoch: 24 | Time Per Epoch: 00:36 | train acc: 74.62 | test acc: 66.62% | Learning Rate: 0.01
#
# Epoch: 25
# 0 391 Loss: 0.712 | Acc: 77.344% (99/128)
# 0 79 Loss: 1.179 | Acc: 64.062% (82/128)
# Epoch: 25 | Time Per Epoch: 00:29 | train acc: 74.23 | test acc: 61.87% | Learning Rate: 0.01
#
# Epoch: 26
# 0 391 Loss: 0.690 | Acc: 76.562% (98/128)
# 0 79 Loss: 1.168 | Acc: 64.844% (83/128)
# Epoch: 26 | Time Per Epoch: 00:32 | train acc: 74.35 | test acc: 60.68% | Learning Rate: 0.01
#
# Epoch: 27
# 0 391 Loss: 0.754 | Acc: 69.531% (89/128)
# 0 79 Loss: 0.826 | Acc: 71.875% (92/128)
# Epoch: 27 | Time Per Epoch: 00:32 | train acc: 74.78 | test acc: 66.29% | Learning Rate: 0.01
#
# Epoch: 28
# 0 391 Loss: 0.768 | Acc: 73.438% (94/128)
# 0 79 Loss: 1.001 | Acc: 64.062% (82/128)
# Epoch: 28 | Time Per Epoch: 00:33 | train acc: 74.74 | test acc: 60.82% | Learning Rate: 0.01
#
# Epoch: 29
# 0 391 Loss: 0.696 | Acc: 78.906% (101/128)
# 0 79 Loss: 0.840 | Acc: 71.875% (92/128)
# Saving..
# Epoch: 29 | Time Per Epoch: 01:13 | train acc: 74.92 | test acc: 69.58% | Learning Rate: 0.01
#
# Epoch: 30
# 0 391 Loss: 0.784 | Acc: 71.094% (91/128)
# 0 79 Loss: 0.942 | Acc: 70.312% (90/128)
# Epoch: 30 | Time Per Epoch: 00:52 | train acc: 74.94 | test acc: 66.30% | Learning Rate: 0.01
#
# Epoch: 31
# 0 391 Loss: 0.553 | Acc: 82.812% (106/128)
# 0 79 Loss: 0.886 | Acc: 71.875% (92/128)
# Epoch: 31 | Time Per Epoch: 00:55 | train acc: 74.71 | test acc: 65.77% | Learning Rate: 0.01
#
# Epoch: 32
# 0 391 Loss: 0.666 | Acc: 75.781% (97/128)
# 0 79 Loss: 1.645 | Acc: 50.781% (65/128)
# Epoch: 32 | Time Per Epoch: 00:55 | train acc: 75.09 | test acc: 49.81% | Learning Rate: 0.01
#
# Epoch: 33
# 0 391 Loss: 0.768 | Acc: 73.438% (94/128)
# 0 79 Loss: 1.367 | Acc: 55.469% (71/128)
# Epoch: 33 | Time Per Epoch: 00:54 | train acc: 74.77 | test acc: 61.08% | Learning Rate: 0.01
#
# Epoch: 34
# 0 391 Loss: 0.617 | Acc: 74.219% (95/128)
# 0 79 Loss: 1.295 | Acc: 59.375% (76/128)
# Epoch: 34 | Time Per Epoch: 00:55 | train acc: 75.15 | test acc: 59.06% | Learning Rate: 0.01
#
# Epoch: 35
# 0 391 Loss: 0.734 | Acc: 75.000% (96/128)
# 0 79 Loss: 1.161 | Acc: 57.812% (74/128)
# Epoch: 35 | Time Per Epoch: 00:54 | train acc: 74.87 | test acc: 59.17% | Learning Rate: 0.01
#
# Epoch: 36
# 0 391 Loss: 0.782 | Acc: 76.562% (98/128)
# 0 79 Loss: 2.101 | Acc: 45.312% (58/128)
# Epoch: 36 | Time Per Epoch: 00:55 | train acc: 74.85 | test acc: 45.32% | Learning Rate: 0.01
#
# Epoch: 37
# 0 391 Loss: 0.571 | Acc: 82.031% (105/128)
# 0 79 Loss: 1.362 | Acc: 51.562% (66/128)
# Epoch: 37 | Time Per Epoch: 00:54 | train acc: 75.05 | test acc: 54.31% | Learning Rate: 0.01
#
# Epoch: 38
# 0 391 Loss: 0.880 | Acc: 72.656% (93/128)
# 0 79 Loss: 1.182 | Acc: 60.938% (78/128)
# Epoch: 38 | Time Per Epoch: 00:54 | train acc: 75.22 | test acc: 60.32% | Learning Rate: 0.01
#
# Epoch: 39
# 0 391 Loss: 0.726 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.882 | Acc: 73.438% (94/128)
# Epoch: 39 | Time Per Epoch: 00:57 | train acc: 75.21 | test acc: 64.05% | Learning Rate: 0.01
#
# Epoch: 40
# 0 391 Loss: 0.537 | Acc: 83.594% (107/128)
# 0 79 Loss: 0.686 | Acc: 73.438% (94/128)
# Saving..
# Epoch: 40 | Time Per Epoch: 00:57 | train acc: 75.15 | test acc: 71.83% | Learning Rate: 0.01
#
# Epoch: 41
# 0 391 Loss: 0.731 | Acc: 74.219% (95/128)
# 0 79 Loss: 1.130 | Acc: 60.156% (77/128)
# Epoch: 41 | Time Per Epoch: 00:54 | train acc: 75.01 | test acc: 62.96% | Learning Rate: 0.01
#
# Epoch: 42
# 0 391 Loss: 0.623 | Acc: 75.781% (97/128)
# 0 79 Loss: 1.193 | Acc: 62.500% (80/128)
# Epoch: 42 | Time Per Epoch: 00:54 | train acc: 75.06 | test acc: 62.26% | Learning Rate: 0.01
#
# Epoch: 43
# 0 391 Loss: 0.702 | Acc: 74.219% (95/128)
# 0 79 Loss: 0.856 | Acc: 71.094% (91/128)
# Epoch: 43 | Time Per Epoch: 00:53 | train acc: 75.30 | test acc: 66.97% | Learning Rate: 0.01
#
# Epoch: 44
# 0 391 Loss: 0.619 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.935 | Acc: 69.531% (89/128)
# Epoch: 44 | Time Per Epoch: 00:55 | train acc: 75.25 | test acc: 64.21% | Learning Rate: 0.01
#
# Epoch: 45
# 0 391 Loss: 0.624 | Acc: 77.344% (99/128)
# 0 79 Loss: 1.002 | Acc: 66.406% (85/128)
# Epoch: 45 | Time Per Epoch: 00:55 | train acc: 75.17 | test acc: 65.79% | Learning Rate: 0.01
#
# Epoch: 46
# 0 391 Loss: 0.536 | Acc: 78.906% (101/128)
# 0 79 Loss: 0.877 | Acc: 71.094% (91/128)
# Epoch: 46 | Time Per Epoch: 00:54 | train acc: 75.05 | test acc: 69.03% | Learning Rate: 0.01
#
# Epoch: 47
# 0 391 Loss: 0.643 | Acc: 78.906% (101/128)
# 0 79 Loss: 0.996 | Acc: 67.969% (87/128)
# Epoch: 47 | Time Per Epoch: 00:55 | train acc: 75.47 | test acc: 63.65% | Learning Rate: 0.01
#
# Epoch: 48
# 0 391 Loss: 0.659 | Acc: 78.906% (101/128)
# 0 79 Loss: 0.770 | Acc: 75.000% (96/128)
# Epoch: 48 | Time Per Epoch: 00:56 | train acc: 75.04 | test acc: 70.68% | Learning Rate: 0.01
#
# Epoch: 49
# 0 391 Loss: 0.607 | Acc: 80.469% (103/128)
# 0 79 Loss: 0.787 | Acc: 75.781% (97/128)
# Epoch: 49 | Time Per Epoch: 00:55 | train acc: 75.42 | test acc: 70.54% | Learning Rate: 0.01
#
# Epoch: 50
# 0 391 Loss: 0.782 | Acc: 72.656% (93/128)
# 0 79 Loss: 1.957 | Acc: 48.438% (62/128)
# Epoch: 50 | Time Per Epoch: 00:54 | train acc: 75.13 | test acc: 48.77% | Learning Rate: 0.01
#
# Epoch: 51
# 0 391 Loss: 0.732 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.825 | Acc: 68.750% (88/128)
# Epoch: 51 | Time Per Epoch: 00:55 | train acc: 75.36 | test acc: 67.76% | Learning Rate: 0.01
#
# Epoch: 52
# 0 391 Loss: 0.717 | Acc: 71.094% (91/128)
# 0 79 Loss: 1.281 | Acc: 56.250% (72/128)
# Epoch: 52 | Time Per Epoch: 00:56 | train acc: 75.16 | test acc: 58.14% | Learning Rate: 0.01
#
# Epoch: 53
# 0 391 Loss: 0.608 | Acc: 76.562% (98/128)
# 0 79 Loss: 2.655 | Acc: 37.500% (48/128)
# Epoch: 53 | Time Per Epoch: 00:55 | train acc: 75.30 | test acc: 36.09% | Learning Rate: 0.01
#
# Epoch: 54
# 0 391 Loss: 0.725 | Acc: 74.219% (95/128)
# 0 79 Loss: 0.916 | Acc: 66.406% (85/128)
# Epoch: 54 | Time Per Epoch: 00:55 | train acc: 75.39 | test acc: 66.01% | Learning Rate: 0.01
#
# Epoch: 55
# 0 391 Loss: 0.709 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.714 | Acc: 77.344% (99/128)
# Epoch: 55 | Time Per Epoch: 00:55 | train acc: 75.44 | test acc: 69.15% | Learning Rate: 0.01
#
# Epoch: 56
# 0 391 Loss: 0.557 | Acc: 83.594% (107/128)
# 0 79 Loss: 0.885 | Acc: 67.188% (86/128)
# Epoch: 56 | Time Per Epoch: 00:54 | train acc: 75.39 | test acc: 61.17% | Learning Rate: 0.01
#
# Epoch: 57
# 0 391 Loss: 0.816 | Acc: 72.656% (93/128)
# 0 79 Loss: 0.861 | Acc: 67.188% (86/128)
# Epoch: 57 | Time Per Epoch: 00:55 | train acc: 75.37 | test acc: 66.30% | Learning Rate: 0.01
#
# Epoch: 58
# 0 391 Loss: 0.666 | Acc: 79.688% (102/128)
# 0 79 Loss: 0.810 | Acc: 68.750% (88/128)
# Epoch: 58 | Time Per Epoch: 00:55 | train acc: 75.58 | test acc: 66.71% | Learning Rate: 0.01
#
# Epoch: 59
# 0 391 Loss: 0.692 | Acc: 78.906% (101/128)
# 0 79 Loss: 0.844 | Acc: 69.531% (89/128)
# Epoch: 59 | Time Per Epoch: 00:55 | train acc: 75.50 | test acc: 68.89% | Learning Rate: 0.001
#
# Epoch: 60
# 0 391 Loss: 0.669 | Acc: 73.438% (94/128)
# 0 79 Loss: 0.542 | Acc: 79.688% (102/128)
# Saving..
# Epoch: 60 | Time Per Epoch: 00:55 | train acc: 80.69 | test acc: 78.91% | Learning Rate: 0.001
#
# Epoch: 61
# 0 391 Loss: 0.410 | Acc: 87.500% (112/128)
# 0 79 Loss: 0.543 | Acc: 81.250% (104/128)
# Saving..
# Epoch: 61 | Time Per Epoch: 00:55 | train acc: 82.21 | test acc: 79.00% | Learning Rate: 0.001
#
# Epoch: 62
# 0 391 Loss: 0.521 | Acc: 82.812% (106/128)
# 0 79 Loss: 0.585 | Acc: 79.688% (102/128)
# Saving..
# Epoch: 62 | Time Per Epoch: 00:55 | train acc: 82.60 | test acc: 79.25% | Learning Rate: 0.001
#
# Epoch: 63
# 0 391 Loss: 0.628 | Acc: 74.219% (95/128)
# 0 79 Loss: 0.548 | Acc: 82.031% (105/128)
# Saving..
# Epoch: 63 | Time Per Epoch: 00:54 | train acc: 83.14 | test acc: 79.47% | Learning Rate: 0.001
#
# Epoch: 64
# 0 391 Loss: 0.574 | Acc: 79.688% (102/128)
# 0 79 Loss: 0.520 | Acc: 83.594% (107/128)
# Saving..
# Epoch: 64 | Time Per Epoch: 00:56 | train acc: 83.54 | test acc: 79.53% | Learning Rate: 0.001
#
# Epoch: 65
# 0 391 Loss: 0.461 | Acc: 83.594% (107/128)
# 0 79 Loss: 0.565 | Acc: 82.031% (105/128)
# Saving..
# Epoch: 65 | Time Per Epoch: 00:54 | train acc: 83.88 | test acc: 79.75% | Learning Rate: 0.001
#
# Epoch: 66
# 0 391 Loss: 0.390 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.570 | Acc: 81.250% (104/128)
# Epoch: 66 | Time Per Epoch: 00:53 | train acc: 84.49 | test acc: 79.57% | Learning Rate: 0.001
#
# Epoch: 67
# 0 391 Loss: 0.364 | Acc: 88.281% (113/128)
# 0 79 Loss: 0.575 | Acc: 81.250% (104/128)
# Epoch: 67 | Time Per Epoch: 00:53 | train acc: 84.83 | test acc: 79.13% | Learning Rate: 0.001
#
# Epoch: 68
# 0 391 Loss: 0.389 | Acc: 86.719% (111/128)
# 0 79 Loss: 0.609 | Acc: 80.469% (103/128)
# Epoch: 68 | Time Per Epoch: 00:52 | train acc: 85.07 | test acc: 79.12% | Learning Rate: 0.001
#
# Epoch: 69
# 0 391 Loss: 0.459 | Acc: 84.375% (108/128)
# 0 79 Loss: 0.573 | Acc: 82.031% (105/128)
# Saving..
# Epoch: 69 | Time Per Epoch: 00:52 | train acc: 85.58 | test acc: 79.84% | Learning Rate: 0.001
#
# Epoch: 70
# 0 391 Loss: 0.374 | Acc: 85.156% (109/128)
# 0 79 Loss: 0.608 | Acc: 79.688% (102/128)
# Epoch: 70 | Time Per Epoch: 00:51 | train acc: 85.79 | test acc: 79.72% | Learning Rate: 0.001
#
# Epoch: 71
# 0 391 Loss: 0.335 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.503 | Acc: 80.469% (103/128)
# Epoch: 71 | Time Per Epoch: 00:51 | train acc: 86.20 | test acc: 79.77% | Learning Rate: 0.001
#
# Epoch: 72
# 0 391 Loss: 0.269 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.582 | Acc: 83.594% (107/128)
# Epoch: 72 | Time Per Epoch: 00:53 | train acc: 86.50 | test acc: 79.35% | Learning Rate: 0.001
#
# Epoch: 73
# 0 391 Loss: 0.367 | Acc: 87.500% (112/128)
# 0 79 Loss: 0.556 | Acc: 85.156% (109/128)
# Saving..
# Epoch: 73 | Time Per Epoch: 00:53 | train acc: 86.91 | test acc: 80.05% | Learning Rate: 0.001
#
# Epoch: 74
# 0 391 Loss: 0.386 | Acc: 85.156% (109/128)
# 0 79 Loss: 0.571 | Acc: 84.375% (108/128)
# Epoch: 74 | Time Per Epoch: 00:52 | train acc: 87.17 | test acc: 79.31% | Learning Rate: 0.001
#
# Epoch: 75
# 0 391 Loss: 0.218 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.612 | Acc: 81.250% (104/128)
# Epoch: 75 | Time Per Epoch: 00:53 | train acc: 87.31 | test acc: 79.15% | Learning Rate: 0.001
#
# Epoch: 76
# 0 391 Loss: 0.371 | Acc: 88.281% (113/128)
# 0 79 Loss: 0.603 | Acc: 82.812% (106/128)
# Epoch: 76 | Time Per Epoch: 00:53 | train acc: 87.55 | test acc: 79.13% | Learning Rate: 0.0001
#
# Epoch: 77
# 0 391 Loss: 0.316 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.532 | Acc: 85.156% (109/128)
# Saving..
# Epoch: 77 | Time Per Epoch: 00:53 | train acc: 89.86 | test acc: 80.74% | Learning Rate: 0.0001
#
# Epoch: 78
# 0 391 Loss: 0.335 | Acc: 87.500% (112/128)
# 0 79 Loss: 0.547 | Acc: 86.719% (111/128)
# Epoch: 78 | Time Per Epoch: 00:53 | train acc: 90.46 | test acc: 80.73% | Learning Rate: 0.0001
#
# Epoch: 79
# 0 391 Loss: 0.408 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.556 | Acc: 84.375% (108/128)
# Epoch: 79 | Time Per Epoch: 00:52 | train acc: 90.78 | test acc: 80.69% | Learning Rate: 0.0001
#
# Epoch: 80
# 0 391 Loss: 0.202 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.552 | Acc: 84.375% (108/128)
# Epoch: 80 | Time Per Epoch: 00:52 | train acc: 90.81 | test acc: 80.68% | Learning Rate: 0.0001
#
# Epoch: 81
# 0 391 Loss: 0.249 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.560 | Acc: 83.594% (107/128)
# Epoch: 81 | Time Per Epoch: 00:52 | train acc: 91.00 | test acc: 80.51% | Learning Rate: 0.0001
#
# Epoch: 82
# 0 391 Loss: 0.264 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.560 | Acc: 85.938% (110/128)
# Saving..
# Epoch: 82 | Time Per Epoch: 00:53 | train acc: 91.14 | test acc: 80.81% | Learning Rate: 0.0001
#
# Epoch: 83
# 0 391 Loss: 0.263 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.567 | Acc: 84.375% (108/128)
# Epoch: 83 | Time Per Epoch: 00:52 | train acc: 91.30 | test acc: 80.78% | Learning Rate: 0.0001
#
# Epoch: 84
# 0 391 Loss: 0.227 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.584 | Acc: 82.812% (106/128)
# Epoch: 84 | Time Per Epoch: 00:53 | train acc: 91.33 | test acc: 80.41% | Learning Rate: 0.0001
#
# Epoch: 85
# 0 391 Loss: 0.183 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.583 | Acc: 82.812% (106/128)
# Epoch: 85 | Time Per Epoch: 00:51 | train acc: 91.44 | test acc: 80.40% | Learning Rate: 0.0001
#
# Epoch: 86
# 0 391 Loss: 0.395 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.571 | Acc: 83.594% (107/128)
# Epoch: 86 | Time Per Epoch: 00:51 | train acc: 91.53 | test acc: 80.35% | Learning Rate: 0.0001
#
# Epoch: 87
# 0 391 Loss: 0.228 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.571 | Acc: 84.375% (108/128)
# Epoch: 87 | Time Per Epoch: 00:52 | train acc: 91.58 | test acc: 80.36% | Learning Rate: 1e-05
#
# Epoch: 88
# 0 391 Loss: 0.235 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.600 | Acc: 82.812% (106/128)
# Epoch: 88 | Time Per Epoch: 00:51 | train acc: 91.95 | test acc: 80.18% | Learning Rate: 1e-05
#
# Epoch: 89
# 0 391 Loss: 0.175 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.587 | Acc: 83.594% (107/128)
# Epoch: 89 | Time Per Epoch: 00:51 | train acc: 92.03 | test acc: 80.27% | Learning Rate: 1e-05
#
# Epoch: 90
# 0 391 Loss: 0.235 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.586 | Acc: 83.594% (107/128)
# Epoch: 90 | Time Per Epoch: 00:50 | train acc: 91.84 | test acc: 80.34% | Learning Rate: 1e-05
#
# Epoch: 91
# 0 391 Loss: 0.173 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.584 | Acc: 84.375% (108/128)
# Epoch: 91 | Time Per Epoch: 00:51 | train acc: 92.17 | test acc: 80.49% | Learning Rate: 1e-05
#
# Epoch: 92
# 0 391 Loss: 0.258 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.588 | Acc: 83.594% (107/128)
# Epoch: 92 | Time Per Epoch: 00:51 | train acc: 92.05 | test acc: 80.27% | Learning Rate: 1e-05
#
# Epoch: 93
# 0 391 Loss: 0.222 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.584 | Acc: 83.594% (107/128)
# Epoch: 93 | Time Per Epoch: 00:51 | train acc: 92.06 | test acc: 80.39% | Learning Rate: 1e-05
#
# Epoch: 94
# 0 391 Loss: 0.189 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.594 | Acc: 83.594% (107/128)
# Epoch: 94 | Time Per Epoch: 00:50 | train acc: 92.08 | test acc: 80.45% | Learning Rate: 1e-05
#
# Epoch: 95
# 0 391 Loss: 0.272 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.595 | Acc: 83.594% (107/128)
# Epoch: 95 | Time Per Epoch: 00:50 | train acc: 92.07 | test acc: 80.51% | Learning Rate: 1e-05
#
# Epoch: 96
# 0 391 Loss: 0.203 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.590 | Acc: 83.594% (107/128)
# Epoch: 96 | Time Per Epoch: 00:50 | train acc: 92.02 | test acc: 80.55% | Learning Rate: 1e-05
#
# Epoch: 97
# 0 391 Loss: 0.211 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.593 | Acc: 84.375% (108/128)
# Epoch: 97 | Time Per Epoch: 00:51 | train acc: 92.16 | test acc: 80.30% | Learning Rate: 1e-05
#
# Epoch: 98
# 0 391 Loss: 0.240 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.594 | Acc: 83.594% (107/128)
# Epoch: 98 | Time Per Epoch: 00:51 | train acc: 92.19 | test acc: 80.41% | Learning Rate: 1e-05
#
# Epoch: 99
# 0 391 Loss: 0.237 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.591 | Acc: 83.594% (107/128)
# Epoch: 99 | Time Per Epoch: 00:50 | train acc: 92.06 | test acc: 80.31% | Learning Rate: 1e-05
#
# Epoch: 100
# 0 391 Loss: 0.164 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.602 | Acc: 83.594% (107/128)
# Epoch: 100 | Time Per Epoch: 00:52 | train acc: 92.34 | test acc: 80.26% | Learning Rate: 1e-05
#
# Epoch: 101
# 0 391 Loss: 0.193 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.589 | Acc: 84.375% (108/128)
# Epoch: 101 | Time Per Epoch: 00:51 | train acc: 92.19 | test acc: 80.33% | Learning Rate: 1e-05
#
# Epoch: 102
# 0 391 Loss: 0.181 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.597 | Acc: 84.375% (108/128)
# Epoch: 102 | Time Per Epoch: 00:50 | train acc: 92.24 | test acc: 80.47% | Learning Rate: 1e-05
#
# Epoch: 103
# 0 391 Loss: 0.178 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.603 | Acc: 83.594% (107/128)
# Epoch: 103 | Time Per Epoch: 00:50 | train acc: 92.18 | test acc: 80.46% | Learning Rate: 1e-05
#
# Epoch: 104
# 0 391 Loss: 0.275 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.593 | Acc: 84.375% (108/128)
# Epoch: 104 | Time Per Epoch: 00:51 | train acc: 92.28 | test acc: 80.34% | Learning Rate: 1e-05
#
# Epoch: 105
# 0 391 Loss: 0.216 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.593 | Acc: 83.594% (107/128)
# Epoch: 105 | Time Per Epoch: 00:50 | train acc: 92.30 | test acc: 80.44% | Learning Rate: 1e-05
#
# Epoch: 106
# 0 391 Loss: 0.320 | Acc: 87.500% (112/128)
# 0 79 Loss: 0.592 | Acc: 84.375% (108/128)
# Epoch: 106 | Time Per Epoch: 00:51 | train acc: 92.25 | test acc: 80.41% | Learning Rate: 1e-05
#
# Epoch: 107
# 0 391 Loss: 0.266 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.590 | Acc: 84.375% (108/128)
# Epoch: 107 | Time Per Epoch: 00:51 | train acc: 92.24 | test acc: 80.29% | Learning Rate: 1e-05
#
# Epoch: 108
# 0 391 Loss: 0.256 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.598 | Acc: 83.594% (107/128)
# Epoch: 108 | Time Per Epoch: 00:51 | train acc: 92.32 | test acc: 80.30% | Learning Rate: 1e-05
#
# Epoch: 109
# 0 391 Loss: 0.166 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.593 | Acc: 84.375% (108/128)
# Epoch: 109 | Time Per Epoch: 00:51 | train acc: 92.31 | test acc: 80.48% | Learning Rate: 1e-05
#
# Epoch: 110
# 0 391 Loss: 0.223 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.607 | Acc: 83.594% (107/128)
# Epoch: 110 | Time Per Epoch: 00:50 | train acc: 92.20 | test acc: 80.24% | Learning Rate: 1e-05
#
# Epoch: 111
# 0 391 Loss: 0.314 | Acc: 87.500% (112/128)
# 0 79 Loss: 0.603 | Acc: 83.594% (107/128)
# Epoch: 111 | Time Per Epoch: 00:50 | train acc: 92.38 | test acc: 80.29% | Learning Rate: 1e-05
#
# Epoch: 112
# 0 391 Loss: 0.157 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.605 | Acc: 83.594% (107/128)
# Epoch: 112 | Time Per Epoch: 00:50 | train acc: 92.30 | test acc: 80.22% | Learning Rate: 1e-05
#
# Epoch: 113
# 0 391 Loss: 0.188 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.591 | Acc: 83.594% (107/128)
# Epoch: 113 | Time Per Epoch: 00:50 | train acc: 92.47 | test acc: 80.34% | Learning Rate: 1e-05
#
# Epoch: 114
# 0 391 Loss: 0.178 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.603 | Acc: 83.594% (107/128)
# Epoch: 114 | Time Per Epoch: 00:50 | train acc: 92.40 | test acc: 80.25% | Learning Rate: 1e-05
#
# Epoch: 115
# 0 391 Loss: 0.224 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.617 | Acc: 83.594% (107/128)
# Epoch: 115 | Time Per Epoch: 00:51 | train acc: 92.39 | test acc: 80.19% | Learning Rate: 1e-05
#
# Epoch: 116
# 0 391 Loss: 0.221 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.601 | Acc: 83.594% (107/128)
# Epoch: 116 | Time Per Epoch: 00:52 | train acc: 92.34 | test acc: 80.25% | Learning Rate: 1e-05
#
# Epoch: 117
# 0 391 Loss: 0.226 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.607 | Acc: 83.594% (107/128)
# Epoch: 117 | Time Per Epoch: 00:51 | train acc: 92.29 | test acc: 80.41% | Learning Rate: 1e-05
#
# Epoch: 118
# 0 391 Loss: 0.155 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.610 | Acc: 83.594% (107/128)
# Epoch: 118 | Time Per Epoch: 00:53 | train acc: 92.49 | test acc: 80.32% | Learning Rate: 1e-05
#
# Epoch: 119
# 0 391 Loss: 0.228 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.605 | Acc: 83.594% (107/128)
# Epoch: 119 | Time Per Epoch: 00:52 | train acc: 92.35 | test acc: 80.36% | Learning Rate: 1e-05
#
# Epoch: 120
# 0 391 Loss: 0.292 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.607 | Acc: 84.375% (108/128)
# Epoch: 120 | Time Per Epoch: 00:53 | train acc: 92.39 | test acc: 80.27% | Learning Rate: 1e-05
#
# Epoch: 121
# 0 391 Loss: 0.265 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.611 | Acc: 83.594% (107/128)
# Epoch: 121 | Time Per Epoch: 00:52 | train acc: 92.48 | test acc: 80.20% | Learning Rate: 1e-05
#
# Epoch: 122
# 0 391 Loss: 0.182 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.609 | Acc: 83.594% (107/128)
# Epoch: 122 | Time Per Epoch: 00:52 | train acc: 92.56 | test acc: 80.20% | Learning Rate: 1e-05
#
# Epoch: 123
# 0 391 Loss: 0.237 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.607 | Acc: 83.594% (107/128)
# Epoch: 123 | Time Per Epoch: 00:52 | train acc: 92.43 | test acc: 80.23% | Learning Rate: 1e-05
#
# Epoch: 124
# 0 391 Loss: 0.270 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.602 | Acc: 84.375% (108/128)
# Epoch: 124 | Time Per Epoch: 00:51 | train acc: 92.48 | test acc: 80.10% | Learning Rate: 1e-05
#
# Epoch: 125
# 0 391 Loss: 0.234 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.612 | Acc: 82.812% (106/128)
# Epoch: 125 | Time Per Epoch: 00:51 | train acc: 92.42 | test acc: 80.16% | Learning Rate: 1e-05
#
# Epoch: 126
# 0 391 Loss: 0.329 | Acc: 86.719% (111/128)
# 0 79 Loss: 0.613 | Acc: 83.594% (107/128)
# Epoch: 126 | Time Per Epoch: 00:51 | train acc: 92.33 | test acc: 80.27% | Learning Rate: 1e-05
#
# Epoch: 127
# 0 391 Loss: 0.275 | Acc: 89.062% (114/128)
# 0 79 Loss: 0.612 | Acc: 83.594% (107/128)
# Epoch: 127 | Time Per Epoch: 00:53 | train acc: 92.45 | test acc: 80.14% | Learning Rate: 1e-05
#
# Epoch: 128
# 0 391 Loss: 0.200 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.610 | Acc: 84.375% (108/128)
# Epoch: 128 | Time Per Epoch: 00:53 | train acc: 92.57 | test acc: 80.13% | Learning Rate: 1e-05
#
# Epoch: 129
# 0 391 Loss: 0.224 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.615 | Acc: 82.812% (106/128)
# Epoch: 129 | Time Per Epoch: 00:53 | train acc: 92.68 | test acc: 80.12% | Learning Rate: 1e-05
#
# Epoch: 130
# 0 391 Loss: 0.166 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.616 | Acc: 83.594% (107/128)
# Epoch: 130 | Time Per Epoch: 00:53 | train acc: 92.63 | test acc: 80.27% | Learning Rate: 1e-05
#
# Epoch: 131
# 0 391 Loss: 0.218 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.607 | Acc: 83.594% (107/128)
# Epoch: 131 | Time Per Epoch: 00:54 | train acc: 92.58 | test acc: 80.26% | Learning Rate: 1e-05
#
# Epoch: 132
# 0 391 Loss: 0.280 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.612 | Acc: 83.594% (107/128)
# Epoch: 132 | Time Per Epoch: 00:54 | train acc: 92.51 | test acc: 80.07% | Learning Rate: 1e-05
#
# Epoch: 133
# 0 391 Loss: 0.289 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.617 | Acc: 83.594% (107/128)
# Epoch: 133 | Time Per Epoch: 00:54 | train acc: 92.56 | test acc: 80.14% | Learning Rate: 1e-05
#
# Epoch: 134
# 0 391 Loss: 0.189 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.611 | Acc: 84.375% (108/128)
# Epoch: 134 | Time Per Epoch: 00:54 | train acc: 92.69 | test acc: 80.25% | Learning Rate: 1e-05
#
# Epoch: 135
# 0 391 Loss: 0.253 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.621 | Acc: 83.594% (107/128)
# Epoch: 135 | Time Per Epoch: 00:54 | train acc: 92.69 | test acc: 80.12% | Learning Rate: 1e-05
#
# Epoch: 136
# 0 391 Loss: 0.277 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.620 | Acc: 83.594% (107/128)
# Epoch: 136 | Time Per Epoch: 00:53 | train acc: 92.68 | test acc: 80.10% | Learning Rate: 1e-05
#
# Epoch: 137
# 0 391 Loss: 0.222 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.616 | Acc: 83.594% (107/128)
# Epoch: 137 | Time Per Epoch: 00:53 | train acc: 92.69 | test acc: 80.16% | Learning Rate: 1e-05
#
# Epoch: 138
# 0 391 Loss: 0.224 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.619 | Acc: 82.812% (106/128)
# Epoch: 138 | Time Per Epoch: 00:52 | train acc: 92.77 | test acc: 80.22% | Learning Rate: 1e-05
#
# Epoch: 139
# 0 391 Loss: 0.150 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.626 | Acc: 83.594% (107/128)
# Epoch: 139 | Time Per Epoch: 00:52 | train acc: 92.60 | test acc: 80.28% | Learning Rate: 1e-05
#
# Epoch: 140
# 0 391 Loss: 0.201 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.621 | Acc: 82.812% (106/128)
# Epoch: 140 | Time Per Epoch: 00:53 | train acc: 92.67 | test acc: 80.18% | Learning Rate: 1e-05
#
# Epoch: 141
# 0 391 Loss: 0.222 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.621 | Acc: 83.594% (107/128)
# Epoch: 141 | Time Per Epoch: 00:52 | train acc: 92.69 | test acc: 80.08% | Learning Rate: 1e-05
#
# Epoch: 142
# 0 391 Loss: 0.175 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.628 | Acc: 83.594% (107/128)
# Epoch: 142 | Time Per Epoch: 00:52 | train acc: 92.81 | test acc: 79.97% | Learning Rate: 1e-05
#
# Epoch: 143
# 0 391 Loss: 0.222 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.623 | Acc: 84.375% (108/128)
# Epoch: 143 | Time Per Epoch: 00:53 | train acc: 92.89 | test acc: 80.18% | Learning Rate: 1e-05
#
# Epoch: 144
# 0 391 Loss: 0.168 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.622 | Acc: 83.594% (107/128)
# Epoch: 144 | Time Per Epoch: 00:53 | train acc: 92.78 | test acc: 79.81% | Learning Rate: 1e-05
#
# Epoch: 145
# 0 391 Loss: 0.134 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.625 | Acc: 82.812% (106/128)
# Epoch: 145 | Time Per Epoch: 00:51 | train acc: 92.88 | test acc: 80.09% | Learning Rate: 1e-05
#
# Epoch: 146
# 0 391 Loss: 0.177 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.625 | Acc: 84.375% (108/128)
# Epoch: 146 | Time Per Epoch: 00:52 | train acc: 92.90 | test acc: 80.28% | Learning Rate: 1e-05
#
# Epoch: 147
# 0 391 Loss: 0.247 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.629 | Acc: 83.594% (107/128)
# Epoch: 147 | Time Per Epoch: 00:52 | train acc: 92.92 | test acc: 80.07% | Learning Rate: 1e-05
#
# Epoch: 148
# 0 391 Loss: 0.204 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.624 | Acc: 84.375% (108/128)
# Epoch: 148 | Time Per Epoch: 00:52 | train acc: 92.66 | test acc: 80.10% | Learning Rate: 1e-05
#
# Epoch: 149
# 0 391 Loss: 0.203 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.622 | Acc: 84.375% (108/128)
# Epoch: 149 | Time Per Epoch: 00:52 | train acc: 92.78 | test acc: 80.13% | Learning Rate: 1e-05
#
# Epoch: 150
# 0 391 Loss: 0.157 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.625 | Acc: 84.375% (108/128)
# Epoch: 150 | Time Per Epoch: 00:51 | train acc: 92.96 | test acc: 79.96% | Learning Rate: 1e-05
#
# Epoch: 151
# 0 391 Loss: 0.265 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.631 | Acc: 83.594% (107/128)
# Epoch: 151 | Time Per Epoch: 00:52 | train acc: 93.04 | test acc: 80.04% | Learning Rate: 1e-05
#
# Epoch: 152
# 0 391 Loss: 0.136 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.629 | Acc: 83.594% (107/128)
# Epoch: 152 | Time Per Epoch: 00:52 | train acc: 92.82 | test acc: 80.10% | Learning Rate: 1e-05
#
# Epoch: 153
# 0 391 Loss: 0.299 | Acc: 88.281% (113/128)
# 0 79 Loss: 0.630 | Acc: 84.375% (108/128)
# Epoch: 153 | Time Per Epoch: 00:52 | train acc: 93.06 | test acc: 79.96% | Learning Rate: 1e-05
#
# Epoch: 154
# 0 391 Loss: 0.252 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.644 | Acc: 82.812% (106/128)
# Epoch: 154 | Time Per Epoch: 00:51 | train acc: 93.02 | test acc: 79.92% | Learning Rate: 1e-05
#
# Epoch: 155
# 0 391 Loss: 0.198 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.634 | Acc: 82.812% (106/128)
# Epoch: 155 | Time Per Epoch: 00:52 | train acc: 93.10 | test acc: 79.94% | Learning Rate: 1e-05
#
# Epoch: 156
# 0 391 Loss: 0.166 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.637 | Acc: 83.594% (107/128)
# Epoch: 156 | Time Per Epoch: 00:51 | train acc: 93.16 | test acc: 80.12% | Learning Rate: 1e-05
#
# Epoch: 157
# 0 391 Loss: 0.190 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.636 | Acc: 82.812% (106/128)
# Epoch: 157 | Time Per Epoch: 00:52 | train acc: 93.17 | test acc: 80.07% | Learning Rate: 1e-05
#
# Epoch: 158
# 0 391 Loss: 0.162 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.636 | Acc: 83.594% (107/128)
# Epoch: 158 | Time Per Epoch: 00:51 | train acc: 93.13 | test acc: 79.92% | Learning Rate: 1e-05
#
# Epoch: 159
# 0 391 Loss: 0.259 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.631 | Acc: 83.594% (107/128)
# Epoch: 159 | Time Per Epoch: 00:52 | train acc: 93.23 | test acc: 79.97% | Learning Rate: 1e-05
#
# Epoch: 160
# 0 391 Loss: 0.171 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.630 | Acc: 85.156% (109/128)
# Epoch: 160 | Time Per Epoch: 00:52 | train acc: 93.31 | test acc: 79.93% | Learning Rate: 1e-05
#
# Epoch: 161
# 0 391 Loss: 0.135 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.638 | Acc: 83.594% (107/128)
# Epoch: 161 | Time Per Epoch: 00:52 | train acc: 93.28 | test acc: 80.11% | Learning Rate: 1e-05
#
# Epoch: 162
# 0 391 Loss: 0.258 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.645 | Acc: 84.375% (108/128)
# Epoch: 162 | Time Per Epoch: 00:54 | train acc: 93.29 | test acc: 80.09% | Learning Rate: 1e-05
#
# Epoch: 163
# 0 391 Loss: 0.150 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.638 | Acc: 83.594% (107/128)
# Epoch: 163 | Time Per Epoch: 00:55 | train acc: 93.26 | test acc: 79.94% | Learning Rate: 1e-05
#
# Epoch: 164
# 0 391 Loss: 0.231 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.624 | Acc: 83.594% (107/128)
# Epoch: 164 | Time Per Epoch: 00:54 | train acc: 93.48 | test acc: 80.00% | Learning Rate: 1e-05
#
# Epoch: 165
# 0 391 Loss: 0.187 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.628 | Acc: 85.938% (110/128)
# Epoch: 165 | Time Per Epoch: 00:53 | train acc: 93.51 | test acc: 80.14% | Learning Rate: 1e-05
#
# Epoch: 166
# 0 391 Loss: 0.188 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.625 | Acc: 84.375% (108/128)
# Epoch: 166 | Time Per Epoch: 00:52 | train acc: 93.51 | test acc: 79.91% | Learning Rate: 1e-05
#
# Epoch: 167
# 0 391 Loss: 0.180 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.639 | Acc: 85.156% (109/128)
# Epoch: 167 | Time Per Epoch: 00:52 | train acc: 93.52 | test acc: 79.92% | Learning Rate: 1e-05
#
# Epoch: 168
# 0 391 Loss: 0.224 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.646 | Acc: 85.156% (109/128)
# Epoch: 168 | Time Per Epoch: 00:52 | train acc: 93.43 | test acc: 79.97% | Learning Rate: 1e-05
#
# Epoch: 169
# 0 391 Loss: 0.146 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.634 | Acc: 85.156% (109/128)
# Epoch: 169 | Time Per Epoch: 00:50 | train acc: 93.66 | test acc: 80.02% | Learning Rate: 1e-05
#
# Epoch: 170
# 0 391 Loss: 0.225 | Acc: 90.625% (116/128)
# 0 79 Loss: 0.643 | Acc: 83.594% (107/128)
# Epoch: 170 | Time Per Epoch: 00:50 | train acc: 93.62 | test acc: 79.95% | Learning Rate: 1e-05
#
# Epoch: 171
# 0 391 Loss: 0.231 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.640 | Acc: 84.375% (108/128)
# Epoch: 171 | Time Per Epoch: 00:51 | train acc: 93.74 | test acc: 79.88% | Learning Rate: 1e-05
#
# Epoch: 172
# 0 391 Loss: 0.169 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.636 | Acc: 85.156% (109/128)
# Epoch: 172 | Time Per Epoch: 00:50 | train acc: 93.65 | test acc: 79.90% | Learning Rate: 1e-05
#
# Epoch: 173
# 0 391 Loss: 0.179 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.627 | Acc: 84.375% (108/128)
# Epoch: 173 | Time Per Epoch: 00:51 | train acc: 93.61 | test acc: 79.95% | Learning Rate: 1e-05
#
# Epoch: 174
# 0 391 Loss: 0.231 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.638 | Acc: 85.938% (110/128)
# Epoch: 174 | Time Per Epoch: 00:50 | train acc: 93.80 | test acc: 79.92% | Learning Rate: 1e-05
#
# Epoch: 175
# 0 391 Loss: 0.193 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.644 | Acc: 83.594% (107/128)
# Epoch: 175 | Time Per Epoch: 00:51 | train acc: 93.89 | test acc: 79.81% | Learning Rate: 1e-05
#
# Epoch: 176
# 0 391 Loss: 0.119 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.623 | Acc: 83.594% (107/128)
# Epoch: 176 | Time Per Epoch: 00:50 | train acc: 93.96 | test acc: 79.62% | Learning Rate: 1e-05
#
# Epoch: 177
# 0 391 Loss: 0.292 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.636 | Acc: 83.594% (107/128)
# Epoch: 177 | Time Per Epoch: 00:51 | train acc: 94.04 | test acc: 79.88% | Learning Rate: 1e-05
#
# Epoch: 178
# 0 391 Loss: 0.193 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.640 | Acc: 84.375% (108/128)
# Epoch: 178 | Time Per Epoch: 00:51 | train acc: 94.18 | test acc: 79.55% | Learning Rate: 1e-05
#
# Epoch: 179
# 0 391 Loss: 0.153 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.651 | Acc: 83.594% (107/128)
# Epoch: 179 | Time Per Epoch: 00:51 | train acc: 94.23 | test acc: 79.69% | Learning Rate: 1e-05
#
# Epoch: 180
# 0 391 Loss: 0.171 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.646 | Acc: 83.594% (107/128)
# Epoch: 180 | Time Per Epoch: 00:51 | train acc: 94.23 | test acc: 79.79% | Learning Rate: 1e-05
#
# Epoch: 181
# 0 391 Loss: 0.134 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.639 | Acc: 84.375% (108/128)
# Epoch: 181 | Time Per Epoch: 00:51 | train acc: 94.10 | test acc: 79.95% | Learning Rate: 1e-05
#
# Epoch: 182
# 0 391 Loss: 0.128 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.647 | Acc: 83.594% (107/128)
# Epoch: 182 | Time Per Epoch: 00:51 | train acc: 94.33 | test acc: 79.76% | Learning Rate: 1e-05
#
# Epoch: 183
# 0 391 Loss: 0.178 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.646 | Acc: 84.375% (108/128)
# Epoch: 183 | Time Per Epoch: 00:50 | train acc: 94.34 | test acc: 79.64% | Learning Rate: 1e-05
#
# Epoch: 184
# 0 391 Loss: 0.137 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.646 | Acc: 84.375% (108/128)
# Epoch: 184 | Time Per Epoch: 00:50 | train acc: 94.45 | test acc: 79.51% | Learning Rate: 1e-05
#
# Epoch: 185
# 0 391 Loss: 0.170 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.643 | Acc: 83.594% (107/128)
# Epoch: 185 | Time Per Epoch: 00:50 | train acc: 94.37 | test acc: 79.78% | Learning Rate: 1e-05
#
# Epoch: 186
# 0 391 Loss: 0.172 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.646 | Acc: 83.594% (107/128)
# Epoch: 186 | Time Per Epoch: 00:50 | train acc: 94.39 | test acc: 79.70% | Learning Rate: 1e-05
#
# Epoch: 187
# 0 391 Loss: 0.205 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.651 | Acc: 84.375% (108/128)
# Epoch: 187 | Time Per Epoch: 00:50 | train acc: 94.47 | test acc: 79.55% | Learning Rate: 1e-05
#
# Epoch: 188
# 0 391 Loss: 0.237 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.655 | Acc: 85.156% (109/128)
# Epoch: 188 | Time Per Epoch: 00:50 | train acc: 94.56 | test acc: 79.60% | Learning Rate: 1e-05
#
# Epoch: 189
# 0 391 Loss: 0.123 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.665 | Acc: 83.594% (107/128)
# Epoch: 189 | Time Per Epoch: 00:51 | train acc: 94.47 | test acc: 79.71% | Learning Rate: 1e-05
#
# Epoch: 190
# 0 391 Loss: 0.144 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.640 | Acc: 85.156% (109/128)
# Epoch: 190 | Time Per Epoch: 00:50 | train acc: 94.60 | test acc: 79.50% | Learning Rate: 1e-05
#
# Epoch: 191
# 0 391 Loss: 0.195 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.654 | Acc: 84.375% (108/128)
# Epoch: 191 | Time Per Epoch: 00:51 | train acc: 94.83 | test acc: 79.51% | Learning Rate: 1e-05
#
# Epoch: 192
# 0 391 Loss: 0.150 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.656 | Acc: 83.594% (107/128)
# Epoch: 192 | Time Per Epoch: 00:50 | train acc: 94.74 | test acc: 79.65% | Learning Rate: 1e-05
#
# Epoch: 193
# 0 391 Loss: 0.122 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.653 | Acc: 84.375% (108/128)
# Epoch: 193 | Time Per Epoch: 00:50 | train acc: 94.75 | test acc: 79.50% | Learning Rate: 1e-05
#
# Epoch: 194
# 0 391 Loss: 0.175 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.654 | Acc: 84.375% (108/128)
# Epoch: 194 | Time Per Epoch: 00:51 | train acc: 94.89 | test acc: 79.42% | Learning Rate: 1e-05
#
# Epoch: 195
# 0 391 Loss: 0.177 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.653 | Acc: 83.594% (107/128)
# Epoch: 195 | Time Per Epoch: 00:50 | train acc: 94.70 | test acc: 79.46% | Learning Rate: 1e-05
#
# Epoch: 196
# 0 391 Loss: 0.138 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.644 | Acc: 85.156% (109/128)
# Epoch: 196 | Time Per Epoch: 00:51 | train acc: 94.76 | test acc: 79.52% | Learning Rate: 1e-05
#
# Epoch: 197
# 0 391 Loss: 0.233 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.659 | Acc: 84.375% (108/128)
# Epoch: 197 | Time Per Epoch: 00:51 | train acc: 94.98 | test acc: 79.19% | Learning Rate: 1e-05
#
# Epoch: 198
# 0 391 Loss: 0.126 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.646 | Acc: 84.375% (108/128)
# Epoch: 198 | Time Per Epoch: 00:50 | train acc: 94.92 | test acc: 79.40% | Learning Rate: 1e-05
#
# Epoch: 199
# 0 391 Loss: 0.123 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.659 | Acc: 83.594% (107/128)
# Epoch: 199 | Time Per Epoch: 00:51 | train acc: 95.11 | test acc: 79.69% | Learning Rate: 1e-05
#
# Epoch: 200
# 0 391 Loss: 0.212 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.665 | Acc: 84.375% (108/128)
# Epoch: 200 | Time Per Epoch: 00:50 | train acc: 95.14 | test acc: 79.55% | Learning Rate: 1e-05

# %%
# plot results
results = pd.read_csv(logname, sep=',')
results.head()
# Out:
#    epoch  train loss  train acc  test loss   test acc
# 0      1    1.881501  31.571999   1.657887  39.989998
# 1      1    1.798483  34.528000   1.603057  43.470001
# 2      2    1.368223  49.910000   1.729005  42.320000
# 3      3    1.179499  57.182003   1.372356  52.389996
# 4      4    1.071950  61.448002   1.246852  56.139999

# %%
train_accuracy = results['train acc'].values
test_accuracy = results['test acc'].values

print(f"Average test Accuracy over {end_apochs} epochs: {sum(test_accuracy)//len(test_accuracy)}")
print(f"best test accuraccy over {end_apochs} epochs: {max(test_accuracy)}")
# Out:
# Average test Accuracy over 200 epochs: 68.0
# best test accuraccy over 200 epochs: 80.80999755859375

# %%
plt.figure(figsize=(9, 6))
plt.plot(sorted(results['epoch'].values), train_accuracy, label='train')
plt.plot(sorted(results['epoch'].values), test_accuracy, label='test')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.title(f'Train/Test Accuracy curve for {end_apochs} epochs')
plt.legend()
plt.show()
