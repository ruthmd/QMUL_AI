# %%
# imports
import os
import time
import csv
import multiprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms

# %%
# @title Set random seed

# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# for DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.
import random
import torch

def set_seed(seed=None, seed_torch=True):
  if seed is None:
    seed = np.random.choice(2 ** 32)
  random.seed(seed)
  np.random.seed(seed)
  if seed_torch:
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True

  print(f'Random seed {seed} has been set.')

# In case that `DataLoader` is used
def seed_worker(worker_id):
  worker_seed = torch.initial_seed() % 2**32
  np.random.seed(worker_seed)
  random.seed(worker_seed)

# %%
# @title Set device (GPU or CPU)

# inform the user if the notebook uses GPU or CPU.

def set_device():
  device = "cuda" if torch.cuda.is_available() else "cpu"
  if device != "cuda":
    print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
  else:
    print("GPU is enabled in this notebook.")

  return device

# %%
set_seed(seed=2021)
set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.
# 'cuda'

# %%
# hyper-parameters
use_cuda = torch.cuda.is_available()
alpha = 1  # alpha for mixup augmentation
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
batch_size = 128
end_apochs = 200  # Please change this to 200
base_learning_rate = 0.001
cutout = True  # True/False if you want to use cutout augmentation
mixup = False  # True/False if you want to use mixup augmentation
n_holes = 16  # number of holes to cut out from image for cutout
length = 2  # length of the holes for cutout augmentation
torchvision_transforms = False  # True/False if you want use torchvision augmentations

# %%
# @markdown `Cutout` Augmentation class

class Cutout(object):
    """
    code from: https://github.com/uoguelph-mlrg/Cutout
    
    Randomly mask out one or more patches from an image.
    Args:
      n_holes (int): Number of patches to cut out of each image.
      length (int): The length (in pixels) of each square patch.
    """
    def __init__(self, n_holes, length):
        self.n_holes = n_holes
        self.length = length
    
    def __call__(self, img):
        """
        Args:
            img (Tensor): Tensor image of size (C, H, W).
        Returns:
            Tensor: Image with n_holes of dimension length x length cut out of it.
        """
        h = img.size(1)
        w = img.size(2)
        
        mask = np.ones((h, w), np.float32)
    
        for n in range(self.n_holes):
            y = np.random.randint(h)
            x = np.random.randint(w)
            
            y1 = np.clip(y - self.length // 2, 0, h)
            y2 = np.clip(y + self.length // 2, 0, h)
            x1 = np.clip(x - self.length // 2, 0, w)
            x2 = np.clip(x + self.length // 2, 0, w)
            
            mask[y1: y2, x1: x2] = 0.
        
        mask = torch.from_numpy(mask)
        mask = mask.expand_as(img)
        img = img * mask
    
        return img

# %%
# @markdown `mixup_data` Augmentation function

def mixup_data(x, y, alpha=1.0, use_cuda=True):
    '''Compute the mixup data. Return mixed inputs, pairs of targets, and lambda
      - https://github.com/hongyi-zhang/mixup
    '''
    if alpha > 0.:
        lam = np.random.beta(alpha, alpha)
    else:
        lam = 1.
    batch_size = x.size()[0]
    
    if use_cuda:
        index = torch.randperm(batch_size).cuda()
    else:
        index = torch.randperm(batch_size)
    
    mixed_x = lam * x + (1 - lam) * x[index, :]
    y_a, y_b = y, y[index]
    
    return mixed_x, y_a, y_b, lam

# %%
# @markdown Download and prepare Data
print('==> Preparing data...')
def percentageSplit(full_dataset, percent=0.0):
    set1_size = int(percent * len(full_dataset))
    set2_size = len(full_dataset) - set1_size
    final_dataset, _ = torch.utils.data.random_split(full_dataset, [set1_size, set2_size])
    return final_dataset

# CIFAR100 normalizing
# mean = [0.5071, 0.4866, 0.4409]
# std = [0.2673, 0.2564, 0.2762]

# CIFAR10 normalizing
mean = (0.4914, 0.4822, 0.4465)
std = (0.2023, 0.1994, 0.2010)

# torchvision transforms
transform_train = transforms.Compose([])
if torchvision_transforms:
    transform_train.transforms.append(transforms.RandomCrop(32, padding=4))
    transform_train.transforms.append(transforms.RandomHorizontalFlip())

transform_train.transforms.append(transforms.ToTensor())
transform_train.transforms.append(transforms.Normalize(mean, std))

if cutout:
    transform_train.transforms.append(Cutout(n_holes=n_holes, length=length))

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

trainset = torchvision.datasets.CIFAR10(
    root='./data', train=True, download=True,
    transform=transform_train)

testset = torchvision.datasets.CIFAR10(
    root='./data', train=False, download=True,
    transform=transform_test)
# Out:
# ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Object type: {type(trainset)}")
print(f"Training data shape: {trainset.data.shape}")
print(f"Test data shape: {testset.data.shape}")
print(f"Number of classes: {np.unique(trainset.targets).shape[0]}")
# Out:
# Object type: <class 'torchvision.datasets.cifar.CIFAR10'>
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)
# Number of classes: 10

# %%
# choose percentage from the trainset. set percent = 1.0 to use the whole train data
percent = 1.0
trainset = percentageSplit(trainset, percent = percent)
print(f"size of the new trainset: {len(trainset)}")
# Out:
# size of the new trainset: 50000

# %%
# Dataloader
num_workers = multiprocessing.cpu_count()

print(f'----> number of workers: {num_workers}')

trainloader = torch.utils.data.DataLoader(
    trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(
    testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ----> number of workers: 96

# %%
# get batch of data
batch_X, batch_Y =  next(iter(trainloader))

# %%
def plot_mixed_images(images):
    inv_normalize = transforms.Normalize(
                      mean= [-m/s for m, s in zip(mean, std)],
                      std= [1/s for s in std]
                    )
    inv_PIL = transforms.ToPILImage()
    fig = plt.figure(figsize=(10, 8))
    
    for i in range(1, len(images) + 1):
        image = images[i-1]
        ax = fig.add_subplot(1, 4, i)
        inv_tensor = inv_normalize(image).cpu()
        ax.imshow(inv_PIL(inv_tensor))
        
    plt.show()

# %%
# Mixup Visualization
if mixup:
  alpha = 0.9
  mixed_x, y_a, y_b, lam = mixup_data(batch_X.cuda(), batch_Y.cuda(), alpha=alpha, use_cuda=use_cuda)
  plot_mixed_images(mixed_x[:4])

# %%
# Mixup Visualization
if cutout:
  plot_mixed_images(batch_X[:4])

# %%
# @markdown ResNet model in PyTorch

class Bottleneck(nn.Module):
    """
    For deep networks, we use BottleNeck, which is proposed in the paper to have approximate computational complexity but save a lot of resources
    zip_channels: The compressed dimension, the final output dimension is expansion * zip_channels
    For the network structure of ResNet50/101/152, mainly because the third layer is 4 times the second layer, so expansion=4
    """
    expansion = 4

    def __init__(self, in_channels, zip_channels, stride=1):
        super(Bottleneck, self).__init__()
        out_channels = self.expansion * zip_channels
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, zip_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, zip_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

class BasicBlock(nn.Module):
    """
    For shallow networks, such as ResNet-18/34, etc., use the basic Block
    The base module is not compressed, so expansion=1
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock,self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True),
            nn.Conv2d(out_channels,out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        # If the input and output dimensions are not equal, use a 1x1 convolutional layer to change the dimension
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels),
            )
    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out


class ResNet(nn.Module):
    """
    Different ResNet architectures are unified with one layer of feature extraction and four layers of residuals, and the difference lies in the depth of each layer of residuals.
    For cifar10, the change of feature map size is as follows:
    (32, 32, 3) -> [Conv2d] -> (32, 32, 64) -> [Res1] -> (32, 32, 64) -> [Res2]
 -> (16, 16, 128) -> [Res3] -> (8, 8, 256) ->[Res4] -> (4, 4, 512) -> [AvgPool]
 -> (1, 1, 512) -> [Reshape] -> (512) -> [Linear] -> (10)
    """
    def __init__(self, block, num_blocks, num_classes=10, verbose = False):
        super(ResNet, self).__init__()
        self.verbose = verbose
        self.in_channels = 64
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        #Use the _make_layer function to generate the structure of conv2_x, conv3_x, conv4_x, conv5_x corresponding to the above table
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        # After cifar10 goes through the above structure, the feature map size here is 4 x 4 x 512 x expansion
        # So 4 x 4 average pooling is used here
        self.avg_pool = nn.AvgPool2d(kernel_size=4)
        self.classifer = nn.Linear(512 *block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # The first block needs to be downsampled
        strides = [stride] + [1]* (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            # If it is Bottleneck Block, you need to compress the input dimension of each layer, and then increase the dimension after compression
            # So the input dimension of each layer should also change accordingly
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.features(x)
        if self.verbose:
            print('block 1 output: {}'.format(out.shape))
        out = self.layer1(out)
        if self.verbose:
            print('block 2 output: {}'.format(out.shape))
        out = self.layer2(out)
        if self.verbose:
            print('block 3 output: {}'.format(out.shape))
        out = self.layer3(out)
        if self.verbose:
            print('block 4 output: {}'.format(out.shape))
        out = self.layer4(out)
        if self.verbose:
            print('block 5 output: {}'.format(out.shape))
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.classifer(out)
        return out


def ResNet18(verbose=False):
    return ResNet(BasicBlock, [2,2,2,2],verbose=verbose)

def ResNet34(verbose=False):
    return ResNet(BasicBlock, [3,4,6,3],verbose=verbose)

def ResNet50(verbose=False):
    return ResNet(Bottleneck, [3,4,6,3],verbose=verbose)

def ResNet101(verbose=False):
    return ResNet(Bottleneck, [3,4,23,3],verbose=verbose)

def ResNet152(verbose=False):
    return ResNet(Bottleneck, [3,8,36,3],verbose=verbose)

# %%
# load the Model
net = ResNet18()
print('-----> verify if model is run on random data')
y = net(Variable(torch.randn(1,3,32,32)))
print('model loaded')

result_folder = './results/'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

proc = "{}{}".format("cutout" if cutout else "", "mixup" if mixup else "") 

logname = result_folder + net.__class__.__name__ + '_' +proc+ 's_16.csv'

if use_cuda:
  net.cuda()
  net = torch.nn.DataParallel(net)
  print('Using', torch.cuda.device_count(), 'GPUs.')
  cudnn.benchmark = True
  print('Using CUDA..')
# Out:
# -----> verify if model is run on random data
# model loaded
# Using 1 GPUs.
# Using CUDA..

# %%
# optimizer and criterion

def mixup_criterion(y_a, y_b, lam):
  '''
    - Mixup criterion
    - https://github.com/hongyi-zhang/mixup
  '''
  return lambda criterion, pred: lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(net.parameters(), lr=base_learning_rate, weight_decay=5e-4)
# scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=10, min_lr=1e-5)

# %%
# Training & Test functions
def train(epoch, alpha, use_cuda=False):
    print('\nEpoch: %d' % epoch)
    
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(trainloader):

        if use_cuda:
            inputs, targets = inputs.cuda(), targets.cuda()

        optimizer.zero_grad()
        if mixup:
        # generate mixed inputs, two one-hot label vectors and mixing coefficient
            inputs, targets_a, targets_b, lam = mixup_data(inputs, targets, alpha, use_cuda)
            inputs, targets_a, targets_b = Variable(inputs), Variable(targets_a), Variable(targets_b)
            outputs = net(inputs)
            loss_func = mixup_criterion(targets_a, targets_b, lam)
            loss = loss_func(criterion, outputs)
        else:
            inputs, targets = Variable(inputs), Variable(targets)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += targets.size(0)

        if mixup:
            correct += lam * predicted.eq(targets_a.data).cpu().sum() + (1 - lam) * predicted.eq(targets_b.data).cpu().sum()
            # correct += lam * predicted.eq(targets_a.data).sum() + (1 - lam) * predicted.eq(targets_b.data).sum()
        else:
            correct += predicted.eq(targets.data).cpu().sum()
            # correct += predicted.eq(targets.data).sum()

        acc = 100.*(correct/total)
        
        if batch_idx % 500 == 0:
            print(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)' % (train_loss/(batch_idx+1), acc, correct, total))
        

    return (train_loss/batch_idx, acc)

# %%
def test(epoch, use_cuda=False):
    global best_acc
    net.eval()
    test_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for batch_idx, (inputs, targets) in enumerate(testloader):
            if use_cuda:
                inputs, targets = inputs.cuda(), targets.cuda()
            # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
            outputs = net(inputs)
            loss = criterion(outputs, targets)

            test_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += targets.size(0)
            correct += predicted.eq(targets.data).cpu().sum()
            # correct += predicted.eq(targets.data).sum()
            

            if batch_idx % 200 == 0:
                print(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'% (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

    # Save checkpoint.
    acc = 100.*(correct/total)
    
    if acc > best_acc:
        best_acc = acc
        checkpoint(acc, epoch)
    return (test_loss/batch_idx, acc)

# %%
# @markdown `checkpoint` and `adjust_learning_rate` functions
def checkpoint(acc, epoch):
  # Save checkpoint.
  print('Saving..')
  state = {
      'net': net.state_dict(),
      'acc': acc,
      'epoch': epoch,
      'rng_state': torch.get_rng_state()
      }
  if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')
  torch.save(state, './checkpoint/ckpt.t7')


def adjust_learning_rate(optimizer, epoch):
  """decrease the learning rate at 100 and 150 epoch"""
  lr = base_learning_rate
  if epoch <= 9 and lr > 0.1:
    # warm-up training for large minibatch
    lr = 0.1 + (base_learning_rate - 0.1) * epoch / 10.
  if epoch >= 100:
    lr /= 10
  if epoch >= 150:
    lr /= 10
  for param_group in optimizer.param_groups:
    param_group['lr'] = lr

# %%
# start training
if not os.path.exists(logname):
  with open(logname, 'w') as logfile:
    logwriter = csv.writer(logfile, delimiter=',')
    logwriter.writerow(['epoch', 'train loss', 'train acc',
                        'test loss', 'test acc'])

for epoch in range(start_epoch+1, end_apochs+1):
#   adjust_learning_rate(optimizer, epoch)
    start = time.time()

    train_loss, train_acc = train(epoch, alpha, use_cuda=use_cuda)
    test_loss, test_acc = test(epoch, use_cuda=use_cuda)

    # scheduler.step(test_loss)

    end = time.time()

    time_ = int(end - start)
    h = time_ / 3600
    m = time_ % 3600 /60
    s = time_ % 60
    time_str = "%02d:%02d" % ( m, s)


    with open(logname, 'a') as logfile:
        logwriter = csv.writer(logfile, delimiter=',')
        logwriter.writerow([epoch, train_loss, train_acc.item(),test_loss, test_acc.item()])
        
    print(f"Epoch: {epoch} | Time Per Epoch: {time_str} | train acc: {train_acc:.2f} | test acc: {test_acc:.2f}% | Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# 0 391 Loss: 2.434 | Acc: 8.594% (11/128)
# 0 79 Loss: 1.343 | Acc: 51.562% (66/128)
# Saving..
# Epoch: 1 | Time Per Epoch: 01:32 | train acc: 47.70 | test acc: 50.44% | Learning Rate: 0.001
#
# Epoch: 2
# 0 391 Loss: 1.094 | Acc: 59.375% (76/128)
# 0 79 Loss: 0.883 | Acc: 72.656% (93/128)
# Saving..
# Epoch: 2 | Time Per Epoch: 01:28 | train acc: 63.65 | test acc: 65.99% | Learning Rate: 0.001
#
# Epoch: 3
# 0 391 Loss: 0.854 | Acc: 69.531% (89/128)
# 0 79 Loss: 1.006 | Acc: 64.844% (83/128)
# Epoch: 3 | Time Per Epoch: 01:28 | train acc: 71.02 | test acc: 63.82% | Learning Rate: 0.001
#
# Epoch: 4
# 0 391 Loss: 0.629 | Acc: 77.344% (99/128)
# 0 79 Loss: 0.923 | Acc: 69.531% (89/128)
# Epoch: 4 | Time Per Epoch: 01:28 | train acc: 75.52 | test acc: 65.99% | Learning Rate: 0.001
#
# Epoch: 5
# 0 391 Loss: 0.554 | Acc: 82.031% (105/128)
# 0 79 Loss: 0.653 | Acc: 78.906% (101/128)
# Saving..
# Epoch: 5 | Time Per Epoch: 01:28 | train acc: 78.46 | test acc: 75.55% | Learning Rate: 0.001
#
# Epoch: 6
# 0 391 Loss: 0.534 | Acc: 82.812% (106/128)
# 0 79 Loss: 0.638 | Acc: 78.906% (101/128)
# Saving..
# Epoch: 6 | Time Per Epoch: 01:31 | train acc: 80.96 | test acc: 77.32% | Learning Rate: 0.001
#
# Epoch: 7
# 0 391 Loss: 0.449 | Acc: 83.594% (107/128)
# 0 79 Loss: 0.562 | Acc: 83.594% (107/128)
# Saving..
# Epoch: 7 | Time Per Epoch: 01:31 | train acc: 82.57 | test acc: 80.13% | Learning Rate: 0.001
#
# Epoch: 8
# 0 391 Loss: 0.470 | Acc: 84.375% (108/128)
# 0 79 Loss: 0.534 | Acc: 85.156% (109/128)
# Epoch: 8 | Time Per Epoch: 01:28 | train acc: 84.15 | test acc: 80.09% | Learning Rate: 0.001
#
# Epoch: 9
# 0 391 Loss: 0.300 | Acc: 88.281% (113/128)
# 0 79 Loss: 0.482 | Acc: 82.812% (106/128)
# Saving..
# Epoch: 9 | Time Per Epoch: 01:30 | train acc: 85.43 | test acc: 82.39% | Learning Rate: 0.001
#
# Epoch: 10
# 0 391 Loss: 0.432 | Acc: 85.156% (109/128)
# 0 79 Loss: 0.484 | Acc: 82.031% (105/128)
# Epoch: 10 | Time Per Epoch: 01:27 | train acc: 86.76 | test acc: 82.28% | Learning Rate: 0.001
#
# Epoch: 11
# 0 391 Loss: 0.428 | Acc: 86.719% (111/128)
# 0 79 Loss: 0.516 | Acc: 82.812% (106/128)
# Epoch: 11 | Time Per Epoch: 01:30 | train acc: 87.64 | test acc: 81.04% | Learning Rate: 0.001
#
# Epoch: 12
# 0 391 Loss: 0.250 | Acc: 89.844% (115/128)
# 0 79 Loss: 0.481 | Acc: 86.719% (111/128)
# Saving..
# Epoch: 12 | Time Per Epoch: 01:29 | train acc: 88.50 | test acc: 83.24% | Learning Rate: 0.001
#
# Epoch: 13
# 0 391 Loss: 0.147 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.426 | Acc: 83.594% (107/128)
# Epoch: 13 | Time Per Epoch: 01:27 | train acc: 89.37 | test acc: 83.18% | Learning Rate: 0.001
#
# Epoch: 14
# 0 391 Loss: 0.212 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.473 | Acc: 85.938% (110/128)
# Saving..
# Epoch: 14 | Time Per Epoch: 01:25 | train acc: 90.04 | test acc: 83.29% | Learning Rate: 0.001
#
# Epoch: 15
# 0 391 Loss: 0.214 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.329 | Acc: 87.500% (112/128)
# Saving..
# Epoch: 15 | Time Per Epoch: 01:29 | train acc: 90.58 | test acc: 84.63% | Learning Rate: 0.001
#
# Epoch: 16
# 0 391 Loss: 0.170 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.562 | Acc: 82.031% (105/128)
# Epoch: 16 | Time Per Epoch: 01:27 | train acc: 91.22 | test acc: 81.99% | Learning Rate: 0.001
#
# Epoch: 17
# 0 391 Loss: 0.279 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.431 | Acc: 83.594% (107/128)
# Epoch: 17 | Time Per Epoch: 01:28 | train acc: 91.79 | test acc: 82.72% | Learning Rate: 0.001
#
# Epoch: 18
# 0 391 Loss: 0.182 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.447 | Acc: 86.719% (111/128)
# Epoch: 18 | Time Per Epoch: 01:27 | train acc: 92.14 | test acc: 83.68% | Learning Rate: 0.001
#
# Epoch: 19
# 0 391 Loss: 0.142 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.530 | Acc: 84.375% (108/128)
# Epoch: 19 | Time Per Epoch: 01:29 | train acc: 92.48 | test acc: 84.06% | Learning Rate: 0.001
#
# Epoch: 20
# 0 391 Loss: 0.253 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.410 | Acc: 85.938% (110/128)
# Epoch: 20 | Time Per Epoch: 01:29 | train acc: 92.95 | test acc: 84.03% | Learning Rate: 0.001
#
# Epoch: 21
# 0 391 Loss: 0.075 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.457 | Acc: 87.500% (112/128)
# Epoch: 21 | Time Per Epoch: 01:33 | train acc: 93.16 | test acc: 84.01% | Learning Rate: 0.001
#
# Epoch: 22
# 0 391 Loss: 0.180 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.485 | Acc: 82.812% (106/128)
# Epoch: 22 | Time Per Epoch: 01:31 | train acc: 93.35 | test acc: 82.75% | Learning Rate: 0.001
#
# Epoch: 23
# 0 391 Loss: 0.230 | Acc: 91.406% (117/128)
# 0 79 Loss: 0.445 | Acc: 87.500% (112/128)
# Saving..
# Epoch: 23 | Time Per Epoch: 01:32 | train acc: 93.41 | test acc: 84.68% | Learning Rate: 0.001
#
# Epoch: 24
# 0 391 Loss: 0.122 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.341 | Acc: 89.062% (114/128)
# Epoch: 24 | Time Per Epoch: 01:29 | train acc: 94.04 | test acc: 84.31% | Learning Rate: 0.001
#
# Epoch: 25
# 0 391 Loss: 0.155 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.553 | Acc: 82.031% (105/128)
# Epoch: 25 | Time Per Epoch: 01:30 | train acc: 94.11 | test acc: 83.69% | Learning Rate: 0.001
#
# Epoch: 26
# 0 391 Loss: 0.202 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.637 | Acc: 82.031% (105/128)
# Epoch: 26 | Time Per Epoch: 01:30 | train acc: 94.22 | test acc: 81.32% | Learning Rate: 0.001
#
# Epoch: 27
# 0 391 Loss: 0.087 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.477 | Acc: 82.812% (106/128)
# Saving..
# Epoch: 27 | Time Per Epoch: 01:31 | train acc: 94.38 | test acc: 84.71% | Learning Rate: 0.001
#
# Epoch: 28
# 0 391 Loss: 0.160 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.510 | Acc: 85.156% (109/128)
# Epoch: 28 | Time Per Epoch: 01:30 | train acc: 94.60 | test acc: 83.35% | Learning Rate: 0.001
#
# Epoch: 29
# 0 391 Loss: 0.126 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.434 | Acc: 85.938% (110/128)
# Epoch: 29 | Time Per Epoch: 01:29 | train acc: 94.49 | test acc: 83.71% | Learning Rate: 0.001
#
# Epoch: 30
# 0 391 Loss: 0.160 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.615 | Acc: 83.594% (107/128)
# Epoch: 30 | Time Per Epoch: 01:28 | train acc: 94.95 | test acc: 82.88% | Learning Rate: 0.001
#
# Epoch: 31
# 0 391 Loss: 0.121 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.547 | Acc: 83.594% (107/128)
# Epoch: 31 | Time Per Epoch: 01:29 | train acc: 95.01 | test acc: 83.72% | Learning Rate: 0.001
#
# Epoch: 32
# 0 391 Loss: 0.057 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.380 | Acc: 87.500% (112/128)
# Epoch: 32 | Time Per Epoch: 01:35 | train acc: 94.93 | test acc: 83.66% | Learning Rate: 0.001
#
# Epoch: 33
# 0 391 Loss: 0.105 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.523 | Acc: 85.156% (109/128)
# Epoch: 33 | Time Per Epoch: 01:35 | train acc: 95.22 | test acc: 84.06% | Learning Rate: 0.001
#
# Epoch: 34
# 0 391 Loss: 0.065 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.730 | Acc: 83.594% (107/128)
# Epoch: 34 | Time Per Epoch: 01:37 | train acc: 95.02 | test acc: 83.43% | Learning Rate: 0.001
#
# Epoch: 35
# 0 391 Loss: 0.074 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.539 | Acc: 85.156% (109/128)
# Epoch: 35 | Time Per Epoch: 01:39 | train acc: 95.06 | test acc: 84.54% | Learning Rate: 0.001
#
# Epoch: 36
# 0 391 Loss: 0.143 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.566 | Acc: 84.375% (108/128)
# Saving..
# Epoch: 36 | Time Per Epoch: 01:40 | train acc: 95.45 | test acc: 84.89% | Learning Rate: 0.001
#
# Epoch: 37
# 0 391 Loss: 0.126 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.550 | Acc: 82.031% (105/128)
# Epoch: 37 | Time Per Epoch: 01:40 | train acc: 95.29 | test acc: 83.94% | Learning Rate: 0.001
#
# Epoch: 38
# 0 391 Loss: 0.171 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.473 | Acc: 84.375% (108/128)
# Epoch: 38 | Time Per Epoch: 01:40 | train acc: 95.39 | test acc: 83.90% | Learning Rate: 0.001
#
# Epoch: 39
# 0 391 Loss: 0.112 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.522 | Acc: 85.156% (109/128)
# Epoch: 39 | Time Per Epoch: 01:39 | train acc: 95.53 | test acc: 84.48% | Learning Rate: 0.001
#
# Epoch: 40
# 0 391 Loss: 0.039 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.459 | Acc: 86.719% (111/128)
# Epoch: 40 | Time Per Epoch: 01:41 | train acc: 95.62 | test acc: 84.77% | Learning Rate: 0.001
#
# Epoch: 41
# 0 391 Loss: 0.121 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.555 | Acc: 85.938% (110/128)
# Epoch: 41 | Time Per Epoch: 01:38 | train acc: 95.71 | test acc: 84.26% | Learning Rate: 0.001
#
# Epoch: 42
# 0 391 Loss: 0.046 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.568 | Acc: 83.594% (107/128)
# Epoch: 42 | Time Per Epoch: 01:36 | train acc: 95.56 | test acc: 83.06% | Learning Rate: 0.001
#
# Epoch: 43
# 0 391 Loss: 0.102 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.634 | Acc: 80.469% (103/128)
# Epoch: 43 | Time Per Epoch: 01:40 | train acc: 95.45 | test acc: 84.23% | Learning Rate: 0.001
#
# Epoch: 44
# 0 391 Loss: 0.067 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.670 | Acc: 85.156% (109/128)
# Epoch: 44 | Time Per Epoch: 01:37 | train acc: 95.88 | test acc: 83.67% | Learning Rate: 0.001
#
# Epoch: 45
# 0 391 Loss: 0.103 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.516 | Acc: 84.375% (108/128)
# Epoch: 45 | Time Per Epoch: 01:38 | train acc: 95.64 | test acc: 82.67% | Learning Rate: 0.001
#
# Epoch: 46
# 0 391 Loss: 0.101 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.586 | Acc: 82.812% (106/128)
# Epoch: 46 | Time Per Epoch: 01:36 | train acc: 95.66 | test acc: 84.46% | Learning Rate: 0.001
#
# Epoch: 47
# 0 391 Loss: 0.074 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.525 | Acc: 85.938% (110/128)
# Epoch: 47 | Time Per Epoch: 01:38 | train acc: 95.92 | test acc: 82.20% | Learning Rate: 0.001
#
# Epoch: 48
# 0 391 Loss: 0.122 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.604 | Acc: 83.594% (107/128)
# Epoch: 48 | Time Per Epoch: 01:38 | train acc: 96.05 | test acc: 83.85% | Learning Rate: 0.001
#
# Epoch: 49
# 0 391 Loss: 0.065 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.543 | Acc: 83.594% (107/128)
# Epoch: 49 | Time Per Epoch: 01:38 | train acc: 95.92 | test acc: 83.85% | Learning Rate: 0.001
#
# Epoch: 50
# 0 391 Loss: 0.179 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.508 | Acc: 84.375% (108/128)
# Epoch: 50 | Time Per Epoch: 01:36 | train acc: 95.96 | test acc: 83.97% | Learning Rate: 0.001
#
# Epoch: 51
# 0 391 Loss: 0.099 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.521 | Acc: 86.719% (111/128)
# Epoch: 51 | Time Per Epoch: 01:38 | train acc: 95.93 | test acc: 84.20% | Learning Rate: 0.001
#
# Epoch: 52
# 0 391 Loss: 0.047 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.564 | Acc: 85.938% (110/128)
# Saving..
# Epoch: 52 | Time Per Epoch: 01:35 | train acc: 95.92 | test acc: 85.16% | Learning Rate: 0.001
#
# Epoch: 53
# 0 391 Loss: 0.101 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.516 | Acc: 82.031% (105/128)
# Epoch: 53 | Time Per Epoch: 01:30 | train acc: 96.05 | test acc: 83.24% | Learning Rate: 0.001
#
# Epoch: 54
# 0 391 Loss: 0.110 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.564 | Acc: 80.469% (103/128)
# Epoch: 54 | Time Per Epoch: 01:33 | train acc: 95.88 | test acc: 84.65% | Learning Rate: 0.001
#
# Epoch: 55
# 0 391 Loss: 0.082 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.535 | Acc: 85.156% (109/128)
# Epoch: 55 | Time Per Epoch: 01:07 | train acc: 96.00 | test acc: 84.14% | Learning Rate: 0.001
#
# Epoch: 56
# 0 391 Loss: 0.076 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.449 | Acc: 87.500% (112/128)
# Epoch: 56 | Time Per Epoch: 00:54 | train acc: 96.15 | test acc: 83.41% | Learning Rate: 0.001
#
# Epoch: 57
# 0 391 Loss: 0.057 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.616 | Acc: 80.469% (103/128)
# Epoch: 57 | Time Per Epoch: 00:56 | train acc: 96.20 | test acc: 82.98% | Learning Rate: 0.001
#
# Epoch: 58
# 0 391 Loss: 0.064 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.695 | Acc: 82.031% (105/128)
# Epoch: 58 | Time Per Epoch: 00:54 | train acc: 96.26 | test acc: 83.35% | Learning Rate: 0.001
#
# Epoch: 59
# 0 391 Loss: 0.048 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.558 | Acc: 81.250% (104/128)
# Epoch: 59 | Time Per Epoch: 00:55 | train acc: 96.18 | test acc: 83.50% | Learning Rate: 0.001
#
# Epoch: 60
# 0 391 Loss: 0.190 | Acc: 92.188% (118/128)
# 0 79 Loss: 0.617 | Acc: 80.469% (103/128)
# Epoch: 60 | Time Per Epoch: 00:54 | train acc: 96.29 | test acc: 83.88% | Learning Rate: 0.001
#
# Epoch: 61
# 0 391 Loss: 0.041 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.492 | Acc: 84.375% (108/128)
# Epoch: 61 | Time Per Epoch: 00:56 | train acc: 96.27 | test acc: 84.07% | Learning Rate: 0.001
#
# Epoch: 62
# 0 391 Loss: 0.095 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.343 | Acc: 89.844% (115/128)
# Epoch: 62 | Time Per Epoch: 00:56 | train acc: 96.01 | test acc: 83.89% | Learning Rate: 0.001
#
# Epoch: 63
# 0 391 Loss: 0.168 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.504 | Acc: 84.375% (108/128)
# Epoch: 63 | Time Per Epoch: 00:56 | train acc: 96.35 | test acc: 82.69% | Learning Rate: 0.001
#
# Epoch: 64
# 0 391 Loss: 0.121 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.436 | Acc: 85.938% (110/128)
# Epoch: 64 | Time Per Epoch: 00:54 | train acc: 96.10 | test acc: 83.55% | Learning Rate: 0.001
#
# Epoch: 65
# 0 391 Loss: 0.151 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.652 | Acc: 80.469% (103/128)
# Epoch: 65 | Time Per Epoch: 00:55 | train acc: 96.11 | test acc: 83.58% | Learning Rate: 0.001
#
# Epoch: 66
# 0 391 Loss: 0.160 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.636 | Acc: 82.031% (105/128)
# Epoch: 66 | Time Per Epoch: 00:54 | train acc: 96.60 | test acc: 82.44% | Learning Rate: 0.001
#
# Epoch: 67
# 0 391 Loss: 0.140 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.681 | Acc: 83.594% (107/128)
# Epoch: 67 | Time Per Epoch: 00:55 | train acc: 96.16 | test acc: 82.71% | Learning Rate: 0.001
#
# Epoch: 68
# 0 391 Loss: 0.031 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.740 | Acc: 84.375% (108/128)
# Epoch: 68 | Time Per Epoch: 00:54 | train acc: 96.41 | test acc: 82.66% | Learning Rate: 0.001
#
# Epoch: 69
# 0 391 Loss: 0.127 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.535 | Acc: 83.594% (107/128)
# Epoch: 69 | Time Per Epoch: 00:54 | train acc: 96.47 | test acc: 83.94% | Learning Rate: 0.001
#
# Epoch: 70
# 0 391 Loss: 0.104 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.511 | Acc: 82.031% (105/128)
# Epoch: 70 | Time Per Epoch: 00:55 | train acc: 96.26 | test acc: 84.96% | Learning Rate: 0.001
#
# Epoch: 71
# 0 391 Loss: 0.100 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.429 | Acc: 88.281% (113/128)
# Epoch: 71 | Time Per Epoch: 00:51 | train acc: 96.22 | test acc: 84.62% | Learning Rate: 0.001
#
# Epoch: 72
# 0 391 Loss: 0.088 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.512 | Acc: 86.719% (111/128)
# Epoch: 72 | Time Per Epoch: 00:50 | train acc: 96.36 | test acc: 84.48% | Learning Rate: 0.001
#
# Epoch: 73
# 0 391 Loss: 0.039 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.542 | Acc: 86.719% (111/128)
# Epoch: 73 | Time Per Epoch: 00:50 | train acc: 96.44 | test acc: 83.85% | Learning Rate: 0.001
#
# Epoch: 74
# 0 391 Loss: 0.095 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.631 | Acc: 86.719% (111/128)
# Epoch: 74 | Time Per Epoch: 00:51 | train acc: 96.53 | test acc: 83.80% | Learning Rate: 0.001
#
# Epoch: 75
# 0 391 Loss: 0.084 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.404 | Acc: 86.719% (111/128)
# Epoch: 75 | Time Per Epoch: 00:50 | train acc: 96.49 | test acc: 82.21% | Learning Rate: 0.001
#
# Epoch: 76
# 0 391 Loss: 0.113 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.573 | Acc: 86.719% (111/128)
# Epoch: 76 | Time Per Epoch: 00:53 | train acc: 96.42 | test acc: 84.32% | Learning Rate: 0.001
#
# Epoch: 77
# 0 391 Loss: 0.061 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.641 | Acc: 83.594% (107/128)
# Epoch: 77 | Time Per Epoch: 00:51 | train acc: 96.26 | test acc: 83.91% | Learning Rate: 0.001
#
# Epoch: 78
# 0 391 Loss: 0.104 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.625 | Acc: 84.375% (108/128)
# Epoch: 78 | Time Per Epoch: 00:52 | train acc: 96.41 | test acc: 82.50% | Learning Rate: 0.001
#
# Epoch: 79
# 0 391 Loss: 0.102 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.503 | Acc: 84.375% (108/128)
# Epoch: 79 | Time Per Epoch: 00:50 | train acc: 96.32 | test acc: 84.18% | Learning Rate: 0.001
#
# Epoch: 80
# 0 391 Loss: 0.098 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.625 | Acc: 86.719% (111/128)
# Epoch: 80 | Time Per Epoch: 00:52 | train acc: 96.68 | test acc: 84.31% | Learning Rate: 0.001
#
# Epoch: 81
# 0 391 Loss: 0.066 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.766 | Acc: 82.031% (105/128)
# Epoch: 81 | Time Per Epoch: 00:51 | train acc: 96.40 | test acc: 84.16% | Learning Rate: 0.001
#
# Epoch: 82
# 0 391 Loss: 0.100 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.635 | Acc: 82.812% (106/128)
# Epoch: 82 | Time Per Epoch: 00:54 | train acc: 96.56 | test acc: 84.12% | Learning Rate: 0.001
#
# Epoch: 83
# 0 391 Loss: 0.135 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.578 | Acc: 85.156% (109/128)
# Epoch: 83 | Time Per Epoch: 00:53 | train acc: 96.41 | test acc: 83.55% | Learning Rate: 0.001
#
# Epoch: 84
# 0 391 Loss: 0.068 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.623 | Acc: 81.250% (104/128)
# Epoch: 84 | Time Per Epoch: 00:56 | train acc: 96.72 | test acc: 84.46% | Learning Rate: 0.001
#
# Epoch: 85
# 0 391 Loss: 0.048 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.636 | Acc: 85.156% (109/128)
# Epoch: 85 | Time Per Epoch: 00:53 | train acc: 96.49 | test acc: 83.54% | Learning Rate: 0.001
#
# Epoch: 86
# 0 391 Loss: 0.157 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.474 | Acc: 86.719% (111/128)
# Epoch: 86 | Time Per Epoch: 00:55 | train acc: 96.37 | test acc: 83.72% | Learning Rate: 0.001
#
# Epoch: 87
# 0 391 Loss: 0.093 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.653 | Acc: 83.594% (107/128)
# Epoch: 87 | Time Per Epoch: 00:56 | train acc: 96.66 | test acc: 83.28% | Learning Rate: 0.001
#
# Epoch: 88
# 0 391 Loss: 0.120 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.387 | Acc: 85.938% (110/128)
# Epoch: 88 | Time Per Epoch: 00:57 | train acc: 96.66 | test acc: 84.53% | Learning Rate: 0.001
#
# Epoch: 89
# 0 391 Loss: 0.100 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.464 | Acc: 85.156% (109/128)
# Epoch: 89 | Time Per Epoch: 00:56 | train acc: 96.51 | test acc: 84.43% | Learning Rate: 0.001
#
# Epoch: 90
# 0 391 Loss: 0.102 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.528 | Acc: 84.375% (108/128)
# Epoch: 90 | Time Per Epoch: 00:57 | train acc: 96.30 | test acc: 83.69% | Learning Rate: 0.001
#
# Epoch: 91
# 0 391 Loss: 0.105 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.643 | Acc: 85.156% (109/128)
# Epoch: 91 | Time Per Epoch: 00:45 | train acc: 96.61 | test acc: 84.98% | Learning Rate: 0.001
#
# Epoch: 92
# 0 391 Loss: 0.040 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.488 | Acc: 86.719% (111/128)
# Epoch: 92 | Time Per Epoch: 00:33 | train acc: 96.63 | test acc: 84.53% | Learning Rate: 0.001
#
# Epoch: 93
# 0 391 Loss: 0.057 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.628 | Acc: 83.594% (107/128)
# Epoch: 93 | Time Per Epoch: 00:34 | train acc: 96.53 | test acc: 84.32% | Learning Rate: 0.001
#
# Epoch: 94
# 0 391 Loss: 0.050 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.483 | Acc: 84.375% (108/128)
# Epoch: 94 | Time Per Epoch: 00:33 | train acc: 96.59 | test acc: 84.06% | Learning Rate: 0.001
#
# Epoch: 95
# 0 391 Loss: 0.057 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.674 | Acc: 81.250% (104/128)
# Epoch: 95 | Time Per Epoch: 00:32 | train acc: 96.77 | test acc: 84.47% | Learning Rate: 0.001
#
# Epoch: 96
# 0 391 Loss: 0.114 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.860 | Acc: 80.469% (103/128)
# Epoch: 96 | Time Per Epoch: 00:34 | train acc: 96.55 | test acc: 83.56% | Learning Rate: 0.001
#
# Epoch: 97
# 0 391 Loss: 0.055 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.725 | Acc: 82.031% (105/128)
# Epoch: 97 | Time Per Epoch: 00:34 | train acc: 96.72 | test acc: 83.74% | Learning Rate: 0.001
#
# Epoch: 98
# 0 391 Loss: 0.079 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.479 | Acc: 85.156% (109/128)
# Epoch: 98 | Time Per Epoch: 00:34 | train acc: 96.51 | test acc: 84.74% | Learning Rate: 0.001
#
# Epoch: 99
# 0 391 Loss: 0.119 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.664 | Acc: 80.469% (103/128)
# Epoch: 99 | Time Per Epoch: 00:36 | train acc: 96.82 | test acc: 84.58% | Learning Rate: 0.001
#
# Epoch: 100
# 0 391 Loss: 0.049 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.672 | Acc: 84.375% (108/128)
# Epoch: 100 | Time Per Epoch: 00:36 | train acc: 96.57 | test acc: 83.66% | Learning Rate: 0.001
#
# Epoch: 101
# 0 391 Loss: 0.055 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.654 | Acc: 85.938% (110/128)
# Epoch: 101 | Time Per Epoch: 00:36 | train acc: 96.55 | test acc: 82.18% | Learning Rate: 0.001
#
# Epoch: 102
# 0 391 Loss: 0.108 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.542 | Acc: 85.156% (109/128)
# Epoch: 102 | Time Per Epoch: 00:35 | train acc: 96.67 | test acc: 83.74% | Learning Rate: 0.001
#
# Epoch: 103
# 0 391 Loss: 0.131 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.555 | Acc: 85.938% (110/128)
# Epoch: 103 | Time Per Epoch: 00:35 | train acc: 96.66 | test acc: 84.47% | Learning Rate: 0.001
#
# Epoch: 104
# 0 391 Loss: 0.035 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.647 | Acc: 82.031% (105/128)
# Epoch: 104 | Time Per Epoch: 00:36 | train acc: 96.64 | test acc: 84.86% | Learning Rate: 0.001
#
# Epoch: 105
# 0 391 Loss: 0.076 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.598 | Acc: 82.812% (106/128)
# Epoch: 105 | Time Per Epoch: 00:35 | train acc: 96.84 | test acc: 83.60% | Learning Rate: 0.001
#
# Epoch: 106
# 0 391 Loss: 0.100 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.572 | Acc: 81.250% (104/128)
# Epoch: 106 | Time Per Epoch: 00:37 | train acc: 96.51 | test acc: 84.32% | Learning Rate: 0.001
#
# Epoch: 107
# 0 391 Loss: 0.106 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.732 | Acc: 82.031% (105/128)
# Epoch: 107 | Time Per Epoch: 00:58 | train acc: 96.84 | test acc: 82.66% | Learning Rate: 0.001
#
# Epoch: 108
# 0 391 Loss: 0.042 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.545 | Acc: 88.281% (113/128)
# Epoch: 108 | Time Per Epoch: 00:36 | train acc: 96.59 | test acc: 84.18% | Learning Rate: 0.001
#
# Epoch: 109
# 0 391 Loss: 0.104 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.628 | Acc: 84.375% (108/128)
# Epoch: 109 | Time Per Epoch: 00:34 | train acc: 96.60 | test acc: 84.44% | Learning Rate: 0.001
#
# Epoch: 110
# 0 391 Loss: 0.105 | Acc: 93.750% (120/128)
# 0 79 Loss: 0.496 | Acc: 85.156% (109/128)
# Epoch: 110 | Time Per Epoch: 00:36 | train acc: 96.65 | test acc: 84.17% | Learning Rate: 0.001
#
# Epoch: 111
# 0 391 Loss: 0.197 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.652 | Acc: 82.031% (105/128)
# Epoch: 111 | Time Per Epoch: 00:35 | train acc: 96.80 | test acc: 84.25% | Learning Rate: 0.001
#
# Epoch: 112
# 0 391 Loss: 0.046 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.510 | Acc: 85.938% (110/128)
# Epoch: 112 | Time Per Epoch: 00:34 | train acc: 96.73 | test acc: 83.91% | Learning Rate: 0.001
#
# Epoch: 113
# 0 391 Loss: 0.051 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.499 | Acc: 86.719% (111/128)
# Epoch: 113 | Time Per Epoch: 00:35 | train acc: 96.66 | test acc: 84.49% | Learning Rate: 0.001
#
# Epoch: 114
# 0 391 Loss: 0.054 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.457 | Acc: 85.938% (110/128)
# Epoch: 114 | Time Per Epoch: 00:35 | train acc: 96.63 | test acc: 83.72% | Learning Rate: 0.001
#
# Epoch: 115
# 0 391 Loss: 0.040 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.572 | Acc: 85.938% (110/128)
# Epoch: 115 | Time Per Epoch: 00:35 | train acc: 96.79 | test acc: 83.80% | Learning Rate: 0.001
#
# Epoch: 116
# 0 391 Loss: 0.067 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.473 | Acc: 89.062% (114/128)
# Epoch: 116 | Time Per Epoch: 00:54 | train acc: 96.77 | test acc: 84.66% | Learning Rate: 0.001
#
# Epoch: 117
# 0 391 Loss: 0.063 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.507 | Acc: 84.375% (108/128)
# Epoch: 117 | Time Per Epoch: 00:35 | train acc: 96.63 | test acc: 82.95% | Learning Rate: 0.001
#
# Epoch: 118
# 0 391 Loss: 0.041 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.549 | Acc: 82.812% (106/128)
# Epoch: 118 | Time Per Epoch: 00:36 | train acc: 96.85 | test acc: 84.42% | Learning Rate: 0.001
#
# Epoch: 119
# 0 391 Loss: 0.054 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.669 | Acc: 82.812% (106/128)
# Epoch: 119 | Time Per Epoch: 00:54 | train acc: 96.79 | test acc: 82.93% | Learning Rate: 0.001
#
# Epoch: 120
# 0 391 Loss: 0.120 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.585 | Acc: 85.938% (110/128)
# Epoch: 120 | Time Per Epoch: 00:54 | train acc: 96.77 | test acc: 84.27% | Learning Rate: 0.001
#
# Epoch: 121
# 0 391 Loss: 0.091 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.667 | Acc: 82.031% (105/128)
# Epoch: 121 | Time Per Epoch: 00:35 | train acc: 96.74 | test acc: 83.77% | Learning Rate: 0.001
#
# Epoch: 122
# 0 391 Loss: 0.087 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.539 | Acc: 83.594% (107/128)
# Epoch: 122 | Time Per Epoch: 00:36 | train acc: 96.85 | test acc: 83.65% | Learning Rate: 0.001
#
# Epoch: 123
# 0 391 Loss: 0.090 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.493 | Acc: 83.594% (107/128)
# Epoch: 123 | Time Per Epoch: 00:36 | train acc: 96.80 | test acc: 83.68% | Learning Rate: 0.001
#
# Epoch: 124
# 0 391 Loss: 0.116 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.517 | Acc: 85.938% (110/128)
# Epoch: 124 | Time Per Epoch: 00:35 | train acc: 96.57 | test acc: 83.74% | Learning Rate: 0.001
#
# Epoch: 125
# 0 391 Loss: 0.055 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.633 | Acc: 81.250% (104/128)
# Epoch: 125 | Time Per Epoch: 00:35 | train acc: 96.79 | test acc: 84.16% | Learning Rate: 0.001
#
# Epoch: 126
# 0 391 Loss: 0.086 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.605 | Acc: 88.281% (113/128)
# Epoch: 126 | Time Per Epoch: 00:35 | train acc: 96.87 | test acc: 84.41% | Learning Rate: 0.001
#
# Epoch: 127
# 0 391 Loss: 0.066 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.493 | Acc: 84.375% (108/128)
# Epoch: 127 | Time Per Epoch: 00:35 | train acc: 96.72 | test acc: 82.41% | Learning Rate: 0.001
#
# Epoch: 128
# 0 391 Loss: 0.066 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.546 | Acc: 83.594% (107/128)
# Epoch: 128 | Time Per Epoch: 00:35 | train acc: 96.82 | test acc: 84.60% | Learning Rate: 0.001
#
# Epoch: 129
# 0 391 Loss: 0.055 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.449 | Acc: 88.281% (113/128)
# Epoch: 129 | Time Per Epoch: 00:35 | train acc: 96.87 | test acc: 84.28% | Learning Rate: 0.001
#
# Epoch: 130
# 0 391 Loss: 0.060 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.476 | Acc: 87.500% (112/128)
# Epoch: 130 | Time Per Epoch: 00:33 | train acc: 96.95 | test acc: 83.95% | Learning Rate: 0.001
#
# Epoch: 131
# 0 391 Loss: 0.055 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.454 | Acc: 88.281% (113/128)
# Epoch: 131 | Time Per Epoch: 00:35 | train acc: 96.62 | test acc: 83.94% | Learning Rate: 0.001
#
# Epoch: 132
# 0 391 Loss: 0.059 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.412 | Acc: 86.719% (111/128)
# Epoch: 132 | Time Per Epoch: 00:33 | train acc: 96.98 | test acc: 84.28% | Learning Rate: 0.001
#
# Epoch: 133
# 0 391 Loss: 0.048 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.496 | Acc: 85.938% (110/128)
# Epoch: 133 | Time Per Epoch: 00:33 | train acc: 96.57 | test acc: 83.57% | Learning Rate: 0.001
#
# Epoch: 134
# 0 391 Loss: 0.046 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.389 | Acc: 88.281% (113/128)
# Epoch: 134 | Time Per Epoch: 00:33 | train acc: 96.96 | test acc: 84.95% | Learning Rate: 0.001
#
# Epoch: 135
# 0 391 Loss: 0.093 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.731 | Acc: 80.469% (103/128)
# Epoch: 135 | Time Per Epoch: 00:33 | train acc: 96.77 | test acc: 84.23% | Learning Rate: 0.001
#
# Epoch: 136
# 0 391 Loss: 0.182 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.418 | Acc: 88.281% (113/128)
# Epoch: 136 | Time Per Epoch: 00:34 | train acc: 96.74 | test acc: 83.53% | Learning Rate: 0.001
#
# Epoch: 137
# 0 391 Loss: 0.070 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.657 | Acc: 85.156% (109/128)
# Epoch: 137 | Time Per Epoch: 00:33 | train acc: 96.94 | test acc: 84.64% | Learning Rate: 0.001
#
# Epoch: 138
# 0 391 Loss: 0.029 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.444 | Acc: 85.938% (110/128)
# Epoch: 138 | Time Per Epoch: 00:32 | train acc: 96.63 | test acc: 84.44% | Learning Rate: 0.001
#
# Epoch: 139
# 0 391 Loss: 0.067 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.689 | Acc: 82.031% (105/128)
# Epoch: 139 | Time Per Epoch: 00:32 | train acc: 96.91 | test acc: 84.50% | Learning Rate: 0.001
#
# Epoch: 140
# 0 391 Loss: 0.132 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.527 | Acc: 84.375% (108/128)
# Epoch: 140 | Time Per Epoch: 00:34 | train acc: 96.74 | test acc: 84.59% | Learning Rate: 0.001
#
# Epoch: 141
# 0 391 Loss: 0.032 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.555 | Acc: 82.812% (106/128)
# Epoch: 141 | Time Per Epoch: 00:33 | train acc: 97.13 | test acc: 83.83% | Learning Rate: 0.001
#
# Epoch: 142
# 0 391 Loss: 0.060 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.492 | Acc: 86.719% (111/128)
# Epoch: 142 | Time Per Epoch: 00:33 | train acc: 96.82 | test acc: 83.74% | Learning Rate: 0.001
#
# Epoch: 143
# 0 391 Loss: 0.086 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.327 | Acc: 89.062% (114/128)
# Epoch: 143 | Time Per Epoch: 00:33 | train acc: 96.61 | test acc: 84.46% | Learning Rate: 0.001
#
# Epoch: 144
# 0 391 Loss: 0.179 | Acc: 92.969% (119/128)
# 0 79 Loss: 0.331 | Acc: 90.625% (116/128)
# Epoch: 144 | Time Per Epoch: 00:33 | train acc: 96.86 | test acc: 84.91% | Learning Rate: 0.001
#
# Epoch: 145
# 0 391 Loss: 0.079 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.527 | Acc: 85.938% (110/128)
# Epoch: 145 | Time Per Epoch: 00:33 | train acc: 96.83 | test acc: 84.78% | Learning Rate: 0.001
#
# Epoch: 146
# 0 391 Loss: 0.104 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.563 | Acc: 85.938% (110/128)
# Epoch: 146 | Time Per Epoch: 00:33 | train acc: 96.75 | test acc: 83.94% | Learning Rate: 0.001
#
# Epoch: 147
# 0 391 Loss: 0.078 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.452 | Acc: 88.281% (113/128)
# Epoch: 147 | Time Per Epoch: 00:33 | train acc: 96.78 | test acc: 84.73% | Learning Rate: 0.001
#
# Epoch: 148
# 0 391 Loss: 0.079 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.532 | Acc: 85.938% (110/128)
# Epoch: 148 | Time Per Epoch: 00:33 | train acc: 97.20 | test acc: 84.29% | Learning Rate: 0.001
#
# Epoch: 149
# 0 391 Loss: 0.065 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.481 | Acc: 85.938% (110/128)
# Epoch: 149 | Time Per Epoch: 00:33 | train acc: 96.70 | test acc: 85.12% | Learning Rate: 0.001
#
# Epoch: 150
# 0 391 Loss: 0.026 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.569 | Acc: 82.812% (106/128)
# Epoch: 150 | Time Per Epoch: 00:33 | train acc: 96.74 | test acc: 83.34% | Learning Rate: 0.001
#
# Epoch: 151
# 0 391 Loss: 0.058 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.448 | Acc: 89.844% (115/128)
# Saving..
# Epoch: 151 | Time Per Epoch: 00:33 | train acc: 96.92 | test acc: 85.25% | Learning Rate: 0.001
#
# Epoch: 152
# 0 391 Loss: 0.092 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.655 | Acc: 83.594% (107/128)
# Epoch: 152 | Time Per Epoch: 00:33 | train acc: 97.03 | test acc: 82.89% | Learning Rate: 0.001
#
# Epoch: 153
# 0 391 Loss: 0.100 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.634 | Acc: 81.250% (104/128)
# Epoch: 153 | Time Per Epoch: 00:33 | train acc: 96.92 | test acc: 84.55% | Learning Rate: 0.001
#
# Epoch: 154
# 0 391 Loss: 0.093 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.556 | Acc: 86.719% (111/128)
# Epoch: 154 | Time Per Epoch: 00:33 | train acc: 96.94 | test acc: 84.46% | Learning Rate: 0.001
#
# Epoch: 155
# 0 391 Loss: 0.064 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.554 | Acc: 85.938% (110/128)
# Epoch: 155 | Time Per Epoch: 00:34 | train acc: 96.61 | test acc: 84.46% | Learning Rate: 0.001
#
# Epoch: 156
# 0 391 Loss: 0.033 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.678 | Acc: 81.250% (104/128)
# Epoch: 156 | Time Per Epoch: 00:33 | train acc: 97.07 | test acc: 83.56% | Learning Rate: 0.001
#
# Epoch: 157
# 0 391 Loss: 0.052 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.617 | Acc: 87.500% (112/128)
# Epoch: 157 | Time Per Epoch: 00:33 | train acc: 96.90 | test acc: 84.31% | Learning Rate: 0.001
#
# Epoch: 158
# 0 391 Loss: 0.089 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.580 | Acc: 87.500% (112/128)
# Epoch: 158 | Time Per Epoch: 00:33 | train acc: 96.81 | test acc: 85.02% | Learning Rate: 0.001
#
# Epoch: 159
# 0 391 Loss: 0.135 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.541 | Acc: 85.938% (110/128)
# Epoch: 159 | Time Per Epoch: 00:33 | train acc: 96.89 | test acc: 84.38% | Learning Rate: 0.001
#
# Epoch: 160
# 0 391 Loss: 0.054 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.737 | Acc: 80.469% (103/128)
# Epoch: 160 | Time Per Epoch: 00:33 | train acc: 96.97 | test acc: 81.59% | Learning Rate: 0.001
#
# Epoch: 161
# 0 391 Loss: 0.067 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.572 | Acc: 86.719% (111/128)
# Epoch: 161 | Time Per Epoch: 00:34 | train acc: 96.80 | test acc: 83.80% | Learning Rate: 0.001
#
# Epoch: 162
# 0 391 Loss: 0.116 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.511 | Acc: 85.156% (109/128)
# Epoch: 162 | Time Per Epoch: 00:33 | train acc: 96.93 | test acc: 84.36% | Learning Rate: 0.001
#
# Epoch: 163
# 0 391 Loss: 0.077 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.596 | Acc: 83.594% (107/128)
# Epoch: 163 | Time Per Epoch: 00:33 | train acc: 96.88 | test acc: 83.88% | Learning Rate: 0.001
#
# Epoch: 164
# 0 391 Loss: 0.087 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.556 | Acc: 85.938% (110/128)
# Epoch: 164 | Time Per Epoch: 00:34 | train acc: 96.83 | test acc: 84.48% | Learning Rate: 0.001
#
# Epoch: 165
# 0 391 Loss: 0.043 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.628 | Acc: 85.156% (109/128)
# Epoch: 165 | Time Per Epoch: 00:33 | train acc: 96.99 | test acc: 83.51% | Learning Rate: 0.001
#
# Epoch: 166
# 0 391 Loss: 0.055 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.494 | Acc: 87.500% (112/128)
# Epoch: 166 | Time Per Epoch: 00:33 | train acc: 97.07 | test acc: 85.22% | Learning Rate: 0.001
#
# Epoch: 167
# 0 391 Loss: 0.068 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.518 | Acc: 82.812% (106/128)
# Epoch: 167 | Time Per Epoch: 00:33 | train acc: 96.96 | test acc: 83.60% | Learning Rate: 0.001
#
# Epoch: 168
# 0 391 Loss: 0.078 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.432 | Acc: 86.719% (111/128)
# Epoch: 168 | Time Per Epoch: 00:34 | train acc: 96.69 | test acc: 84.85% | Learning Rate: 0.001
#
# Epoch: 169
# 0 391 Loss: 0.044 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.532 | Acc: 86.719% (111/128)
# Epoch: 169 | Time Per Epoch: 00:33 | train acc: 97.12 | test acc: 84.21% | Learning Rate: 0.001
#
# Epoch: 170
# 0 391 Loss: 0.081 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.535 | Acc: 83.594% (107/128)
# Epoch: 170 | Time Per Epoch: 00:33 | train acc: 96.94 | test acc: 84.83% | Learning Rate: 0.001
#
# Epoch: 171
# 0 391 Loss: 0.102 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.481 | Acc: 87.500% (112/128)
# Epoch: 171 | Time Per Epoch: 00:33 | train acc: 96.98 | test acc: 83.95% | Learning Rate: 0.001
#
# Epoch: 172
# 0 391 Loss: 0.031 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.470 | Acc: 89.062% (114/128)
# Epoch: 172 | Time Per Epoch: 00:34 | train acc: 96.82 | test acc: 84.44% | Learning Rate: 0.001
#
# Epoch: 173
# 0 391 Loss: 0.076 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.509 | Acc: 82.031% (105/128)
# Epoch: 173 | Time Per Epoch: 00:33 | train acc: 97.10 | test acc: 84.09% | Learning Rate: 0.001
#
# Epoch: 174
# 0 391 Loss: 0.045 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.571 | Acc: 83.594% (107/128)
# Epoch: 174 | Time Per Epoch: 00:32 | train acc: 96.81 | test acc: 83.99% | Learning Rate: 0.001
#
# Epoch: 175
# 0 391 Loss: 0.112 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.470 | Acc: 85.938% (110/128)
# Epoch: 175 | Time Per Epoch: 00:32 | train acc: 97.11 | test acc: 84.60% | Learning Rate: 0.001
#
# Epoch: 176
# 0 391 Loss: 0.079 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.428 | Acc: 88.281% (113/128)
# Epoch: 176 | Time Per Epoch: 00:33 | train acc: 96.68 | test acc: 84.06% | Learning Rate: 0.001
#
# Epoch: 177
# 0 391 Loss: 0.072 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.478 | Acc: 85.938% (110/128)
# Epoch: 177 | Time Per Epoch: 00:33 | train acc: 97.18 | test acc: 84.36% | Learning Rate: 0.001
#
# Epoch: 178
# 0 391 Loss: 0.053 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.714 | Acc: 80.469% (103/128)
# Epoch: 178 | Time Per Epoch: 00:34 | train acc: 97.25 | test acc: 83.54% | Learning Rate: 0.001
#
# Epoch: 179
# 0 391 Loss: 0.100 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.480 | Acc: 88.281% (113/128)
# Epoch: 179 | Time Per Epoch: 00:33 | train acc: 96.76 | test acc: 82.86% | Learning Rate: 0.001
#
# Epoch: 180
# 0 391 Loss: 0.088 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.442 | Acc: 89.844% (115/128)
# Epoch: 180 | Time Per Epoch: 00:32 | train acc: 96.62 | test acc: 85.02% | Learning Rate: 0.001
#
# Epoch: 181
# 0 391 Loss: 0.018 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.404 | Acc: 85.156% (109/128)
# Epoch: 181 | Time Per Epoch: 00:33 | train acc: 96.98 | test acc: 83.39% | Learning Rate: 0.001
#
# Epoch: 182
# 0 391 Loss: 0.062 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.421 | Acc: 87.500% (112/128)
# Epoch: 182 | Time Per Epoch: 00:33 | train acc: 97.08 | test acc: 84.60% | Learning Rate: 0.001
#
# Epoch: 183
# 0 391 Loss: 0.064 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.406 | Acc: 88.281% (113/128)
# Epoch: 183 | Time Per Epoch: 00:33 | train acc: 96.99 | test acc: 84.81% | Learning Rate: 0.001
#
# Epoch: 184
# 0 391 Loss: 0.072 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.440 | Acc: 87.500% (112/128)
# Epoch: 184 | Time Per Epoch: 00:33 | train acc: 97.02 | test acc: 83.82% | Learning Rate: 0.001
#
# Epoch: 185
# 0 391 Loss: 0.033 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.511 | Acc: 89.062% (114/128)
# Epoch: 185 | Time Per Epoch: 00:32 | train acc: 97.11 | test acc: 84.40% | Learning Rate: 0.001
#
# Epoch: 186
# 0 391 Loss: 0.038 | Acc: 100.000% (128/128)
# 0 79 Loss: 0.535 | Acc: 86.719% (111/128)
# Epoch: 186 | Time Per Epoch: 00:32 | train acc: 97.04 | test acc: 84.20% | Learning Rate: 0.001
#
# Epoch: 187
# 0 391 Loss: 0.094 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.491 | Acc: 89.062% (114/128)
# Epoch: 187 | Time Per Epoch: 00:32 | train acc: 97.03 | test acc: 83.82% | Learning Rate: 0.001
#
# Epoch: 188
# 0 391 Loss: 0.117 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.573 | Acc: 82.031% (105/128)
# Epoch: 188 | Time Per Epoch: 00:33 | train acc: 96.76 | test acc: 84.14% | Learning Rate: 0.001
#
# Epoch: 189
# 0 391 Loss: 0.059 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.499 | Acc: 84.375% (108/128)
# Epoch: 189 | Time Per Epoch: 00:32 | train acc: 96.94 | test acc: 84.50% | Learning Rate: 0.001
#
# Epoch: 190
# 0 391 Loss: 0.091 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.543 | Acc: 85.938% (110/128)
# Epoch: 190 | Time Per Epoch: 00:32 | train acc: 97.01 | test acc: 84.41% | Learning Rate: 0.001
#
# Epoch: 191
# 0 391 Loss: 0.122 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.419 | Acc: 87.500% (112/128)
# Epoch: 191 | Time Per Epoch: 00:32 | train acc: 96.95 | test acc: 83.48% | Learning Rate: 0.001
#
# Epoch: 192
# 0 391 Loss: 0.092 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.593 | Acc: 85.938% (110/128)
# Epoch: 192 | Time Per Epoch: 00:33 | train acc: 97.11 | test acc: 84.71% | Learning Rate: 0.001
#
# Epoch: 193
# 0 391 Loss: 0.046 | Acc: 98.438% (126/128)
# 0 79 Loss: 0.489 | Acc: 85.938% (110/128)
# Epoch: 193 | Time Per Epoch: 00:32 | train acc: 96.98 | test acc: 84.86% | Learning Rate: 0.001
#
# Epoch: 194
# 0 391 Loss: 0.071 | Acc: 96.875% (124/128)
# 0 79 Loss: 0.556 | Acc: 85.938% (110/128)
# Epoch: 194 | Time Per Epoch: 00:32 | train acc: 96.82 | test acc: 84.24% | Learning Rate: 0.001
#
# Epoch: 195
# 0 391 Loss: 0.109 | Acc: 94.531% (121/128)
# 0 79 Loss: 0.501 | Acc: 85.938% (110/128)
# Epoch: 195 | Time Per Epoch: 00:33 | train acc: 97.11 | test acc: 84.85% | Learning Rate: 0.001
#
# Epoch: 196
# 0 391 Loss: 0.093 | Acc: 96.094% (123/128)
# 0 79 Loss: 0.534 | Acc: 85.156% (109/128)
# Epoch: 196 | Time Per Epoch: 00:32 | train acc: 96.96 | test acc: 84.69% | Learning Rate: 0.001
#
# Epoch: 197
# 0 391 Loss: 0.068 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.560 | Acc: 83.594% (107/128)
# Epoch: 197 | Time Per Epoch: 00:33 | train acc: 96.90 | test acc: 83.83% | Learning Rate: 0.001
#
# Epoch: 198
# 0 391 Loss: 0.127 | Acc: 95.312% (122/128)
# 0 79 Loss: 0.404 | Acc: 88.281% (113/128)
# Saving..
# Epoch: 198 | Time Per Epoch: 00:34 | train acc: 97.05 | test acc: 85.62% | Learning Rate: 0.001
#
# Epoch: 199
# 0 391 Loss: 0.054 | Acc: 97.656% (125/128)
# 0 79 Loss: 0.534 | Acc: 85.156% (109/128)
# Epoch: 199 | Time Per Epoch: 00:34 | train acc: 97.32 | test acc: 84.08% | Learning Rate: 0.001
#
# Epoch: 200
# 0 391 Loss: 0.043 | Acc: 99.219% (127/128)
# 0 79 Loss: 0.433 | Acc: 89.062% (114/128)
# Epoch: 200 | Time Per Epoch: 00:32 | train acc: 96.77 | test acc: 84.35% | Learning Rate: 0.001

# %%
# plot results
results = pd.read_csv(logname, sep=',')
results.head()
# Out:
#    epoch  train loss  train acc  test loss   test acc
# 0      1    1.781772  35.153999   1.598876  42.449997
# 1      2    1.394245  48.820000   1.601570  45.610001
# 2      3    1.221063  55.606003   1.429040  49.829998
# 3      4    1.132467  59.278000   1.216585  56.500000
# 4      5    1.069960  61.680000   1.303143  56.010002

# %%
train_accuracy = results['train acc'].values
test_accuracy = results['test acc'].values

print(f"Average test Accuracy over {end_apochs} epochs: {sum(test_accuracy)//len(test_accuracy)}")
print(f"best test accuraccy over {end_apochs} epochs: {max(test_accuracy)}")
print(f"best Train accuraccy over {end_apochs} epochs: {max(train_accuracy)}")
# Out:
# Average test Accuracy over 200 epochs: 80.0
# best test accuraccy over 200 epochs: 85.6199951171875
# best Train accuraccy over 200 epochs: 97.31600189208984

# %%
plt.figure(figsize=(9, 6))
plt.plot(sorted(results['epoch'].values), train_accuracy, label='train')
plt.plot(sorted(results['epoch'].values), test_accuracy, label='test')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.title(f'Train/Test Accuracy curve for {end_apochs} epochs')
plt.legend()
plt.show()
