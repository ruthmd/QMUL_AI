# %%
# imports
import os
import csv
import time
import multiprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms

# %%
# @title Set random seed

# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# for DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.
import random
import torch

def set_seed(seed=None, seed_torch=True):
    if seed is None:
        seed = np.random.choice(2 ** 32)
    random.seed(seed)
    np.random.seed(seed)
    if seed_torch:
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
    
    print(f'Random seed {seed} has been set.')

# In case that `DataLoader` is used
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %%
# @title Set device (GPU or CPU)

# inform the user if the notebook uses GPU or CPU.

def set_device():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    if device != "cuda":
        print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
    else:
        print("GPU is enabled in this notebook.")

    return device

# %%
set_seed(seed=2021)
set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.
# 'cuda'

# %%
# hyper-parameters
use_cuda = torch.cuda.is_available()
alpha = 0.4  # alpha for mixup augmentation
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
batch_size = 256
end_apochs = 200  # Please change this to 200
base_learning_rate = 1e-3
cutout = False  # True/False if you want to use cutout augmentation
mixup = True  # True/False if you want to use mixup augmentation
n_holes = 1  # number of holes to cut out from image for cutout
length = 16  # length of the holes for cutout augmentation
torchvision_transforms = False  # True/False if you want use torchvision augmentations

# %%
# @markdown `Cutout` Augmentation class

class Cutout(object):
  """
  code from: https://github.com/uoguelph-mlrg/Cutout

  Randomly mask out one or more patches from an image.
  Args:
      n_holes (int): Number of patches to cut out of each image.
      length (int): The length (in pixels) of each square patch.
  """
  def __init__(self, n_holes, length):
    self.n_holes = n_holes
    self.length = length

  def __call__(self, img):
    """
    Args:
        img (Tensor): Tensor image of size (C, H, W).
    Returns:
        Tensor: Image with n_holes of dimension length x length cut out of it.
    """
    h = img.size(1)
    w = img.size(2)

    mask = np.ones((h, w), np.float32)

    for n in range(self.n_holes):
      y = np.random.randint(h)
      x = np.random.randint(w)

      y1 = np.clip(y - self.length // 2, 0, h)
      y2 = np.clip(y + self.length // 2, 0, h)
      x1 = np.clip(x - self.length // 2, 0, w)
      x2 = np.clip(x + self.length // 2, 0, w)

      mask[y1: y2, x1: x2] = 0.

    mask = torch.from_numpy(mask)
    mask = mask.expand_as(img)
    img = img * mask

    return img

# %%
# @markdown `mixup_data` Augmentation function

def mixup_data(x, y, alpha=1.0, use_cuda=True):
  '''Compute the mixup data. Return mixed inputs, pairs of targets, and lambda
      - https://github.com/hongyi-zhang/mixup
  '''
  if alpha > 0.:
    lam = np.random.beta(alpha, alpha)
  else:
    lam = 1.
  batch_size = x.size()[0]
  if use_cuda:
    index = torch.randperm(batch_size).cuda()
  else:
    index = torch.randperm(batch_size)

  mixed_x = lam * x + (1 - lam) * x[index, :]
  y_a, y_b = y, y[index]

  return mixed_x, y_a, y_b, lam

# %%
# @markdown Download and prepare Data
print('==> Preparing data...')
def percentageSplit(full_dataset, percent=0.0):
  set1_size = int(percent * len(full_dataset))
  set2_size = len(full_dataset) - set1_size
  final_dataset, _ = torch.utils.data.random_split(full_dataset,
                                                   [set1_size, set2_size])
  return final_dataset

# CIFAR normalizing
mean = [0.5071, 0.4866, 0.4409]
std = [0.2673, 0.2564, 0.2762]

# torchvision transforms
transform_train = transforms.Compose([])
if torchvision_transforms:
  transform_train.transforms.append(transforms.RandomCrop(32, padding=4))
  transform_train.transforms.append(transforms.RandomHorizontalFlip())

transform_train.transforms.append(transforms.ToTensor())
transform_train.transforms.append(transforms.Normalize(mean, std))

if cutout:
  transform_train.transforms.append(Cutout(n_holes=n_holes, length=length))

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# Out:
# ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Object type: {type(trainset)}")
print(f"Training data shape: {trainset.data.shape}")
print(f"Test data shape: {testset.data.shape}")
print(f"Number of classes: {np.unique(trainset.targets).shape[0]}")
# Out:
# Object type: <class 'torchvision.datasets.cifar.CIFAR10'>
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)
# Number of classes: 10

# %%
# choose percentage from the trainset. set percent = 1.0 to use the whole train data
percent = 1.0
trainset = percentageSplit(trainset, percent = percent)
print(f"size of the new trainset: {len(trainset)}")
# Out:
# size of the new trainset: 50000

# %%
# Dataloader
num_workers = multiprocessing.cpu_count()

print(f'----> number of workers: {num_workers}')

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ----> number of workers: 96

# %%
# get batch of data
batch_X, batch_Y =  next(iter(trainloader))

# %%
def plot_mixed_images(images):
  inv_normalize = transforms.Normalize(
                      mean= [-m/s for m, s in zip(mean, std)],
                      std= [1/s for s in std]
                      )
  inv_PIL = transforms.ToPILImage()
  fig = plt.figure(figsize=(10, 8))
  for i in range(1, len(images) + 1):
    image = images[i-1]
    ax = fig.add_subplot(1, 4, i)
    inv_tensor = inv_normalize(image).cpu()
    ax.imshow(inv_PIL(inv_tensor))
  plt.show()

# %%
# Mixup Visualization
if mixup:
    alpha = 0.4
    mixed_x, y_a, y_b, lam = mixup_data(batch_X.cuda(), batch_Y.cuda(), alpha=alpha, use_cuda=use_cuda)
    plot_mixed_images(mixed_x[:4])

# %%
# Mixup Visualization
if cutout:
    plot_mixed_images(batch_X[:4])

# %%
# @markdown ResNet model in PyTorch

class Bottleneck(nn.Module):
    """
    For deep networks, we use BottleNeck, which is proposed in the paper to have approximate computational complexity but save a lot of resources
    zip_channels: The compressed dimension, the final output dimension is expansion * zip_channels
    For the network structure of ResNet50/101/152, mainly because the third layer is 4 times the second layer, so expansion=4
    """
    expansion = 4

    def __init__(self, in_channels, zip_channels, stride=1):
        super(Bottleneck, self).__init__()
        out_channels = self.expansion * zip_channels
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, zip_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, zip_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

class BasicBlock(nn.Module):
    """
    For shallow networks, such as ResNet-18/34, etc., use the basic Block
    The base module is not compressed, so expansion=1
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock,self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True),
            nn.Conv2d(out_channels,out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        # If the input and output dimensions are not equal, use a 1x1 convolutional layer to change the dimension
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels),
            )
    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out


class ResNet(nn.Module):
    """
    Different ResNet architectures are unified with one layer of feature extraction and four layers of residuals, and the difference lies in the depth of each layer of residuals.
    For cifar10, the change of feature map size is as follows:
    (32, 32, 3) -> [Conv2d] -> (32, 32, 64) -> [Res1] -> (32, 32, 64) -> [Res2]
 -> (16, 16, 128) -> [Res3] -> (8, 8, 256) ->[Res4] -> (4, 4, 512) -> [AvgPool]
 -> (1, 1, 512) -> [Reshape] -> (512) -> [Linear] -> (10)
    """
    def __init__(self, block, num_blocks, num_classes=10, verbose = False):
        super(ResNet, self).__init__()
        self.verbose = verbose
        self.in_channels = 64
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        #Use the _make_layer function to generate the structure of conv2_x, conv3_x, conv4_x, conv5_x corresponding to the above table
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        # After cifar10 goes through the above structure, the feature map size here is 4 x 4 x 512 x expansion
        # So 4 x 4 average pooling is used here
        self.avg_pool = nn.AvgPool2d(kernel_size=4)
        self.classifer = nn.Linear(512 *block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # The first block needs to be downsampled
        strides = [stride] + [1]* (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            # If it is Bottleneck Block, you need to compress the input dimension of each layer, and then increase the dimension after compression
            # So the input dimension of each layer should also change accordingly
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.features(x)
        if self.verbose:
            print('block 1 output: {}'.format(out.shape))
        out = self.layer1(out)
        if self.verbose:
            print('block 2 output: {}'.format(out.shape))
        out = self.layer2(out)
        if self.verbose:
            print('block 3 output: {}'.format(out.shape))
        out = self.layer3(out)
        if self.verbose:
            print('block 4 output: {}'.format(out.shape))
        out = self.layer4(out)
        if self.verbose:
            print('block 5 output: {}'.format(out.shape))
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.classifer(out)
        return out


def ResNet18(verbose=False):
    return ResNet(BasicBlock, [2,2,2,2],verbose=verbose)

def ResNet34(verbose=False):
    return ResNet(BasicBlock, [3,4,6,3],verbose=verbose)

def ResNet50(verbose=False):
    return ResNet(Bottleneck, [3,4,6,3],verbose=verbose)

def ResNet101(verbose=False):
    return ResNet(Bottleneck, [3,4,23,3],verbose=verbose)

def ResNet152(verbose=False):
    return ResNet(Bottleneck, [3,8,36,3],verbose=verbose)

# %%
# load the Model
net = ResNet18()
print('-----> verify if model is run on random data')
y = net(Variable(torch.randn(1,3,32,32)))
print('model loaded')

result_folder = './results/'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

logname = result_folder + net.__class__.__name__ + '_' + 'mixup_alpha_p4.csv'

if use_cuda:
  net.cuda()
  net = torch.nn.DataParallel(net)
  print('Using', torch.cuda.device_count(), 'GPUs.')
  cudnn.benchmark = True
  print('Using CUDA..')
# Out:
# -----> verify if model is run on random data
# model loaded
# Using 1 GPUs.
# Using CUDA..

# %%
# optimizer and criterion

def mixup_criterion(y_a, y_b, lam):
  '''
    - Mixup criterion
    - https://github.com/hongyi-zhang/mixup
  '''
  return lambda criterion, pred: lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

criterion = nn.CrossEntropyLoss()  # only for test data
optimizer = optim.Adam(net.parameters(), lr=base_learning_rate, weight_decay=5e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=10, min_lr=1e-5)

# %%
# Training & Test functions
def train(epoch, alpha, use_cuda=False):
  print('\nEpoch: %d' % epoch)
  net.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(trainloader):
    if use_cuda:
      inputs, targets = inputs.cuda(), targets.cuda()
    optimizer.zero_grad()
    if mixup:
      # generate mixed inputs, two one-hot label vectors and mixing coefficient
      inputs, targets_a, targets_b, lam = mixup_data(inputs, targets, alpha, use_cuda)
      inputs, targets_a, targets_b = Variable(inputs), Variable(targets_a), Variable(targets_b)
      outputs = net(inputs)
      loss_func = mixup_criterion(targets_a, targets_b, lam)
      loss = loss_func(criterion, outputs)
    else:
      inputs, targets = Variable(inputs), Variable(targets)
      outputs = net(inputs)
      loss = criterion(outputs, targets)

    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = torch.max(outputs.data, 1)
    total += targets.size(0)

    if mixup:
      correct += lam * predicted.eq(targets_a.data).cpu().sum() + (1 - lam) * predicted.eq(targets_b.data).cpu().sum()
    else:
      correct += predicted.eq(targets.data).cpu().sum()

    if batch_idx % 500 == 0:
      print(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
          % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
  return (train_loss/batch_idx, 100.*correct/total)


def test(epoch, use_cuda=False):
  global best_acc
  net.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
      if use_cuda:
        inputs, targets = inputs.cuda(), targets.cuda()
      # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
      outputs = net(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = torch.max(outputs.data, 1)
      total += targets.size(0)
      correct += predicted.eq(targets.data).cpu().sum()

      if batch_idx % 200 == 0:
        print(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    best_acc = acc
    checkpoint(acc, epoch)
  return (test_loss/batch_idx, 100.*correct/total)

# %%
# @markdown `checkpoint` and `adjust_learning_rate` functions
def checkpoint(acc, epoch):
  # Save checkpoint.
  print('Saving..')
  state = {
      'net': net.state_dict(),
      'acc': acc,
      'epoch': epoch,
      'rng_state': torch.get_rng_state()
      }
  if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')
  torch.save(state, './checkpoint/ckpt.t7')


def adjust_learning_rate(optimizer, epoch):
  """decrease the learning rate at 100 and 150 epoch"""
  lr = base_learning_rate
  if epoch <= 9 and lr > 0.1:
    # warm-up training for large minibatch
    lr = 0.1 + (base_learning_rate - 0.1) * epoch / 10.
  if epoch >= 100:
    lr /= 10
  if epoch >= 150:
    lr /= 10
  for param_group in optimizer.param_groups:
    param_group['lr'] = lr

# %%
# start training
if not os.path.exists(logname):
  with open(logname, 'w') as logfile:
    logwriter = csv.writer(logfile, delimiter=',')
    logwriter.writerow(['epoch', 'train loss', 'train acc',
                        'test loss', 'test acc'])

for epoch in range(start_epoch+1, end_apochs+1):
  # adjust_learning_rate(optimizer, epoch)

    start = time.time()
    
    train_loss, train_acc = train(epoch, alpha, use_cuda=use_cuda)
    test_loss, test_acc = test(epoch, use_cuda=use_cuda)

    scheduler.step(test_loss)

    end = time.time()

    time_ = int(end - start)
    h = time_ / 3600
    m = time_ % 3600 /60
    s = time_ % 60
    time_str = "%02d:%02d" % (m, s)
    
    with open(logname, 'a') as logfile:
        logwriter = csv.writer(logfile, delimiter=',')
        logwriter.writerow([epoch, train_loss, train_acc.item(),
                            test_loss, test_acc.item()])
    print(f"Epoch: {epoch} | Time Per Epoch: {time_str} | train acc: {train_acc:.2f} | test acc: {test_acc:.2f}% | Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# 0 196 Loss: 2.411 | Acc: 8.430% (21/256)
# 0 40 Loss: 1.368 | Acc: 54.688% (140/256)
# Saving..
# Epoch: 1 | Time Per Epoch: 00:18 | train acc: 39.55 | test acc: 50.79% | Learning Rate: 0.001
#
# Epoch: 2
# 0 196 Loss: 1.083 | Acc: 61.651% (157/256)
# 0 40 Loss: 0.981 | Acc: 66.406% (170/256)
# Saving..
# Epoch: 2 | Time Per Epoch: 00:16 | train acc: 54.98 | test acc: 66.38% | Learning Rate: 0.001
#
# Epoch: 3
# 0 196 Loss: 1.422 | Acc: 57.234% (146/256)
# 0 40 Loss: 0.949 | Acc: 67.969% (174/256)
# Saving..
# Epoch: 3 | Time Per Epoch: 00:17 | train acc: 61.28 | test acc: 68.26% | Learning Rate: 0.001
#
# Epoch: 4
# 0 196 Loss: 1.608 | Acc: 52.690% (134/256)
# 0 40 Loss: 0.761 | Acc: 76.172% (195/256)
# Saving..
# Epoch: 4 | Time Per Epoch: 00:16 | train acc: 64.35 | test acc: 74.62% | Learning Rate: 0.001
#
# Epoch: 5
# 0 196 Loss: 0.919 | Acc: 75.787% (194/256)
# 0 40 Loss: 0.982 | Acc: 67.969% (174/256)
# Epoch: 5 | Time Per Epoch: 00:16 | train acc: 67.90 | test acc: 65.85% | Learning Rate: 0.001
#
# Epoch: 6
# 0 196 Loss: 0.604 | Acc: 83.450% (213/256)
# 0 40 Loss: 0.657 | Acc: 80.469% (206/256)
# Saving..
# Epoch: 6 | Time Per Epoch: 00:16 | train acc: 69.12 | test acc: 78.19% | Learning Rate: 0.001
#
# Epoch: 7
# 0 196 Loss: 0.487 | Acc: 87.322% (223/256)
# 0 40 Loss: 0.886 | Acc: 69.922% (179/256)
# Epoch: 7 | Time Per Epoch: 00:16 | train acc: 69.94 | test acc: 71.36% | Learning Rate: 0.001
#
# Epoch: 8
# 0 196 Loss: 0.755 | Acc: 82.520% (211/256)
# 0 40 Loss: 0.600 | Acc: 79.688% (204/256)
# Saving..
# Epoch: 8 | Time Per Epoch: 00:16 | train acc: 72.40 | test acc: 80.35% | Learning Rate: 0.001
#
# Epoch: 9
# 0 196 Loss: 1.841 | Acc: 46.919% (120/256)
# 0 40 Loss: 0.633 | Acc: 79.688% (204/256)
# Epoch: 9 | Time Per Epoch: 00:15 | train acc: 72.88 | test acc: 77.17% | Learning Rate: 0.001
#
# Epoch: 10
# 0 196 Loss: 0.776 | Acc: 82.384% (210/256)
# 0 40 Loss: 0.632 | Acc: 78.125% (200/256)
# Epoch: 10 | Time Per Epoch: 00:16 | train acc: 72.08 | test acc: 78.55% | Learning Rate: 0.001
#
# Epoch: 11
# 0 196 Loss: 0.421 | Acc: 91.189% (233/256)
# 0 40 Loss: 0.750 | Acc: 74.219% (190/256)
# Epoch: 11 | Time Per Epoch: 00:16 | train acc: 74.01 | test acc: 77.50% | Learning Rate: 0.001
#
# Epoch: 12
# 0 196 Loss: 0.848 | Acc: 81.119% (207/256)
# 0 40 Loss: 0.779 | Acc: 78.125% (200/256)
# Epoch: 12 | Time Per Epoch: 00:16 | train acc: 75.45 | test acc: 78.08% | Learning Rate: 0.001
#
# Epoch: 13
# 0 196 Loss: 1.339 | Acc: 61.012% (156/256)
# 0 40 Loss: 0.683 | Acc: 80.859% (207/256)
# Epoch: 13 | Time Per Epoch: 00:16 | train acc: 76.14 | test acc: 79.55% | Learning Rate: 0.001
#
# Epoch: 14
# 0 196 Loss: 1.255 | Acc: 64.798% (165/256)
# 0 40 Loss: 0.639 | Acc: 81.641% (209/256)
# Saving..
# Epoch: 14 | Time Per Epoch: 00:16 | train acc: 75.02 | test acc: 81.95% | Learning Rate: 0.001
#
# Epoch: 15
# 0 196 Loss: 0.438 | Acc: 92.697% (237/256)
# 0 40 Loss: 0.548 | Acc: 83.203% (213/256)
# Saving..
# Epoch: 15 | Time Per Epoch: 00:16 | train acc: 77.23 | test acc: 82.64% | Learning Rate: 0.001
#
# Epoch: 16
# 0 196 Loss: 0.734 | Acc: 82.071% (210/256)
# 0 40 Loss: 0.443 | Acc: 87.500% (224/256)
# Saving..
# Epoch: 16 | Time Per Epoch: 00:16 | train acc: 76.84 | test acc: 85.33% | Learning Rate: 0.001
#
# Epoch: 17
# 0 196 Loss: 1.603 | Acc: 46.091% (117/256)
# 0 40 Loss: 0.448 | Acc: 87.891% (225/256)
# Epoch: 17 | Time Per Epoch: 00:16 | train acc: 76.56 | test acc: 84.26% | Learning Rate: 0.001
#
# Epoch: 18
# 0 196 Loss: 1.148 | Acc: 70.349% (180/256)
# 0 40 Loss: 0.539 | Acc: 84.766% (217/256)
# Epoch: 18 | Time Per Epoch: 00:16 | train acc: 76.21 | test acc: 83.28% | Learning Rate: 0.001
#
# Epoch: 19
# 0 196 Loss: 0.635 | Acc: 88.083% (225/256)
# 0 40 Loss: 0.495 | Acc: 83.984% (215/256)
# Epoch: 19 | Time Per Epoch: 00:16 | train acc: 78.09 | test acc: 84.20% | Learning Rate: 0.001
#
# Epoch: 20
# 0 196 Loss: 0.181 | Acc: 95.311% (243/256)
# 0 40 Loss: 0.568 | Acc: 85.156% (218/256)
# Epoch: 20 | Time Per Epoch: 00:15 | train acc: 79.17 | test acc: 82.40% | Learning Rate: 0.001
#
# Epoch: 21
# 0 196 Loss: 1.228 | Acc: 68.495% (175/256)
# 0 40 Loss: 0.532 | Acc: 85.547% (219/256)
# Epoch: 21 | Time Per Epoch: 00:16 | train acc: 78.79 | test acc: 84.94% | Learning Rate: 0.001
#
# Epoch: 22
# 0 196 Loss: 0.394 | Acc: 92.604% (237/256)
# 0 40 Loss: 0.546 | Acc: 83.203% (213/256)
# Epoch: 22 | Time Per Epoch: 00:15 | train acc: 80.55 | test acc: 83.40% | Learning Rate: 0.001
#
# Epoch: 23
# 0 196 Loss: 0.782 | Acc: 83.455% (213/256)
# 0 40 Loss: 0.531 | Acc: 84.766% (217/256)
# Epoch: 23 | Time Per Epoch: 00:15 | train acc: 80.69 | test acc: 83.79% | Learning Rate: 0.001
#
# Epoch: 24
# 0 196 Loss: 1.179 | Acc: 67.501% (172/256)
# 0 40 Loss: 0.619 | Acc: 82.422% (211/256)
# Epoch: 24 | Time Per Epoch: 00:16 | train acc: 78.90 | test acc: 84.08% | Learning Rate: 0.001
#
# Epoch: 25
# 0 196 Loss: 0.226 | Acc: 95.186% (243/256)
# 0 40 Loss: 0.534 | Acc: 82.812% (212/256)
# Epoch: 25 | Time Per Epoch: 00:16 | train acc: 80.02 | test acc: 83.88% | Learning Rate: 0.001
#
# Epoch: 26
# 0 196 Loss: 0.152 | Acc: 95.671% (244/256)
# 0 40 Loss: 0.505 | Acc: 84.375% (216/256)
# Epoch: 26 | Time Per Epoch: 00:16 | train acc: 81.48 | test acc: 83.89% | Learning Rate: 0.001
#
# Epoch: 27
# 0 196 Loss: 0.139 | Acc: 96.487% (247/256)
# 0 40 Loss: 0.501 | Acc: 84.375% (216/256)
# Epoch: 27 | Time Per Epoch: 00:16 | train acc: 77.46 | test acc: 84.00% | Learning Rate: 0.0001
#
# Epoch: 28
# 0 196 Loss: 1.234 | Acc: 64.322% (164/256)
# 0 40 Loss: 0.368 | Acc: 89.453% (229/256)
# Saving..
# Epoch: 28 | Time Per Epoch: 00:16 | train acc: 82.16 | test acc: 88.66% | Learning Rate: 0.0001
#
# Epoch: 29
# 0 196 Loss: 1.102 | Acc: 71.055% (181/256)
# 0 40 Loss: 0.381 | Acc: 91.016% (233/256)
# Epoch: 29 | Time Per Epoch: 00:15 | train acc: 83.22 | test acc: 88.63% | Learning Rate: 0.0001
#
# Epoch: 30
# 0 196 Loss: 1.316 | Acc: 58.836% (150/256)
# 0 40 Loss: 0.321 | Acc: 91.797% (235/256)
# Saving..
# Epoch: 30 | Time Per Epoch: 00:16 | train acc: 83.26 | test acc: 89.09% | Learning Rate: 0.0001
#
# Epoch: 31
# 0 196 Loss: 0.259 | Acc: 96.260% (246/256)
# 0 40 Loss: 0.359 | Acc: 90.234% (231/256)
# Epoch: 31 | Time Per Epoch: 00:16 | train acc: 84.36 | test acc: 88.78% | Learning Rate: 0.0001
#
# Epoch: 32
# 0 196 Loss: 0.161 | Acc: 97.813% (250/256)
# 0 40 Loss: 0.322 | Acc: 91.797% (235/256)
# Saving..
# Epoch: 32 | Time Per Epoch: 00:16 | train acc: 82.51 | test acc: 89.22% | Learning Rate: 0.0001
#
# Epoch: 33
# 0 196 Loss: 0.402 | Acc: 93.610% (239/256)
# 0 40 Loss: 0.307 | Acc: 91.797% (235/256)
# Saving..
# Epoch: 33 | Time Per Epoch: 00:16 | train acc: 84.64 | test acc: 89.50% | Learning Rate: 0.0001
#
# Epoch: 34
# 0 196 Loss: 0.354 | Acc: 94.595% (242/256)
# 0 40 Loss: 0.332 | Acc: 91.406% (234/256)
# Epoch: 34 | Time Per Epoch: 00:16 | train acc: 82.77 | test acc: 89.32% | Learning Rate: 0.0001
#
# Epoch: 35
# 0 196 Loss: 0.755 | Acc: 84.801% (217/256)
# 0 40 Loss: 0.349 | Acc: 92.188% (236/256)
# Saving..
# Epoch: 35 | Time Per Epoch: 00:16 | train acc: 85.39 | test acc: 89.61% | Learning Rate: 0.0001
#
# Epoch: 36
# 0 196 Loss: 1.015 | Acc: 73.732% (188/256)
# 0 40 Loss: 0.333 | Acc: 91.797% (235/256)
# Epoch: 36 | Time Per Epoch: 00:16 | train acc: 84.41 | test acc: 89.36% | Learning Rate: 0.0001
#
# Epoch: 37
# 0 196 Loss: 0.950 | Acc: 76.874% (196/256)
# 0 40 Loss: 0.360 | Acc: 91.406% (234/256)
# Epoch: 37 | Time Per Epoch: 00:16 | train acc: 83.64 | test acc: 89.21% | Learning Rate: 0.0001
#
# Epoch: 38
# 0 196 Loss: 0.190 | Acc: 97.356% (249/256)
# 0 40 Loss: 0.309 | Acc: 91.406% (234/256)
# Epoch: 38 | Time Per Epoch: 00:16 | train acc: 84.19 | test acc: 89.47% | Learning Rate: 0.0001
#
# Epoch: 39
# 0 196 Loss: 1.200 | Acc: 59.889% (153/256)
# 0 40 Loss: 0.358 | Acc: 91.797% (235/256)
# Epoch: 39 | Time Per Epoch: 00:16 | train acc: 85.76 | test acc: 89.11% | Learning Rate: 0.0001
#
# Epoch: 40
# 0 196 Loss: 0.701 | Acc: 86.428% (221/256)
# 0 40 Loss: 0.399 | Acc: 90.625% (232/256)
# Epoch: 40 | Time Per Epoch: 00:15 | train acc: 81.97 | test acc: 88.67% | Learning Rate: 0.0001
#
# Epoch: 41
# 0 196 Loss: 1.109 | Acc: 68.582% (175/256)
# 0 40 Loss: 0.403 | Acc: 90.234% (231/256)
# Epoch: 41 | Time Per Epoch: 00:16 | train acc: 85.17 | test acc: 89.17% | Learning Rate: 0.0001
#
# Epoch: 42
# 0 196 Loss: 0.781 | Acc: 83.635% (214/256)
# 0 40 Loss: 0.352 | Acc: 88.281% (226/256)
# Epoch: 42 | Time Per Epoch: 00:16 | train acc: 84.06 | test acc: 88.86% | Learning Rate: 0.0001
#
# Epoch: 43
# 0 196 Loss: 0.048 | Acc: 99.486% (254/256)
# 0 40 Loss: 0.364 | Acc: 89.453% (229/256)
# Epoch: 43 | Time Per Epoch: 00:16 | train acc: 83.90 | test acc: 88.96% | Learning Rate: 0.0001
#
# Epoch: 44
# 0 196 Loss: 0.980 | Acc: 74.526% (190/256)
# 0 40 Loss: 0.366 | Acc: 89.844% (230/256)
# Epoch: 44 | Time Per Epoch: 00:15 | train acc: 84.19 | test acc: 89.23% | Learning Rate: 1e-05
#
# Epoch: 45
# 0 196 Loss: 0.359 | Acc: 94.135% (240/256)
# 0 40 Loss: 0.324 | Acc: 90.234% (231/256)
# Epoch: 45 | Time Per Epoch: 00:16 | train acc: 83.11 | test acc: 89.45% | Learning Rate: 1e-05
#
# Epoch: 46
# 0 196 Loss: 1.275 | Acc: 55.930% (143/256)
# 0 40 Loss: 0.324 | Acc: 91.406% (234/256)
# Saving..
# Epoch: 46 | Time Per Epoch: 00:15 | train acc: 83.32 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 47
# 0 196 Loss: 0.159 | Acc: 97.834% (250/256)
# 0 40 Loss: 0.380 | Acc: 92.188% (236/256)
# Epoch: 47 | Time Per Epoch: 00:15 | train acc: 81.54 | test acc: 89.21% | Learning Rate: 1e-05
#
# Epoch: 48
# 0 196 Loss: 1.293 | Acc: 49.772% (127/256)
# 0 40 Loss: 0.373 | Acc: 91.797% (235/256)
# Epoch: 48 | Time Per Epoch: 00:16 | train acc: 82.72 | test acc: 89.46% | Learning Rate: 1e-05
#
# Epoch: 49
# 0 196 Loss: 0.469 | Acc: 91.936% (235/256)
# 0 40 Loss: 0.359 | Acc: 91.406% (234/256)
# Epoch: 49 | Time Per Epoch: 00:16 | train acc: 82.61 | test acc: 89.50% | Learning Rate: 1e-05
#
# Epoch: 50
# 0 196 Loss: 0.664 | Acc: 87.189% (223/256)
# 0 40 Loss: 0.349 | Acc: 91.797% (235/256)
# Epoch: 50 | Time Per Epoch: 00:15 | train acc: 85.47 | test acc: 89.50% | Learning Rate: 1e-05
#
# Epoch: 51
# 0 196 Loss: 0.015 | Acc: 99.979% (255/256)
# 0 40 Loss: 0.378 | Acc: 91.406% (234/256)
# Epoch: 51 | Time Per Epoch: 00:16 | train acc: 84.26 | test acc: 89.30% | Learning Rate: 1e-05
#
# Epoch: 52
# 0 196 Loss: 0.960 | Acc: 76.320% (195/256)
# 0 40 Loss: 0.355 | Acc: 91.406% (234/256)
# Epoch: 52 | Time Per Epoch: 00:15 | train acc: 84.49 | test acc: 89.42% | Learning Rate: 1e-05
#
# Epoch: 53
# 0 196 Loss: 1.111 | Acc: 64.609% (165/256)
# 0 40 Loss: 0.366 | Acc: 91.406% (234/256)
# Epoch: 53 | Time Per Epoch: 00:16 | train acc: 83.95 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 54
# 0 196 Loss: 1.308 | Acc: 49.708% (127/256)
# 0 40 Loss: 0.329 | Acc: 91.016% (233/256)
# Saving..
# Epoch: 54 | Time Per Epoch: 00:16 | train acc: 83.75 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 55
# 0 196 Loss: 1.187 | Acc: 61.231% (156/256)
# 0 40 Loss: 0.322 | Acc: 92.188% (236/256)
# Epoch: 55 | Time Per Epoch: 00:16 | train acc: 84.85 | test acc: 89.46% | Learning Rate: 1e-05
#
# Epoch: 56
# 0 196 Loss: 0.168 | Acc: 97.656% (250/256)
# 0 40 Loss: 0.341 | Acc: 91.406% (234/256)
# Epoch: 56 | Time Per Epoch: 00:16 | train acc: 84.19 | test acc: 89.67% | Learning Rate: 1e-05
#
# Epoch: 57
# 0 196 Loss: 0.017 | Acc: 99.943% (255/256)
# 0 40 Loss: 0.366 | Acc: 91.016% (233/256)
# Epoch: 57 | Time Per Epoch: 00:16 | train acc: 84.39 | test acc: 89.53% | Learning Rate: 1e-05
#
# Epoch: 58
# 0 196 Loss: 1.229 | Acc: 53.056% (135/256)
# 0 40 Loss: 0.330 | Acc: 91.797% (235/256)
# Epoch: 58 | Time Per Epoch: 00:15 | train acc: 84.42 | test acc: 89.47% | Learning Rate: 1e-05
#
# Epoch: 59
# 0 196 Loss: 0.033 | Acc: 99.697% (255/256)
# 0 40 Loss: 0.336 | Acc: 91.406% (234/256)
# Saving..
# Epoch: 59 | Time Per Epoch: 00:16 | train acc: 84.82 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 60
# 0 196 Loss: 0.090 | Acc: 98.882% (253/256)
# 0 40 Loss: 0.332 | Acc: 91.406% (234/256)
# Epoch: 60 | Time Per Epoch: 00:15 | train acc: 82.59 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 61
# 0 196 Loss: 0.759 | Acc: 83.528% (213/256)
# 0 40 Loss: 0.335 | Acc: 91.797% (235/256)
# Epoch: 61 | Time Per Epoch: 00:16 | train acc: 85.97 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 62
# 0 196 Loss: 0.022 | Acc: 99.922% (255/256)
# 0 40 Loss: 0.360 | Acc: 91.406% (234/256)
# Epoch: 62 | Time Per Epoch: 00:16 | train acc: 86.50 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 63
# 0 196 Loss: 1.078 | Acc: 68.554% (175/256)
# 0 40 Loss: 0.344 | Acc: 91.406% (234/256)
# Epoch: 63 | Time Per Epoch: 00:16 | train acc: 83.59 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 64
# 0 196 Loss: 0.061 | Acc: 99.314% (254/256)
# 0 40 Loss: 0.350 | Acc: 91.797% (235/256)
# Epoch: 64 | Time Per Epoch: 00:16 | train acc: 85.02 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 65
# 0 196 Loss: 1.146 | Acc: 62.987% (161/256)
# 0 40 Loss: 0.379 | Acc: 90.625% (232/256)
# Epoch: 65 | Time Per Epoch: 00:16 | train acc: 82.94 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 66
# 0 196 Loss: 1.163 | Acc: 56.565% (144/256)
# 0 40 Loss: 0.376 | Acc: 91.406% (234/256)
# Epoch: 66 | Time Per Epoch: 00:16 | train acc: 82.85 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 67
# 0 196 Loss: 1.087 | Acc: 68.804% (176/256)
# 0 40 Loss: 0.398 | Acc: 90.625% (232/256)
# Epoch: 67 | Time Per Epoch: 00:16 | train acc: 82.76 | test acc: 89.37% | Learning Rate: 1e-05
#
# Epoch: 68
# 0 196 Loss: 1.273 | Acc: 53.223% (136/256)
# 0 40 Loss: 0.379 | Acc: 91.406% (234/256)
# Epoch: 68 | Time Per Epoch: 00:16 | train acc: 84.27 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 69
# 0 196 Loss: 1.006 | Acc: 73.303% (187/256)
# 0 40 Loss: 0.381 | Acc: 90.625% (232/256)
# Epoch: 69 | Time Per Epoch: 00:17 | train acc: 81.79 | test acc: 89.46% | Learning Rate: 1e-05
#
# Epoch: 70
# 0 196 Loss: 0.221 | Acc: 96.789% (247/256)
# 0 40 Loss: 0.368 | Acc: 90.234% (231/256)
# Epoch: 70 | Time Per Epoch: 00:16 | train acc: 85.19 | test acc: 89.53% | Learning Rate: 1e-05
#
# Epoch: 71
# 0 196 Loss: 0.707 | Acc: 85.832% (219/256)
# 0 40 Loss: 0.352 | Acc: 91.406% (234/256)
# Saving..
# Epoch: 71 | Time Per Epoch: 00:17 | train acc: 85.25 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 72
# 0 196 Loss: 0.076 | Acc: 99.079% (253/256)
# 0 40 Loss: 0.372 | Acc: 91.016% (233/256)
# Epoch: 72 | Time Per Epoch: 00:17 | train acc: 83.03 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 73
# 0 196 Loss: 1.093 | Acc: 66.166% (169/256)
# 0 40 Loss: 0.404 | Acc: 90.625% (232/256)
# Epoch: 73 | Time Per Epoch: 00:16 | train acc: 83.99 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 74
# 0 196 Loss: 0.061 | Acc: 99.291% (254/256)
# 0 40 Loss: 0.362 | Acc: 90.625% (232/256)
# Epoch: 74 | Time Per Epoch: 00:17 | train acc: 84.17 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 75
# 0 196 Loss: 0.633 | Acc: 87.965% (225/256)
# 0 40 Loss: 0.389 | Acc: 90.625% (232/256)
# Epoch: 75 | Time Per Epoch: 00:16 | train acc: 81.90 | test acc: 89.56% | Learning Rate: 1e-05
#
# Epoch: 76
# 0 196 Loss: 1.189 | Acc: 60.367% (154/256)
# 0 40 Loss: 0.402 | Acc: 90.625% (232/256)
# Epoch: 76 | Time Per Epoch: 00:16 | train acc: 83.02 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 77
# 0 196 Loss: 0.378 | Acc: 93.761% (240/256)
# 0 40 Loss: 0.356 | Acc: 90.625% (232/256)
# Epoch: 77 | Time Per Epoch: 00:17 | train acc: 84.00 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 78
# 0 196 Loss: 0.194 | Acc: 97.208% (248/256)
# 0 40 Loss: 0.347 | Acc: 91.406% (234/256)
# Saving..
# Epoch: 78 | Time Per Epoch: 00:16 | train acc: 85.19 | test acc: 89.91% | Learning Rate: 1e-05
#
# Epoch: 79
# 0 196 Loss: 0.045 | Acc: 99.511% (254/256)
# 0 40 Loss: 0.371 | Acc: 91.016% (233/256)
# Epoch: 79 | Time Per Epoch: 00:17 | train acc: 83.45 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 80
# 0 196 Loss: 1.099 | Acc: 66.874% (171/256)
# 0 40 Loss: 0.387 | Acc: 91.016% (233/256)
# Epoch: 80 | Time Per Epoch: 00:16 | train acc: 85.17 | test acc: 89.76% | Learning Rate: 1e-05
#
# Epoch: 81
# 0 196 Loss: 0.167 | Acc: 97.696% (250/256)
# 0 40 Loss: 0.369 | Acc: 91.016% (233/256)
# Epoch: 81 | Time Per Epoch: 00:16 | train acc: 84.08 | test acc: 89.82% | Learning Rate: 1e-05
#
# Epoch: 82
# 0 196 Loss: 1.214 | Acc: 50.859% (130/256)
# 0 40 Loss: 0.402 | Acc: 90.625% (232/256)
# Epoch: 82 | Time Per Epoch: 00:17 | train acc: 82.75 | test acc: 89.39% | Learning Rate: 1e-05
#
# Epoch: 83
# 0 196 Loss: 0.106 | Acc: 98.638% (252/256)
# 0 40 Loss: 0.408 | Acc: 90.625% (232/256)
# Epoch: 83 | Time Per Epoch: 00:16 | train acc: 83.66 | test acc: 89.46% | Learning Rate: 1e-05
#
# Epoch: 84
# 0 196 Loss: 0.027 | Acc: 99.806% (255/256)
# 0 40 Loss: 0.353 | Acc: 91.016% (233/256)
# Epoch: 84 | Time Per Epoch: 00:17 | train acc: 84.21 | test acc: 89.80% | Learning Rate: 1e-05
#
# Epoch: 85
# 0 196 Loss: 1.007 | Acc: 72.604% (185/256)
# 0 40 Loss: 0.391 | Acc: 90.234% (231/256)
# Epoch: 85 | Time Per Epoch: 00:16 | train acc: 85.24 | test acc: 89.80% | Learning Rate: 1e-05
#
# Epoch: 86
# 0 196 Loss: 0.399 | Acc: 93.380% (239/256)
# 0 40 Loss: 0.377 | Acc: 91.406% (234/256)
# Epoch: 86 | Time Per Epoch: 00:16 | train acc: 83.44 | test acc: 89.71% | Learning Rate: 1e-05
#
# Epoch: 87
# 0 196 Loss: 0.275 | Acc: 95.722% (245/256)
# 0 40 Loss: 0.399 | Acc: 90.625% (232/256)
# Epoch: 87 | Time Per Epoch: 00:16 | train acc: 84.12 | test acc: 89.39% | Learning Rate: 1e-05
#
# Epoch: 88
# 0 196 Loss: 0.035 | Acc: 99.675% (255/256)
# 0 40 Loss: 0.360 | Acc: 90.625% (232/256)
# Epoch: 88 | Time Per Epoch: 00:16 | train acc: 82.41 | test acc: 89.67% | Learning Rate: 1e-05
#
# Epoch: 89
# 0 196 Loss: 0.917 | Acc: 76.795% (196/256)
# 0 40 Loss: 0.345 | Acc: 90.234% (231/256)
# Epoch: 89 | Time Per Epoch: 00:17 | train acc: 85.15 | test acc: 89.75% | Learning Rate: 1e-05
#
# Epoch: 90
# 0 196 Loss: 0.062 | Acc: 99.286% (254/256)
# 0 40 Loss: 0.326 | Acc: 91.406% (234/256)
# Epoch: 90 | Time Per Epoch: 00:20 | train acc: 83.25 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 91
# 0 196 Loss: 1.104 | Acc: 63.133% (161/256)
# 0 40 Loss: 0.381 | Acc: 91.016% (233/256)
# Epoch: 91 | Time Per Epoch: 00:19 | train acc: 83.84 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 92
# 0 196 Loss: 0.506 | Acc: 90.958% (232/256)
# 0 40 Loss: 0.351 | Acc: 91.406% (234/256)
# Epoch: 92 | Time Per Epoch: 00:20 | train acc: 83.56 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 93
# 0 196 Loss: 0.296 | Acc: 95.356% (244/256)
# 0 40 Loss: 0.359 | Acc: 90.625% (232/256)
# Epoch: 93 | Time Per Epoch: 00:19 | train acc: 83.31 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 94
# 0 196 Loss: 0.993 | Acc: 74.187% (189/256)
# 0 40 Loss: 0.373 | Acc: 91.016% (233/256)
# Epoch: 94 | Time Per Epoch: 00:20 | train acc: 83.11 | test acc: 89.49% | Learning Rate: 1e-05
#
# Epoch: 95
# 0 196 Loss: 0.107 | Acc: 98.615% (252/256)
# 0 40 Loss: 0.364 | Acc: 90.234% (231/256)
# Epoch: 95 | Time Per Epoch: 00:19 | train acc: 83.56 | test acc: 89.75% | Learning Rate: 1e-05
#
# Epoch: 96
# 0 196 Loss: 0.056 | Acc: 99.350% (254/256)
# 0 40 Loss: 0.346 | Acc: 90.234% (231/256)
# Epoch: 96 | Time Per Epoch: 00:20 | train acc: 84.72 | test acc: 89.80% | Learning Rate: 1e-05
#
# Epoch: 97
# 0 196 Loss: 0.257 | Acc: 96.078% (245/256)
# 0 40 Loss: 0.368 | Acc: 90.625% (232/256)
# Epoch: 97 | Time Per Epoch: 00:19 | train acc: 82.76 | test acc: 89.64% | Learning Rate: 1e-05
#
# Epoch: 98
# 0 196 Loss: 0.432 | Acc: 92.648% (237/256)
# 0 40 Loss: 0.402 | Acc: 91.016% (233/256)
# Epoch: 98 | Time Per Epoch: 00:20 | train acc: 85.33 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 99
# 0 196 Loss: 1.033 | Acc: 71.108% (182/256)
# 0 40 Loss: 0.347 | Acc: 91.016% (233/256)
# Epoch: 99 | Time Per Epoch: 00:19 | train acc: 84.77 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 100
# 0 196 Loss: 0.741 | Acc: 84.280% (215/256)
# 0 40 Loss: 0.436 | Acc: 90.234% (231/256)
# Epoch: 100 | Time Per Epoch: 00:19 | train acc: 83.73 | test acc: 89.15% | Learning Rate: 1e-05
#
# Epoch: 101
# 0 196 Loss: 0.019 | Acc: 99.876% (255/256)
# 0 40 Loss: 0.362 | Acc: 91.016% (233/256)
# Epoch: 101 | Time Per Epoch: 00:20 | train acc: 81.98 | test acc: 89.90% | Learning Rate: 1e-05
#
# Epoch: 102
# 0 196 Loss: 0.230 | Acc: 96.617% (247/256)
# 0 40 Loss: 0.381 | Acc: 91.016% (233/256)
# Epoch: 102 | Time Per Epoch: 00:19 | train acc: 84.30 | test acc: 89.67% | Learning Rate: 1e-05
#
# Epoch: 103
# 0 196 Loss: 0.036 | Acc: 99.647% (255/256)
# 0 40 Loss: 0.404 | Acc: 91.797% (235/256)
# Epoch: 103 | Time Per Epoch: 00:19 | train acc: 84.45 | test acc: 89.35% | Learning Rate: 1e-05
#
# Epoch: 104
# 0 196 Loss: 0.424 | Acc: 92.927% (237/256)
# 0 40 Loss: 0.401 | Acc: 90.234% (231/256)
# Epoch: 104 | Time Per Epoch: 00:19 | train acc: 83.76 | test acc: 89.43% | Learning Rate: 1e-05
#
# Epoch: 105
# 0 196 Loss: 0.965 | Acc: 75.777% (193/256)
# 0 40 Loss: 0.395 | Acc: 90.234% (231/256)
# Epoch: 105 | Time Per Epoch: 00:19 | train acc: 83.28 | test acc: 89.51% | Learning Rate: 1e-05
#
# Epoch: 106
# 0 196 Loss: 1.002 | Acc: 72.689% (186/256)
# 0 40 Loss: 0.401 | Acc: 91.016% (233/256)
# Epoch: 106 | Time Per Epoch: 00:19 | train acc: 82.82 | test acc: 89.37% | Learning Rate: 1e-05
#
# Epoch: 107
# 0 196 Loss: 0.156 | Acc: 97.863% (250/256)
# 0 40 Loss: 0.355 | Acc: 90.234% (231/256)
# Epoch: 107 | Time Per Epoch: 00:19 | train acc: 85.28 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 108
# 0 196 Loss: 1.079 | Acc: 66.420% (170/256)
# 0 40 Loss: 0.329 | Acc: 91.406% (234/256)
# Epoch: 108 | Time Per Epoch: 00:20 | train acc: 85.55 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 109
# 0 196 Loss: 1.070 | Acc: 67.597% (173/256)
# 0 40 Loss: 0.396 | Acc: 91.016% (233/256)
# Epoch: 109 | Time Per Epoch: 00:19 | train acc: 83.81 | test acc: 89.19% | Learning Rate: 1e-05
#
# Epoch: 110
# 0 196 Loss: 1.228 | Acc: 52.610% (134/256)
# 0 40 Loss: 0.423 | Acc: 90.625% (232/256)
# Epoch: 110 | Time Per Epoch: 00:20 | train acc: 82.31 | test acc: 89.31% | Learning Rate: 1e-05
#
# Epoch: 111
# 0 196 Loss: 1.119 | Acc: 63.847% (163/256)
# 0 40 Loss: 0.350 | Acc: 89.453% (229/256)
# Epoch: 111 | Time Per Epoch: 00:19 | train acc: 83.19 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 112
# 0 196 Loss: 0.017 | Acc: 99.909% (255/256)
# 0 40 Loss: 0.344 | Acc: 90.625% (232/256)
# Epoch: 112 | Time Per Epoch: 00:19 | train acc: 83.55 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 113
# 0 196 Loss: 1.218 | Acc: 54.381% (139/256)
# 0 40 Loss: 0.395 | Acc: 90.625% (232/256)
# Epoch: 113 | Time Per Epoch: 00:20 | train acc: 82.06 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 114
# 0 196 Loss: 0.294 | Acc: 95.428% (244/256)
# 0 40 Loss: 0.355 | Acc: 90.625% (232/256)
# Epoch: 114 | Time Per Epoch: 00:19 | train acc: 84.01 | test acc: 89.56% | Learning Rate: 1e-05
#
# Epoch: 115
# 0 196 Loss: 0.039 | Acc: 99.621% (255/256)
# 0 40 Loss: 0.340 | Acc: 90.625% (232/256)
# Epoch: 115 | Time Per Epoch: 00:19 | train acc: 85.52 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 116
# 0 196 Loss: 0.588 | Acc: 88.379% (226/256)
# 0 40 Loss: 0.375 | Acc: 89.844% (230/256)
# Epoch: 116 | Time Per Epoch: 00:19 | train acc: 81.39 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 117
# 0 196 Loss: 0.064 | Acc: 99.276% (254/256)
# 0 40 Loss: 0.346 | Acc: 90.625% (232/256)
# Epoch: 117 | Time Per Epoch: 00:20 | train acc: 84.79 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 118
# 0 196 Loss: 1.202 | Acc: 58.559% (149/256)
# 0 40 Loss: 0.367 | Acc: 89.844% (230/256)
# Epoch: 118 | Time Per Epoch: 00:19 | train acc: 83.56 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 119
# 0 196 Loss: 0.867 | Acc: 78.293% (200/256)
# 0 40 Loss: 0.351 | Acc: 90.625% (232/256)
# Epoch: 119 | Time Per Epoch: 00:19 | train acc: 84.62 | test acc: 89.67% | Learning Rate: 1e-05
#
# Epoch: 120
# 0 196 Loss: 0.097 | Acc: 98.776% (252/256)
# 0 40 Loss: 0.386 | Acc: 89.844% (230/256)
# Epoch: 120 | Time Per Epoch: 00:20 | train acc: 83.93 | test acc: 89.45% | Learning Rate: 1e-05
#
# Epoch: 121
# 0 196 Loss: 1.167 | Acc: 56.637% (144/256)
# 0 40 Loss: 0.346 | Acc: 91.406% (234/256)
# Epoch: 121 | Time Per Epoch: 00:19 | train acc: 85.54 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 122
# 0 196 Loss: 0.648 | Acc: 86.934% (222/256)
# 0 40 Loss: 0.376 | Acc: 90.625% (232/256)
# Epoch: 122 | Time Per Epoch: 00:19 | train acc: 84.05 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 123
# 0 196 Loss: 0.832 | Acc: 81.335% (208/256)
# 0 40 Loss: 0.376 | Acc: 91.406% (234/256)
# Epoch: 123 | Time Per Epoch: 00:19 | train acc: 84.44 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 124
# 0 196 Loss: 0.527 | Acc: 90.080% (230/256)
# 0 40 Loss: 0.370 | Acc: 91.016% (233/256)
# Epoch: 124 | Time Per Epoch: 00:19 | train acc: 83.90 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 125
# 0 196 Loss: 0.019 | Acc: 99.925% (255/256)
# 0 40 Loss: 0.341 | Acc: 91.016% (233/256)
# Epoch: 125 | Time Per Epoch: 00:19 | train acc: 84.93 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 126
# 0 196 Loss: 1.214 | Acc: 54.047% (138/256)
# 0 40 Loss: 0.383 | Acc: 90.625% (232/256)
# Epoch: 126 | Time Per Epoch: 00:20 | train acc: 81.73 | test acc: 89.58% | Learning Rate: 1e-05
#
# Epoch: 127
# 0 196 Loss: 0.184 | Acc: 97.499% (249/256)
# 0 40 Loss: 0.379 | Acc: 91.016% (233/256)
# Epoch: 127 | Time Per Epoch: 00:20 | train acc: 85.13 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 128
# 0 196 Loss: 0.445 | Acc: 92.242% (236/256)
# 0 40 Loss: 0.351 | Acc: 90.625% (232/256)
# Epoch: 128 | Time Per Epoch: 00:19 | train acc: 83.02 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 129
# 0 196 Loss: 0.294 | Acc: 95.425% (244/256)
# 0 40 Loss: 0.364 | Acc: 89.844% (230/256)
# Epoch: 129 | Time Per Epoch: 00:19 | train acc: 82.38 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 130
# 0 196 Loss: 0.266 | Acc: 96.068% (245/256)
# 0 40 Loss: 0.336 | Acc: 90.625% (232/256)
# Epoch: 130 | Time Per Epoch: 00:20 | train acc: 85.43 | test acc: 89.75% | Learning Rate: 1e-05
#
# Epoch: 131
# 0 196 Loss: 0.853 | Acc: 79.056% (202/256)
# 0 40 Loss: 0.403 | Acc: 89.453% (229/256)
# Epoch: 131 | Time Per Epoch: 00:20 | train acc: 85.01 | test acc: 89.43% | Learning Rate: 1e-05
#
# Epoch: 132
# 0 196 Loss: 1.066 | Acc: 65.685% (168/256)
# 0 40 Loss: 0.342 | Acc: 91.016% (233/256)
# Epoch: 132 | Time Per Epoch: 00:19 | train acc: 84.63 | test acc: 89.71% | Learning Rate: 1e-05
#
# Epoch: 133
# 0 196 Loss: 0.800 | Acc: 82.113% (210/256)
# 0 40 Loss: 0.384 | Acc: 90.234% (231/256)
# Epoch: 133 | Time Per Epoch: 00:19 | train acc: 86.35 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 134
# 0 196 Loss: 1.237 | Acc: 51.678% (132/256)
# 0 40 Loss: 0.386 | Acc: 90.234% (231/256)
# Epoch: 134 | Time Per Epoch: 00:19 | train acc: 84.06 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 135
# 0 196 Loss: 0.363 | Acc: 94.065% (240/256)
# 0 40 Loss: 0.350 | Acc: 90.234% (231/256)
# Epoch: 135 | Time Per Epoch: 00:19 | train acc: 85.90 | test acc: 89.79% | Learning Rate: 1e-05
#
# Epoch: 136
# 0 196 Loss: 0.427 | Acc: 92.560% (236/256)
# 0 40 Loss: 0.331 | Acc: 91.406% (234/256)
# Saving..
# Epoch: 136 | Time Per Epoch: 00:20 | train acc: 84.80 | test acc: 89.98% | Learning Rate: 1e-05
#
# Epoch: 137
# 0 196 Loss: 0.663 | Acc: 86.802% (222/256)
# 0 40 Loss: 0.344 | Acc: 89.844% (230/256)
# Epoch: 137 | Time Per Epoch: 00:19 | train acc: 85.49 | test acc: 89.78% | Learning Rate: 1e-05
#
# Epoch: 138
# 0 196 Loss: 0.140 | Acc: 98.118% (251/256)
# 0 40 Loss: 0.345 | Acc: 90.625% (232/256)
# Epoch: 138 | Time Per Epoch: 00:19 | train acc: 83.51 | test acc: 89.67% | Learning Rate: 1e-05
#
# Epoch: 139
# 0 196 Loss: 0.311 | Acc: 95.071% (243/256)
# 0 40 Loss: 0.361 | Acc: 90.234% (231/256)
# Epoch: 139 | Time Per Epoch: 00:19 | train acc: 84.23 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 140
# 0 196 Loss: 0.012 | Acc: 99.994% (255/256)
# 0 40 Loss: 0.364 | Acc: 91.016% (233/256)
# Epoch: 140 | Time Per Epoch: 00:19 | train acc: 82.53 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 141
# 0 196 Loss: 0.364 | Acc: 93.985% (240/256)
# 0 40 Loss: 0.342 | Acc: 90.625% (232/256)
# Epoch: 141 | Time Per Epoch: 00:19 | train acc: 84.42 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 142
# 0 196 Loss: 1.200 | Acc: 53.324% (136/256)
# 0 40 Loss: 0.414 | Acc: 89.844% (230/256)
# Epoch: 142 | Time Per Epoch: 00:20 | train acc: 83.82 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 143
# 0 196 Loss: 0.862 | Acc: 80.435% (205/256)
# 0 40 Loss: 0.376 | Acc: 90.625% (232/256)
# Epoch: 143 | Time Per Epoch: 00:19 | train acc: 82.06 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 144
# 0 196 Loss: 0.820 | Acc: 81.436% (208/256)
# 0 40 Loss: 0.334 | Acc: 90.625% (232/256)
# Epoch: 144 | Time Per Epoch: 00:20 | train acc: 84.07 | test acc: 89.92% | Learning Rate: 1e-05
#
# Epoch: 145
# 0 196 Loss: 1.115 | Acc: 63.288% (162/256)
# 0 40 Loss: 0.335 | Acc: 90.625% (232/256)
# Epoch: 145 | Time Per Epoch: 00:20 | train acc: 85.10 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 146
# 0 196 Loss: 0.038 | Acc: 99.607% (254/256)
# 0 40 Loss: 0.349 | Acc: 91.406% (234/256)
# Epoch: 146 | Time Per Epoch: 00:18 | train acc: 84.61 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 147
# 0 196 Loss: 0.444 | Acc: 92.348% (236/256)
# 0 40 Loss: 0.351 | Acc: 90.625% (232/256)
# Epoch: 147 | Time Per Epoch: 00:19 | train acc: 84.92 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 148
# 0 196 Loss: 0.044 | Acc: 99.530% (254/256)
# 0 40 Loss: 0.364 | Acc: 89.844% (230/256)
# Epoch: 148 | Time Per Epoch: 00:20 | train acc: 84.68 | test acc: 89.79% | Learning Rate: 1e-05
#
# Epoch: 149
# 0 196 Loss: 0.108 | Acc: 98.589% (252/256)
# 0 40 Loss: 0.342 | Acc: 90.234% (231/256)
# Epoch: 149 | Time Per Epoch: 00:20 | train acc: 86.30 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 150
# 0 196 Loss: 0.796 | Acc: 81.981% (209/256)
# 0 40 Loss: 0.372 | Acc: 89.453% (229/256)
# Epoch: 150 | Time Per Epoch: 00:20 | train acc: 82.00 | test acc: 89.76% | Learning Rate: 1e-05
#
# Epoch: 151
# 0 196 Loss: 0.920 | Acc: 76.776% (196/256)
# 0 40 Loss: 0.379 | Acc: 91.016% (233/256)
# Epoch: 151 | Time Per Epoch: 00:20 | train acc: 85.64 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 152
# 0 196 Loss: 1.235 | Acc: 52.362% (134/256)
# 0 40 Loss: 0.364 | Acc: 89.844% (230/256)
# Epoch: 152 | Time Per Epoch: 00:20 | train acc: 86.56 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 153
# 0 196 Loss: 0.627 | Acc: 87.819% (224/256)
# 0 40 Loss: 0.366 | Acc: 89.453% (229/256)
# Epoch: 153 | Time Per Epoch: 00:19 | train acc: 83.47 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 154
# 0 196 Loss: 1.089 | Acc: 66.015% (168/256)
# 0 40 Loss: 0.400 | Acc: 89.453% (229/256)
# Epoch: 154 | Time Per Epoch: 00:19 | train acc: 82.91 | test acc: 89.47% | Learning Rate: 1e-05
#
# Epoch: 155
# 0 196 Loss: 1.208 | Acc: 53.493% (136/256)
# 0 40 Loss: 0.348 | Acc: 90.625% (232/256)
# Epoch: 155 | Time Per Epoch: 00:20 | train acc: 84.40 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 156
# 0 196 Loss: 0.326 | Acc: 94.812% (242/256)
# 0 40 Loss: 0.392 | Acc: 89.844% (230/256)
# Epoch: 156 | Time Per Epoch: 00:20 | train acc: 83.17 | test acc: 89.41% | Learning Rate: 1e-05
#
# Epoch: 157
# 0 196 Loss: 0.359 | Acc: 94.018% (240/256)
# 0 40 Loss: 0.352 | Acc: 90.234% (231/256)
# Epoch: 157 | Time Per Epoch: 00:20 | train acc: 84.45 | test acc: 89.92% | Learning Rate: 1e-05
#
# Epoch: 158
# 0 196 Loss: 1.155 | Acc: 59.096% (151/256)
# 0 40 Loss: 0.407 | Acc: 89.453% (229/256)
# Epoch: 158 | Time Per Epoch: 00:19 | train acc: 83.80 | test acc: 89.42% | Learning Rate: 1e-05
#
# Epoch: 159
# 0 196 Loss: 1.163 | Acc: 57.027% (145/256)
# 0 40 Loss: 0.344 | Acc: 91.016% (233/256)
# Epoch: 159 | Time Per Epoch: 00:19 | train acc: 86.43 | test acc: 89.74% | Learning Rate: 1e-05
#
# Epoch: 160
# 0 196 Loss: 0.074 | Acc: 99.144% (253/256)
# 0 40 Loss: 0.353 | Acc: 90.625% (232/256)
# Epoch: 160 | Time Per Epoch: 00:20 | train acc: 82.95 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 161
# 0 196 Loss: 0.304 | Acc: 95.205% (243/256)
# 0 40 Loss: 0.379 | Acc: 89.844% (230/256)
# Epoch: 161 | Time Per Epoch: 00:19 | train acc: 84.29 | test acc: 89.71% | Learning Rate: 1e-05
#
# Epoch: 162
# 0 196 Loss: 0.054 | Acc: 99.375% (254/256)
# 0 40 Loss: 0.381 | Acc: 90.234% (231/256)
# Epoch: 162 | Time Per Epoch: 00:19 | train acc: 83.44 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 163
# 0 196 Loss: 0.133 | Acc: 98.216% (251/256)
# 0 40 Loss: 0.351 | Acc: 91.016% (233/256)
# Epoch: 163 | Time Per Epoch: 00:20 | train acc: 84.90 | test acc: 89.71% | Learning Rate: 1e-05
#
# Epoch: 164
# 0 196 Loss: 0.065 | Acc: 99.209% (253/256)
# 0 40 Loss: 0.366 | Acc: 90.625% (232/256)
# Epoch: 164 | Time Per Epoch: 00:20 | train acc: 83.59 | test acc: 89.66% | Learning Rate: 1e-05
#
# Epoch: 165
# 0 196 Loss: 1.148 | Acc: 54.225% (138/256)
# 0 40 Loss: 0.410 | Acc: 89.062% (228/256)
# Epoch: 165 | Time Per Epoch: 00:20 | train acc: 83.32 | test acc: 89.56% | Learning Rate: 1e-05
#
# Epoch: 166
# 0 196 Loss: 0.712 | Acc: 85.659% (219/256)
# 0 40 Loss: 0.360 | Acc: 91.406% (234/256)
# Epoch: 166 | Time Per Epoch: 00:19 | train acc: 82.51 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 167
# 0 196 Loss: 0.103 | Acc: 98.668% (252/256)
# 0 40 Loss: 0.381 | Acc: 89.453% (229/256)
# Epoch: 167 | Time Per Epoch: 00:20 | train acc: 84.28 | test acc: 89.46% | Learning Rate: 1e-05
#
# Epoch: 168
# 0 196 Loss: 0.169 | Acc: 97.669% (250/256)
# 0 40 Loss: 0.327 | Acc: 91.406% (234/256)
# Epoch: 168 | Time Per Epoch: 00:20 | train acc: 86.76 | test acc: 89.69% | Learning Rate: 1e-05
#
# Epoch: 169
# 0 196 Loss: 1.164 | Acc: 55.340% (141/256)
# 0 40 Loss: 0.385 | Acc: 89.844% (230/256)
# Epoch: 169 | Time Per Epoch: 00:20 | train acc: 84.05 | test acc: 89.41% | Learning Rate: 1e-05
#
# Epoch: 170
# 0 196 Loss: 0.398 | Acc: 93.260% (238/256)
# 0 40 Loss: 0.356 | Acc: 89.453% (229/256)
# Epoch: 170 | Time Per Epoch: 00:19 | train acc: 83.88 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 171
# 0 196 Loss: 0.564 | Acc: 89.312% (228/256)
# 0 40 Loss: 0.327 | Acc: 90.234% (231/256)
# Epoch: 171 | Time Per Epoch: 00:19 | train acc: 83.97 | test acc: 89.74% | Learning Rate: 1e-05
#
# Epoch: 172
# 0 196 Loss: 0.644 | Acc: 86.952% (222/256)
# 0 40 Loss: 0.370 | Acc: 89.844% (230/256)
# Epoch: 172 | Time Per Epoch: 00:19 | train acc: 83.37 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 173
# 0 196 Loss: 0.236 | Acc: 96.432% (246/256)
# 0 40 Loss: 0.347 | Acc: 90.625% (232/256)
# Epoch: 173 | Time Per Epoch: 00:20 | train acc: 83.83 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 174
# 0 196 Loss: 0.043 | Acc: 99.528% (254/256)
# 0 40 Loss: 0.369 | Acc: 90.234% (231/256)
# Epoch: 174 | Time Per Epoch: 00:19 | train acc: 84.61 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 175
# 0 196 Loss: 0.014 | Acc: 99.952% (255/256)
# 0 40 Loss: 0.365 | Acc: 89.453% (229/256)
# Epoch: 175 | Time Per Epoch: 00:19 | train acc: 85.29 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 176
# 0 196 Loss: 0.027 | Acc: 99.760% (255/256)
# 0 40 Loss: 0.353 | Acc: 90.625% (232/256)
# Epoch: 176 | Time Per Epoch: 00:19 | train acc: 84.28 | test acc: 89.53% | Learning Rate: 1e-05
#
# Epoch: 177
# 0 196 Loss: 0.058 | Acc: 99.312% (254/256)
# 0 40 Loss: 0.372 | Acc: 90.234% (231/256)
# Epoch: 177 | Time Per Epoch: 00:19 | train acc: 84.72 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 178
# 0 196 Loss: 0.210 | Acc: 96.955% (248/256)
# 0 40 Loss: 0.355 | Acc: 91.406% (234/256)
# Epoch: 178 | Time Per Epoch: 00:20 | train acc: 83.65 | test acc: 89.84% | Learning Rate: 1e-05
#
# Epoch: 179
# 0 196 Loss: 0.925 | Acc: 75.764% (193/256)
# 0 40 Loss: 0.345 | Acc: 91.797% (235/256)
# Epoch: 179 | Time Per Epoch: 00:19 | train acc: 84.45 | test acc: 89.94% | Learning Rate: 1e-05
#
# Epoch: 180
# 0 196 Loss: 0.466 | Acc: 91.784% (234/256)
# 0 40 Loss: 0.342 | Acc: 90.625% (232/256)
# Epoch: 180 | Time Per Epoch: 00:19 | train acc: 83.81 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 181
# 0 196 Loss: 0.295 | Acc: 95.450% (244/256)
# 0 40 Loss: 0.356 | Acc: 90.234% (231/256)
# Epoch: 181 | Time Per Epoch: 00:20 | train acc: 84.01 | test acc: 89.52% | Learning Rate: 1e-05
#
# Epoch: 182
# 0 196 Loss: 0.671 | Acc: 85.934% (219/256)
# 0 40 Loss: 0.361 | Acc: 90.234% (231/256)
# Epoch: 182 | Time Per Epoch: 00:20 | train acc: 82.16 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 183
# 0 196 Loss: 1.174 | Acc: 52.489% (134/256)
# 0 40 Loss: 0.352 | Acc: 90.234% (231/256)
# Epoch: 183 | Time Per Epoch: 00:19 | train acc: 85.04 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 184
# 0 196 Loss: 1.149 | Acc: 52.736% (135/256)
# 0 40 Loss: 0.409 | Acc: 89.062% (228/256)
# Epoch: 184 | Time Per Epoch: 00:19 | train acc: 83.15 | test acc: 89.55% | Learning Rate: 1e-05
#
# Epoch: 185
# 0 196 Loss: 0.912 | Acc: 76.266% (195/256)
# 0 40 Loss: 0.406 | Acc: 90.234% (231/256)
# Epoch: 185 | Time Per Epoch: 00:19 | train acc: 84.17 | test acc: 89.52% | Learning Rate: 1e-05
#
# Epoch: 186
# 0 196 Loss: 0.212 | Acc: 96.924% (248/256)
# 0 40 Loss: 0.348 | Acc: 90.625% (232/256)
# Epoch: 186 | Time Per Epoch: 00:19 | train acc: 83.09 | test acc: 89.86% | Learning Rate: 1e-05
#
# Epoch: 187
# 0 196 Loss: 1.177 | Acc: 54.990% (140/256)
# 0 40 Loss: 0.379 | Acc: 90.234% (231/256)
# Epoch: 187 | Time Per Epoch: 00:19 | train acc: 83.51 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 188
# 0 196 Loss: 0.720 | Acc: 84.650% (216/256)
# 0 40 Loss: 0.339 | Acc: 91.016% (233/256)
# Epoch: 188 | Time Per Epoch: 00:20 | train acc: 85.01 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 189
# 0 196 Loss: 0.296 | Acc: 95.405% (244/256)
# 0 40 Loss: 0.369 | Acc: 89.844% (230/256)
# Epoch: 189 | Time Per Epoch: 00:20 | train acc: 84.81 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 190
# 0 196 Loss: 0.888 | Acc: 77.439% (198/256)
# 0 40 Loss: 0.368 | Acc: 90.625% (232/256)
# Epoch: 190 | Time Per Epoch: 00:20 | train acc: 85.74 | test acc: 89.64% | Learning Rate: 1e-05
#
# Epoch: 191
# 0 196 Loss: 0.066 | Acc: 99.239% (254/256)
# 0 40 Loss: 0.365 | Acc: 89.844% (230/256)
# Epoch: 191 | Time Per Epoch: 00:20 | train acc: 83.99 | test acc: 89.66% | Learning Rate: 1e-05
#
# Epoch: 192
# 0 196 Loss: 1.052 | Acc: 65.840% (168/256)
# 0 40 Loss: 0.391 | Acc: 89.062% (228/256)
# Epoch: 192 | Time Per Epoch: 00:19 | train acc: 84.65 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 193
# 0 196 Loss: 0.175 | Acc: 97.511% (249/256)
# 0 40 Loss: 0.336 | Acc: 90.234% (231/256)
# Saving..
# Epoch: 193 | Time Per Epoch: 00:20 | train acc: 82.27 | test acc: 89.99% | Learning Rate: 1e-05
#
# Epoch: 194
# 0 196 Loss: 0.983 | Acc: 73.654% (188/256)
# 0 40 Loss: 0.323 | Acc: 90.234% (231/256)
# Epoch: 194 | Time Per Epoch: 00:20 | train acc: 84.95 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 195
# 0 196 Loss: 0.134 | Acc: 98.206% (251/256)
# 0 40 Loss: 0.356 | Acc: 90.625% (232/256)
# Epoch: 195 | Time Per Epoch: 00:19 | train acc: 83.35 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 196
# 0 196 Loss: 0.048 | Acc: 99.501% (254/256)
# 0 40 Loss: 0.344 | Acc: 90.234% (231/256)
# Epoch: 196 | Time Per Epoch: 00:20 | train acc: 82.75 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 197
# 0 196 Loss: 1.196 | Acc: 51.001% (130/256)
# 0 40 Loss: 0.345 | Acc: 90.625% (232/256)
# Epoch: 197 | Time Per Epoch: 00:20 | train acc: 84.43 | test acc: 89.74% | Learning Rate: 1e-05
#
# Epoch: 198
# 0 196 Loss: 0.034 | Acc: 99.660% (255/256)
# 0 40 Loss: 0.393 | Acc: 89.453% (229/256)
# Epoch: 198 | Time Per Epoch: 00:20 | train acc: 85.31 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 199
# 0 196 Loss: 0.070 | Acc: 99.145% (253/256)
# 0 40 Loss: 0.337 | Acc: 90.234% (231/256)
# Epoch: 199 | Time Per Epoch: 00:17 | train acc: 83.68 | test acc: 89.89% | Learning Rate: 1e-05
#
# Epoch: 200
# 0 196 Loss: 0.061 | Acc: 99.269% (254/256)
# 0 40 Loss: 0.352 | Acc: 89.844% (230/256)
# Epoch: 200 | Time Per Epoch: 00:10 | train acc: 83.79 | test acc: 89.74% | Learning Rate: 1e-05

# %%
# plot results
results = pd.read_csv('./results/ResNet_mixup_alpha_p4.csv', sep=',')
results.head()
# Out:
#    epoch  train loss  train acc  test loss   test acc
# 0      1    1.755973  39.545155   1.454792  50.790001
# 1      2    1.393289  54.979294   1.016780  66.379997
# 2      3    1.250802  61.282890   0.941492  68.260002
# 3      4    1.188232  64.353737   0.813970  74.620003
# 4      5    1.093622  67.896767   1.090286  65.849998

# %%
train_accuracy = results['train acc'].values
test_accuracy = results['test acc'].values

print(f"Average test Accuracy over {end_apochs} epochs: {sum(test_accuracy)//len(test_accuracy)}")
print(f"best test accuraccy over {end_apochs} epochs: {max(test_accuracy)}")
# Out:
# Average test Accuracy over 200 epochs: 88.0
# best test accuraccy over 200 epochs: 89.98999786376953

# %%
figureName = 'WithMixUp' # change figure name

plt.figure(figsize=(9, 6))
plt.plot(sorted(results['epoch'].values), train_accuracy, label='train')
plt.plot(sorted(results['epoch'].values), test_accuracy, label='test')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.title(f'Train/Test Accuracy curve for {end_apochs} epochs')
# plt.savefig(f'/content/results/{figureName}.png')
plt.legend()
plt.show()
