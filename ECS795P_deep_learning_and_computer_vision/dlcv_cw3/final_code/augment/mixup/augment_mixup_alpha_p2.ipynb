# %%
# imports
import os
import csv
import time
import multiprocessing

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
from torch.autograd import Variable

import torchvision
import torchvision.transforms as transforms

# %%
# @title Set random seed

# @markdown Executing `set_seed(seed=seed)` you are setting the seed

# for DL its critical to set the random seed so that students can have a
# baseline to compare their results to expected results.
# Read more here: https://pytorch.org/docs/stable/notes/randomness.html

# Call `set_seed` function in the exercises to ensure reproducibility.
import random
import torch

def set_seed(seed=None, seed_torch=True):
    if seed is None:
        seed = np.random.choice(2 ** 32)
    random.seed(seed)
    np.random.seed(seed)
    if seed_torch:
        torch.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.cuda.manual_seed(seed)
        torch.backends.cudnn.benchmark = False
        torch.backends.cudnn.deterministic = True
    
    print(f'Random seed {seed} has been set.')

# In case that `DataLoader` is used
def seed_worker(worker_id):
    worker_seed = torch.initial_seed() % 2**32
    np.random.seed(worker_seed)
    random.seed(worker_seed)

# %%
# @title Set device (GPU or CPU)

# inform the user if the notebook uses GPU or CPU.

def set_device():
    device = "cuda" if torch.cuda.is_available() else "cpu"
    if device != "cuda":
        print("WARNING: For this notebook to perform best, "
        "if possible, in the menu under `Runtime` -> "
        "`Change runtime type.`  select `GPU` ")
    else:
        print("GPU is enabled in this notebook.")

    return device

# %%
set_seed(seed=2021)
set_device()
# Out:
# Random seed 2021 has been set.
# GPU is enabled in this notebook.
# 'cuda'

# %%
# hyper-parameters
use_cuda = torch.cuda.is_available()
alpha = 0.2  # alpha for mixup augmentation
best_acc = 0  # best test accuracy
start_epoch = 0  # start from epoch 0 or last checkpoint epoch
batch_size = 256
end_apochs = 200  # Please change this to 200
base_learning_rate = 1e-3
cutout = False  # True/False if you want to use cutout augmentation
mixup = True  # True/False if you want to use mixup augmentation
n_holes = 1  # number of holes to cut out from image for cutout
length = 16  # length of the holes for cutout augmentation
torchvision_transforms = False  # True/False if you want use torchvision augmentations

# %%
# @markdown `Cutout` Augmentation class

class Cutout(object):
  """
  code from: https://github.com/uoguelph-mlrg/Cutout

  Randomly mask out one or more patches from an image.
  Args:
      n_holes (int): Number of patches to cut out of each image.
      length (int): The length (in pixels) of each square patch.
  """
  def __init__(self, n_holes, length):
    self.n_holes = n_holes
    self.length = length

  def __call__(self, img):
    """
    Args:
        img (Tensor): Tensor image of size (C, H, W).
    Returns:
        Tensor: Image with n_holes of dimension length x length cut out of it.
    """
    h = img.size(1)
    w = img.size(2)

    mask = np.ones((h, w), np.float32)

    for n in range(self.n_holes):
      y = np.random.randint(h)
      x = np.random.randint(w)

      y1 = np.clip(y - self.length // 2, 0, h)
      y2 = np.clip(y + self.length // 2, 0, h)
      x1 = np.clip(x - self.length // 2, 0, w)
      x2 = np.clip(x + self.length // 2, 0, w)

      mask[y1: y2, x1: x2] = 0.

    mask = torch.from_numpy(mask)
    mask = mask.expand_as(img)
    img = img * mask

    return img

# %%
# @markdown `mixup_data` Augmentation function

def mixup_data(x, y, alpha=1.0, use_cuda=True):
  '''Compute the mixup data. Return mixed inputs, pairs of targets, and lambda
      - https://github.com/hongyi-zhang/mixup
  '''
  if alpha > 0.:
    lam = np.random.beta(alpha, alpha)
  else:
    lam = 1.
  batch_size = x.size()[0]
  if use_cuda:
    index = torch.randperm(batch_size).cuda()
  else:
    index = torch.randperm(batch_size)

  mixed_x = lam * x + (1 - lam) * x[index, :]
  y_a, y_b = y, y[index]

  return mixed_x, y_a, y_b, lam

# %%
# @markdown Download and prepare Data
print('==> Preparing data...')
def percentageSplit(full_dataset, percent=0.0):
  set1_size = int(percent * len(full_dataset))
  set2_size = len(full_dataset) - set1_size
  final_dataset, _ = torch.utils.data.random_split(full_dataset,
                                                   [set1_size, set2_size])
  return final_dataset

# CIFAR normalizing
mean = [0.5071, 0.4866, 0.4409]
std = [0.2673, 0.2564, 0.2762]

# torchvision transforms
transform_train = transforms.Compose([])
if torchvision_transforms:
  transform_train.transforms.append(transforms.RandomCrop(32, padding=4))
  transform_train.transforms.append(transforms.RandomHorizontalFlip())

transform_train.transforms.append(transforms.ToTensor())
transform_train.transforms.append(transforms.Normalize(mean, std))

if cutout:
  transform_train.transforms.append(Cutout(n_holes=n_holes, length=length))

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(mean, std),
])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)
# Out:
# ==> Preparing data...
# Files already downloaded and verified
# Files already downloaded and verified

# %%
print(f"Object type: {type(trainset)}")
print(f"Training data shape: {trainset.data.shape}")
print(f"Test data shape: {testset.data.shape}")
print(f"Number of classes: {np.unique(trainset.targets).shape[0]}")
# Out:
# Object type: <class 'torchvision.datasets.cifar.CIFAR10'>
# Training data shape: (50000, 32, 32, 3)
# Test data shape: (10000, 32, 32, 3)
# Number of classes: 10

# %%
# choose percentage from the trainset. set percent = 1.0 to use the whole train data
percent = 1.0
trainset = percentageSplit(trainset, percent = percent)
print(f"size of the new trainset: {len(trainset)}")
# Out:
# size of the new trainset: 50000

# %%
# Dataloader
num_workers = multiprocessing.cpu_count()

print(f'----> number of workers: {num_workers}')

trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size, shuffle=True, num_workers=2)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size, shuffle=False, num_workers=2)
# Out:
# ----> number of workers: 96

# %%
# get batch of data
batch_X, batch_Y =  next(iter(trainloader))

# %%
def plot_mixed_images(images):
  inv_normalize = transforms.Normalize(
                      mean= [-m/s for m, s in zip(mean, std)],
                      std= [1/s for s in std]
                      )
  inv_PIL = transforms.ToPILImage()
  fig = plt.figure(figsize=(10, 8))
  for i in range(1, len(images) + 1):
    image = images[i-1]
    ax = fig.add_subplot(1, 4, i)
    inv_tensor = inv_normalize(image).cpu()
    ax.imshow(inv_PIL(inv_tensor))
  plt.show()

# %%
# Mixup Visualization
if mixup:
    alpha = 0.2
    mixed_x, y_a, y_b, lam = mixup_data(batch_X.cuda(), batch_Y.cuda(), alpha=alpha, use_cuda=use_cuda)
    plot_mixed_images(mixed_x[:4])

# %%
# Mixup Visualization
if cutout:
    plot_mixed_images(batch_X[:4])

# %%
# @markdown ResNet model in PyTorch

class Bottleneck(nn.Module):
    """
    For deep networks, we use BottleNeck, which is proposed in the paper to have approximate computational complexity but save a lot of resources
    zip_channels: The compressed dimension, the final output dimension is expansion * zip_channels
    For the network structure of ResNet50/101/152, mainly because the third layer is 4 times the second layer, so expansion=4
    """
    expansion = 4

    def __init__(self, in_channels, zip_channels, stride=1):
        super(Bottleneck, self).__init__()
        out_channels = self.expansion * zip_channels
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, zip_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, zip_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(zip_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(zip_channels, out_channels, kernel_size=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(out_channels)
            )

    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out

class BasicBlock(nn.Module):
    """
    For shallow networks, such as ResNet-18/34, etc., use the basic Block
    The base module is not compressed, so expansion=1
    """
    expansion = 1
    def __init__(self, in_channels, out_channels, stride=1):
        super(BasicBlock,self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(in_channels, out_channels, kernel_size=3, stride=stride, padding=1, bias=False),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(True),
            nn.Conv2d(out_channels,out_channels, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(out_channels)
        )
        # If the input and output dimensions are not equal, use a 1x1 convolutional layer to change the dimension
        self.shortcut = nn.Sequential()
        if stride != 1 or in_channels != self.expansion * out_channels:
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_channels, self.expansion * out_channels, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(self.expansion * out_channels),
            )
    def forward(self, x):
        out = self.features(x)
# print(out.shape)
        out += self.shortcut(x)
        out = torch.relu(out)
        return out


class ResNet(nn.Module):
    """
    Different ResNet architectures are unified with one layer of feature extraction and four layers of residuals, and the difference lies in the depth of each layer of residuals.
    For cifar10, the change of feature map size is as follows:
    (32, 32, 3) -> [Conv2d] -> (32, 32, 64) -> [Res1] -> (32, 32, 64) -> [Res2]
 -> (16, 16, 128) -> [Res3] -> (8, 8, 256) ->[Res4] -> (4, 4, 512) -> [AvgPool]
 -> (1, 1, 512) -> [Reshape] -> (512) -> [Linear] -> (10)
    """
    def __init__(self, block, num_blocks, num_classes=10, verbose = False):
        super(ResNet, self).__init__()
        self.verbose = verbose
        self.in_channels = 64
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )
        #Use the _make_layer function to generate the structure of conv2_x, conv3_x, conv4_x, conv5_x corresponding to the above table
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        # After cifar10 goes through the above structure, the feature map size here is 4 x 4 x 512 x expansion
        # So 4 x 4 average pooling is used here
        self.avg_pool = nn.AvgPool2d(kernel_size=4)
        self.classifer = nn.Linear(512 *block.expansion, num_classes)

    def _make_layer(self, block, out_channels, num_blocks, stride):
        # The first block needs to be downsampled
        strides = [stride] + [1]* (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_channels, out_channels, stride))
            # If it is Bottleneck Block, you need to compress the input dimension of each layer, and then increase the dimension after compression
            # So the input dimension of each layer should also change accordingly
            self.in_channels = out_channels * block.expansion
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.features(x)
        if self.verbose:
            print('block 1 output: {}'.format(out.shape))
        out = self.layer1(out)
        if self.verbose:
            print('block 2 output: {}'.format(out.shape))
        out = self.layer2(out)
        if self.verbose:
            print('block 3 output: {}'.format(out.shape))
        out = self.layer3(out)
        if self.verbose:
            print('block 4 output: {}'.format(out.shape))
        out = self.layer4(out)
        if self.verbose:
            print('block 5 output: {}'.format(out.shape))
        out = self.avg_pool(out)
        out = out.view(out.size(0), -1)
        out = self.classifer(out)
        return out


def ResNet18(verbose=False):
    return ResNet(BasicBlock, [2,2,2,2],verbose=verbose)

def ResNet34(verbose=False):
    return ResNet(BasicBlock, [3,4,6,3],verbose=verbose)

def ResNet50(verbose=False):
    return ResNet(Bottleneck, [3,4,6,3],verbose=verbose)

def ResNet101(verbose=False):
    return ResNet(Bottleneck, [3,4,23,3],verbose=verbose)

def ResNet152(verbose=False):
    return ResNet(Bottleneck, [3,8,36,3],verbose=verbose)

# %%
# load the Model
net = ResNet18()
print('-----> verify if model is run on random data')
y = net(Variable(torch.randn(1,3,32,32)))
print('model loaded')

result_folder = './results/'
if not os.path.exists(result_folder):
    os.makedirs(result_folder)

logname = result_folder + net.__class__.__name__ + '_' + 'mixup_alpha_p2.csv'

if use_cuda:
  net.cuda()
  net = torch.nn.DataParallel(net)
  print('Using', torch.cuda.device_count(), 'GPUs.')
  cudnn.benchmark = True
  print('Using CUDA..')
# Out:
# -----> verify if model is run on random data
# model loaded
# Using 1 GPUs.
# Using CUDA..

# %%
# optimizer and criterion

def mixup_criterion(y_a, y_b, lam):
  '''
    - Mixup criterion
    - https://github.com/hongyi-zhang/mixup
  '''
  return lambda criterion, pred: lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

criterion = nn.CrossEntropyLoss()  # only for test data
optimizer = optim.Adam(net.parameters(), lr=base_learning_rate, weight_decay=5e-4)
scheduler = optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor=0.1, patience=10, min_lr=1e-5)

# %%
# Training & Test functions
def train(epoch, alpha, use_cuda=False):
  print('\nEpoch: %d' % epoch)
  net.train()
  train_loss = 0
  correct = 0
  total = 0
  for batch_idx, (inputs, targets) in enumerate(trainloader):
    if use_cuda:
      inputs, targets = inputs.cuda(), targets.cuda()
    optimizer.zero_grad()
    if mixup:
      # generate mixed inputs, two one-hot label vectors and mixing coefficient
      inputs, targets_a, targets_b, lam = mixup_data(inputs, targets, alpha, use_cuda)
      inputs, targets_a, targets_b = Variable(inputs), Variable(targets_a), Variable(targets_b)
      outputs = net(inputs)
      loss_func = mixup_criterion(targets_a, targets_b, lam)
      loss = loss_func(criterion, outputs)
    else:
      inputs, targets = Variable(inputs), Variable(targets)
      outputs = net(inputs)
      loss = criterion(outputs, targets)

    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    _, predicted = torch.max(outputs.data, 1)
    total += targets.size(0)

    if mixup:
      correct += lam * predicted.eq(targets_a.data).cpu().sum() + (1 - lam) * predicted.eq(targets_b.data).cpu().sum()
    else:
      correct += predicted.eq(targets.data).cpu().sum()

    if batch_idx % 500 == 0:
      print(batch_idx, len(trainloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
          % (train_loss/(batch_idx+1), 100.*correct/total, correct, total))
  return (train_loss/batch_idx, 100.*correct/total)


def test(epoch, use_cuda=False):
  global best_acc
  net.eval()
  test_loss = 0
  correct = 0
  total = 0
  with torch.no_grad():
    for batch_idx, (inputs, targets) in enumerate(testloader):
      if use_cuda:
        inputs, targets = inputs.cuda(), targets.cuda()
      # inputs, targets = Variable(inputs, volatile=True), Variable(targets)
      outputs = net(inputs)
      loss = criterion(outputs, targets)

      test_loss += loss.item()
      _, predicted = torch.max(outputs.data, 1)
      total += targets.size(0)
      correct += predicted.eq(targets.data).cpu().sum()

      if batch_idx % 200 == 0:
        print(batch_idx, len(testloader), 'Loss: %.3f | Acc: %.3f%% (%d/%d)'
            % (test_loss/(batch_idx+1), 100.*correct/total, correct, total))

  # Save checkpoint.
  acc = 100.*correct/total
  if acc > best_acc:
    best_acc = acc
    checkpoint(acc, epoch)
  return (test_loss/batch_idx, 100.*correct/total)

# %%
# @markdown `checkpoint` and `adjust_learning_rate` functions
def checkpoint(acc, epoch):
  # Save checkpoint.
  print('Saving..')
  state = {
      'net': net.state_dict(),
      'acc': acc,
      'epoch': epoch,
      'rng_state': torch.get_rng_state()
      }
  if not os.path.isdir('checkpoint'):
    os.mkdir('checkpoint')
  torch.save(state, './checkpoint/ckpt.t7')


def adjust_learning_rate(optimizer, epoch):
  """decrease the learning rate at 100 and 150 epoch"""
  lr = base_learning_rate
  if epoch <= 9 and lr > 0.1:
    # warm-up training for large minibatch
    lr = 0.1 + (base_learning_rate - 0.1) * epoch / 10.
  if epoch >= 100:
    lr /= 10
  if epoch >= 150:
    lr /= 10
  for param_group in optimizer.param_groups:
    param_group['lr'] = lr

# %%
# start training
if not os.path.exists(logname):
  with open(logname, 'w') as logfile:
    logwriter = csv.writer(logfile, delimiter=',')
    logwriter.writerow(['epoch', 'train loss', 'train acc',
                        'test loss', 'test acc'])

for epoch in range(start_epoch+1, end_apochs+1):
  # adjust_learning_rate(optimizer, epoch)

    start = time.time()
    
    train_loss, train_acc = train(epoch, alpha, use_cuda=use_cuda)
    test_loss, test_acc = test(epoch, use_cuda=use_cuda)

    scheduler.step(test_loss)

    end = time.time()

    time_ = int(end - start)
    h = time_ / 3600
    m = time_ % 3600 /60
    s = time_ % 60
    time_str = "%02d:%02d" % (m, s)
    
    with open(logname, 'a') as logfile:
        logwriter = csv.writer(logfile, delimiter=',')
        logwriter.writerow([epoch, train_loss, train_acc.item(),
                            test_loss, test_acc.item()])
    print(f"Epoch: {epoch} | Time Per Epoch: {time_str} | train acc: {train_acc:.2f} | test acc: {test_acc:.2f}% | Learning Rate: {optimizer.param_groups[0]['lr']}")
# Out:
# Epoch: 1
# /opt/conda/lib/python3.10/site-packages/torch/nn/modules/conv.py:456: UserWarning: Applied workaround for CuDNN issue, install nvrtc.so (Triggered internally at ../aten/src/ATen/native/cudnn/Conv_v8.cpp:80.)
#   return F.conv2d(input, weight, bias, self.stride,
# 0 196 Loss: 2.411 | Acc: 7.799% (19/256)
# 0 40 Loss: 1.391 | Acc: 50.391% (129/256)
# Saving..
# Epoch: 1 | Time Per Epoch: 00:16 | train acc: 41.30 | test acc: 50.98% | Learning Rate: 0.001
#
# Epoch: 2
# 0 196 Loss: 1.247 | Acc: 57.993% (148/256)
# 0 40 Loss: 1.053 | Acc: 64.453% (165/256)
# Saving..
# Epoch: 2 | Time Per Epoch: 00:15 | train acc: 59.13 | test acc: 66.95% | Learning Rate: 0.001
#
# Epoch: 3
# 0 196 Loss: 0.907 | Acc: 70.107% (179/256)
# 0 40 Loss: 0.984 | Acc: 69.922% (179/256)
# Saving..
# Epoch: 3 | Time Per Epoch: 00:16 | train acc: 64.69 | test acc: 67.02% | Learning Rate: 0.001
#
# Epoch: 4
# 0 196 Loss: 1.081 | Acc: 72.207% (184/256)
# 0 40 Loss: 0.813 | Acc: 75.000% (192/256)
# Saving..
# Epoch: 4 | Time Per Epoch: 00:16 | train acc: 69.38 | test acc: 73.53% | Learning Rate: 0.001
#
# Epoch: 5
# 0 196 Loss: 1.451 | Acc: 56.243% (143/256)
# 0 40 Loss: 0.777 | Acc: 75.000% (192/256)
# Epoch: 5 | Time Per Epoch: 00:15 | train acc: 71.91 | test acc: 73.32% | Learning Rate: 0.001
#
# Epoch: 6
# 0 196 Loss: 0.870 | Acc: 77.078% (197/256)
# 0 40 Loss: 0.653 | Acc: 79.297% (203/256)
# Saving..
# Epoch: 6 | Time Per Epoch: 00:16 | train acc: 75.12 | test acc: 78.38% | Learning Rate: 0.001
#
# Epoch: 7
# 0 196 Loss: 1.495 | Acc: 56.715% (145/256)
# 0 40 Loss: 0.911 | Acc: 68.359% (175/256)
# Epoch: 7 | Time Per Epoch: 00:16 | train acc: 76.84 | test acc: 70.01% | Learning Rate: 0.001
#
# Epoch: 8
# 0 196 Loss: 1.678 | Acc: 57.750% (147/256)
# 0 40 Loss: 0.722 | Acc: 79.297% (203/256)
# Saving..
# Epoch: 8 | Time Per Epoch: 00:16 | train acc: 76.60 | test acc: 80.95% | Learning Rate: 0.001
#
# Epoch: 9
# 0 196 Loss: 0.515 | Acc: 86.989% (222/256)
# 0 40 Loss: 0.615 | Acc: 79.688% (204/256)
# Epoch: 9 | Time Per Epoch: 00:15 | train acc: 78.42 | test acc: 77.00% | Learning Rate: 0.001
#
# Epoch: 10
# 0 196 Loss: 0.319 | Acc: 89.413% (228/256)
# 0 40 Loss: 0.608 | Acc: 82.812% (212/256)
# Saving..
# Epoch: 10 | Time Per Epoch: 00:16 | train acc: 79.83 | test acc: 82.05% | Learning Rate: 0.001
#
# Epoch: 11
# 0 196 Loss: 0.332 | Acc: 93.746% (239/256)
# 0 40 Loss: 0.675 | Acc: 79.297% (203/256)
# Epoch: 11 | Time Per Epoch: 00:16 | train acc: 79.41 | test acc: 81.73% | Learning Rate: 0.001
#
# Epoch: 12
# 0 196 Loss: 0.429 | Acc: 90.171% (230/256)
# 0 40 Loss: 0.577 | Acc: 81.641% (209/256)
# Epoch: 12 | Time Per Epoch: 00:15 | train acc: 81.40 | test acc: 81.27% | Learning Rate: 0.001
#
# Epoch: 13
# 0 196 Loss: 0.371 | Acc: 91.783% (234/256)
# 0 40 Loss: 0.618 | Acc: 80.859% (207/256)
# Epoch: 13 | Time Per Epoch: 00:15 | train acc: 83.68 | test acc: 81.11% | Learning Rate: 0.001
#
# Epoch: 14
# 0 196 Loss: 0.671 | Acc: 86.790% (222/256)
# 0 40 Loss: 0.574 | Acc: 82.031% (210/256)
# Saving..
# Epoch: 14 | Time Per Epoch: 00:16 | train acc: 83.72 | test acc: 84.02% | Learning Rate: 0.001
#
# Epoch: 15
# 0 196 Loss: 1.594 | Acc: 48.449% (124/256)
# 0 40 Loss: 0.623 | Acc: 80.469% (206/256)
# Epoch: 15 | Time Per Epoch: 00:16 | train acc: 83.65 | test acc: 81.56% | Learning Rate: 0.001
#
# Epoch: 16
# 0 196 Loss: 0.301 | Acc: 92.636% (237/256)
# 0 40 Loss: 0.544 | Acc: 83.594% (214/256)
# Epoch: 16 | Time Per Epoch: 00:16 | train acc: 83.77 | test acc: 82.80% | Learning Rate: 0.001
#
# Epoch: 17
# 0 196 Loss: 0.171 | Acc: 96.845% (247/256)
# 0 40 Loss: 0.552 | Acc: 83.203% (213/256)
# Epoch: 17 | Time Per Epoch: 00:16 | train acc: 84.39 | test acc: 80.20% | Learning Rate: 0.001
#
# Epoch: 18
# 0 196 Loss: 1.718 | Acc: 45.609% (116/256)
# 0 40 Loss: 0.600 | Acc: 80.469% (206/256)
# Epoch: 18 | Time Per Epoch: 00:16 | train acc: 84.10 | test acc: 81.16% | Learning Rate: 0.001
#
# Epoch: 19
# 0 196 Loss: 1.001 | Acc: 79.626% (203/256)
# 0 40 Loss: 0.578 | Acc: 81.641% (209/256)
# Epoch: 19 | Time Per Epoch: 00:16 | train acc: 84.15 | test acc: 83.13% | Learning Rate: 0.001
#
# Epoch: 20
# 0 196 Loss: 0.124 | Acc: 97.266% (249/256)
# 0 40 Loss: 0.532 | Acc: 83.203% (213/256)
# Saving..
# Epoch: 20 | Time Per Epoch: 00:16 | train acc: 83.95 | test acc: 84.74% | Learning Rate: 0.001
#
# Epoch: 21
# 0 196 Loss: 0.155 | Acc: 95.293% (243/256)
# 0 40 Loss: 0.493 | Acc: 84.766% (217/256)
# Epoch: 21 | Time Per Epoch: 00:16 | train acc: 84.81 | test acc: 83.21% | Learning Rate: 0.001
#
# Epoch: 22
# 0 196 Loss: 0.124 | Acc: 97.266% (248/256)
# 0 40 Loss: 0.566 | Acc: 81.641% (209/256)
# Epoch: 22 | Time Per Epoch: 00:16 | train acc: 85.44 | test acc: 82.30% | Learning Rate: 0.001
#
# Epoch: 23
# 0 196 Loss: 0.441 | Acc: 92.310% (236/256)
# 0 40 Loss: 0.500 | Acc: 84.766% (217/256)
# Epoch: 23 | Time Per Epoch: 00:16 | train acc: 86.68 | test acc: 84.35% | Learning Rate: 0.001
#
# Epoch: 24
# 0 196 Loss: 0.140 | Acc: 97.964% (250/256)
# 0 40 Loss: 0.607 | Acc: 81.641% (209/256)
# Epoch: 24 | Time Per Epoch: 00:16 | train acc: 85.76 | test acc: 82.50% | Learning Rate: 0.001
#
# Epoch: 25
# 0 196 Loss: 0.245 | Acc: 95.532% (244/256)
# 0 40 Loss: 0.606 | Acc: 82.812% (212/256)
# Epoch: 25 | Time Per Epoch: 00:16 | train acc: 86.86 | test acc: 82.17% | Learning Rate: 0.001
#
# Epoch: 26
# 0 196 Loss: 1.619 | Acc: 46.539% (119/256)
# 0 40 Loss: 0.592 | Acc: 82.031% (210/256)
# Epoch: 26 | Time Per Epoch: 00:15 | train acc: 86.07 | test acc: 83.39% | Learning Rate: 0.001
#
# Epoch: 27
# 0 196 Loss: 0.308 | Acc: 96.464% (246/256)
# 0 40 Loss: 0.495 | Acc: 86.719% (222/256)
# Epoch: 27 | Time Per Epoch: 00:16 | train acc: 86.96 | test acc: 83.99% | Learning Rate: 0.001
#
# Epoch: 28
# 0 196 Loss: 0.553 | Acc: 89.666% (229/256)
# 0 40 Loss: 0.623 | Acc: 78.516% (201/256)
# Epoch: 28 | Time Per Epoch: 00:16 | train acc: 86.92 | test acc: 81.82% | Learning Rate: 0.001
#
# Epoch: 29
# 0 196 Loss: 0.101 | Acc: 98.040% (250/256)
# 0 40 Loss: 0.577 | Acc: 82.031% (210/256)
# Epoch: 29 | Time Per Epoch: 00:15 | train acc: 86.63 | test acc: 81.57% | Learning Rate: 0.001
#
# Epoch: 30
# 0 196 Loss: 0.116 | Acc: 96.875% (247/256)
# 0 40 Loss: 0.617 | Acc: 80.469% (206/256)
# Epoch: 30 | Time Per Epoch: 00:16 | train acc: 85.37 | test acc: 82.92% | Learning Rate: 0.001
#
# Epoch: 31
# 0 196 Loss: 1.389 | Acc: 57.475% (147/256)
# 0 40 Loss: 0.752 | Acc: 76.562% (196/256)
# Epoch: 31 | Time Per Epoch: 00:16 | train acc: 86.49 | test acc: 81.85% | Learning Rate: 0.0001
#
# Epoch: 32
# 0 196 Loss: 1.582 | Acc: 47.199% (120/256)
# 0 40 Loss: 0.416 | Acc: 87.500% (224/256)
# Saving..
# Epoch: 32 | Time Per Epoch: 00:16 | train acc: 89.21 | test acc: 88.13% | Learning Rate: 0.0001
#
# Epoch: 33
# 0 196 Loss: 0.020 | Acc: 99.996% (255/256)
# 0 40 Loss: 0.418 | Acc: 87.500% (224/256)
# Saving..
# Epoch: 33 | Time Per Epoch: 00:16 | train acc: 88.45 | test acc: 88.23% | Learning Rate: 0.0001
#
# Epoch: 34
# 0 196 Loss: 0.017 | Acc: 99.964% (255/256)
# 0 40 Loss: 0.405 | Acc: 87.891% (225/256)
# Saving..
# Epoch: 34 | Time Per Epoch: 00:16 | train acc: 90.55 | test acc: 88.90% | Learning Rate: 0.0001
#
# Epoch: 35
# 0 196 Loss: 0.047 | Acc: 99.527% (254/256)
# 0 40 Loss: 0.407 | Acc: 87.891% (225/256)
# Epoch: 35 | Time Per Epoch: 00:16 | train acc: 90.28 | test acc: 88.81% | Learning Rate: 0.0001
#
# Epoch: 36
# 0 196 Loss: 0.012 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.399 | Acc: 88.281% (226/256)
# Epoch: 36 | Time Per Epoch: 00:15 | train acc: 90.24 | test acc: 88.75% | Learning Rate: 0.0001
#
# Epoch: 37
# 0 196 Loss: 0.011 | Acc: 99.999% (255/256)
# 0 40 Loss: 0.387 | Acc: 89.453% (229/256)
# Saving..
# Epoch: 37 | Time Per Epoch: 00:16 | train acc: 90.68 | test acc: 89.02% | Learning Rate: 0.0001
#
# Epoch: 38
# 0 196 Loss: 0.052 | Acc: 99.423% (254/256)
# 0 40 Loss: 0.426 | Acc: 87.500% (224/256)
# Epoch: 38 | Time Per Epoch: 00:16 | train acc: 88.49 | test acc: 88.97% | Learning Rate: 0.0001
#
# Epoch: 39
# 0 196 Loss: 0.371 | Acc: 94.136% (240/256)
# 0 40 Loss: 0.390 | Acc: 88.281% (226/256)
# Saving..
# Epoch: 39 | Time Per Epoch: 00:16 | train acc: 91.01 | test acc: 89.06% | Learning Rate: 0.0001
#
# Epoch: 40
# 0 196 Loss: 0.090 | Acc: 98.871% (253/256)
# 0 40 Loss: 0.408 | Acc: 87.500% (224/256)
# Epoch: 40 | Time Per Epoch: 00:16 | train acc: 89.95 | test acc: 88.88% | Learning Rate: 0.0001
#
# Epoch: 41
# 0 196 Loss: 0.688 | Acc: 87.204% (223/256)
# 0 40 Loss: 0.412 | Acc: 87.500% (224/256)
# Epoch: 41 | Time Per Epoch: 00:15 | train acc: 90.33 | test acc: 88.80% | Learning Rate: 0.0001
#
# Epoch: 42
# 0 196 Loss: 0.075 | Acc: 99.097% (253/256)
# 0 40 Loss: 0.394 | Acc: 88.672% (227/256)
# Epoch: 42 | Time Per Epoch: 00:15 | train acc: 89.28 | test acc: 88.90% | Learning Rate: 0.0001
#
# Epoch: 43
# 0 196 Loss: 1.166 | Acc: 69.237% (177/256)
# 0 40 Loss: 0.427 | Acc: 88.281% (226/256)
# Epoch: 43 | Time Per Epoch: 00:16 | train acc: 91.18 | test acc: 89.00% | Learning Rate: 0.0001
#
# Epoch: 44
# 0 196 Loss: 0.518 | Acc: 92.847% (237/256)
# 0 40 Loss: 0.395 | Acc: 87.500% (224/256)
# Epoch: 44 | Time Per Epoch: 00:16 | train acc: 88.92 | test acc: 88.76% | Learning Rate: 0.0001
#
# Epoch: 45
# 0 196 Loss: 1.259 | Acc: 60.208% (154/256)
# 0 40 Loss: 0.398 | Acc: 87.500% (224/256)
# Epoch: 45 | Time Per Epoch: 00:16 | train acc: 87.56 | test acc: 88.78% | Learning Rate: 0.0001
#
# Epoch: 46
# 0 196 Loss: 0.228 | Acc: 96.669% (247/256)
# 0 40 Loss: 0.401 | Acc: 88.281% (226/256)
# Epoch: 46 | Time Per Epoch: 00:16 | train acc: 90.60 | test acc: 88.97% | Learning Rate: 0.0001
#
# Epoch: 47
# 0 196 Loss: 0.267 | Acc: 96.221% (246/256)
# 0 40 Loss: 0.385 | Acc: 88.672% (227/256)
# Saving..
# Epoch: 47 | Time Per Epoch: 00:16 | train acc: 89.95 | test acc: 89.16% | Learning Rate: 0.0001
#
# Epoch: 48
# 0 196 Loss: 0.008 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.405 | Acc: 87.500% (224/256)
# Epoch: 48 | Time Per Epoch: 00:16 | train acc: 87.73 | test acc: 89.02% | Learning Rate: 0.0001
#
# Epoch: 49
# 0 196 Loss: 0.018 | Acc: 99.888% (255/256)
# 0 40 Loss: 0.416 | Acc: 86.719% (222/256)
# Epoch: 49 | Time Per Epoch: 00:15 | train acc: 89.88 | test acc: 89.10% | Learning Rate: 0.0001
#
# Epoch: 50
# 0 196 Loss: 0.144 | Acc: 98.080% (251/256)
# 0 40 Loss: 0.438 | Acc: 86.719% (222/256)
# Epoch: 50 | Time Per Epoch: 00:16 | train acc: 89.63 | test acc: 88.96% | Learning Rate: 1e-05
#
# Epoch: 51
# 0 196 Loss: 1.270 | Acc: 57.824% (148/256)
# 0 40 Loss: 0.408 | Acc: 86.719% (222/256)
# Saving..
# Epoch: 51 | Time Per Epoch: 00:16 | train acc: 88.55 | test acc: 89.32% | Learning Rate: 1e-05
#
# Epoch: 52
# 0 196 Loss: 0.007 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.433 | Acc: 87.109% (223/256)
# Epoch: 52 | Time Per Epoch: 00:15 | train acc: 88.86 | test acc: 89.05% | Learning Rate: 1e-05
#
# Epoch: 53
# 0 196 Loss: 1.004 | Acc: 74.520% (190/256)
# 0 40 Loss: 0.395 | Acc: 88.281% (226/256)
# Saving..
# Epoch: 53 | Time Per Epoch: 00:16 | train acc: 88.79 | test acc: 89.39% | Learning Rate: 1e-05
#
# Epoch: 54
# 0 196 Loss: 0.009 | Acc: 99.986% (255/256)
# 0 40 Loss: 0.410 | Acc: 86.719% (222/256)
# Epoch: 54 | Time Per Epoch: 00:16 | train acc: 87.95 | test acc: 89.24% | Learning Rate: 1e-05
#
# Epoch: 55
# 0 196 Loss: 1.004 | Acc: 75.081% (192/256)
# 0 40 Loss: 0.410 | Acc: 87.500% (224/256)
# Epoch: 55 | Time Per Epoch: 00:15 | train acc: 88.14 | test acc: 89.23% | Learning Rate: 1e-05
#
# Epoch: 56
# 0 196 Loss: 0.485 | Acc: 91.643% (234/256)
# 0 40 Loss: 0.408 | Acc: 87.891% (225/256)
# Saving..
# Epoch: 56 | Time Per Epoch: 00:16 | train acc: 90.33 | test acc: 89.56% | Learning Rate: 1e-05
#
# Epoch: 57
# 0 196 Loss: 0.894 | Acc: 80.000% (204/256)
# 0 40 Loss: 0.404 | Acc: 87.891% (225/256)
# Epoch: 57 | Time Per Epoch: 00:16 | train acc: 89.69 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 58
# 0 196 Loss: 0.134 | Acc: 98.266% (251/256)
# 0 40 Loss: 0.402 | Acc: 87.500% (224/256)
# Epoch: 58 | Time Per Epoch: 00:16 | train acc: 90.62 | test acc: 89.50% | Learning Rate: 1e-05
#
# Epoch: 59
# 0 196 Loss: 0.034 | Acc: 99.641% (255/256)
# 0 40 Loss: 0.401 | Acc: 88.281% (226/256)
# Epoch: 59 | Time Per Epoch: 00:16 | train acc: 90.19 | test acc: 89.50% | Learning Rate: 1e-05
#
# Epoch: 60
# 0 196 Loss: 0.011 | Acc: 99.946% (255/256)
# 0 40 Loss: 0.411 | Acc: 88.281% (226/256)
# Saving..
# Epoch: 60 | Time Per Epoch: 00:15 | train acc: 91.09 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 61
# 0 196 Loss: 0.009 | Acc: 99.957% (255/256)
# 0 40 Loss: 0.400 | Acc: 87.500% (224/256)
# Epoch: 61 | Time Per Epoch: 00:16 | train acc: 88.70 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 62
# 0 196 Loss: 0.585 | Acc: 89.349% (228/256)
# 0 40 Loss: 0.431 | Acc: 87.500% (224/256)
# Saving..
# Epoch: 62 | Time Per Epoch: 00:16 | train acc: 90.55 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 63
# 0 196 Loss: 0.035 | Acc: 99.623% (255/256)
# 0 40 Loss: 0.401 | Acc: 87.891% (225/256)
# Epoch: 63 | Time Per Epoch: 00:16 | train acc: 89.85 | test acc: 89.58% | Learning Rate: 1e-05
#
# Epoch: 64
# 0 196 Loss: 0.122 | Acc: 98.410% (251/256)
# 0 40 Loss: 0.405 | Acc: 87.500% (224/256)
# Epoch: 64 | Time Per Epoch: 00:16 | train acc: 90.17 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 65
# 0 196 Loss: 0.141 | Acc: 98.169% (251/256)
# 0 40 Loss: 0.405 | Acc: 87.891% (225/256)
# Epoch: 65 | Time Per Epoch: 00:16 | train acc: 90.36 | test acc: 89.55% | Learning Rate: 1e-05
#
# Epoch: 66
# 0 196 Loss: 0.033 | Acc: 99.642% (255/256)
# 0 40 Loss: 0.409 | Acc: 87.109% (223/256)
# Epoch: 66 | Time Per Epoch: 00:16 | train acc: 90.71 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 67
# 0 196 Loss: 0.162 | Acc: 97.871% (250/256)
# 0 40 Loss: 0.401 | Acc: 87.891% (225/256)
# Epoch: 67 | Time Per Epoch: 00:16 | train acc: 89.44 | test acc: 89.30% | Learning Rate: 1e-05
#
# Epoch: 68
# 0 196 Loss: 0.013 | Acc: 99.917% (255/256)
# 0 40 Loss: 0.409 | Acc: 87.500% (224/256)
# Saving..
# Epoch: 68 | Time Per Epoch: 00:16 | train acc: 90.24 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 69
# 0 196 Loss: 0.101 | Acc: 98.756% (252/256)
# 0 40 Loss: 0.404 | Acc: 88.281% (226/256)
# Epoch: 69 | Time Per Epoch: 00:16 | train acc: 91.31 | test acc: 89.58% | Learning Rate: 1e-05
#
# Epoch: 70
# 0 196 Loss: 0.059 | Acc: 99.293% (254/256)
# 0 40 Loss: 0.392 | Acc: 88.281% (226/256)
# Epoch: 70 | Time Per Epoch: 00:17 | train acc: 91.68 | test acc: 89.58% | Learning Rate: 1e-05
#
# Epoch: 71
# 0 196 Loss: 1.084 | Acc: 69.693% (178/256)
# 0 40 Loss: 0.387 | Acc: 88.672% (227/256)
# Epoch: 71 | Time Per Epoch: 00:16 | train acc: 88.91 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 72
# 0 196 Loss: 1.326 | Acc: 52.207% (133/256)
# 0 40 Loss: 0.392 | Acc: 87.891% (225/256)
# Epoch: 72 | Time Per Epoch: 00:16 | train acc: 90.39 | test acc: 89.51% | Learning Rate: 1e-05
#
# Epoch: 73
# 0 196 Loss: 0.042 | Acc: 99.610% (255/256)
# 0 40 Loss: 0.393 | Acc: 88.281% (226/256)
# Epoch: 73 | Time Per Epoch: 00:16 | train acc: 88.59 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 74
# 0 196 Loss: 0.771 | Acc: 84.105% (215/256)
# 0 40 Loss: 0.389 | Acc: 87.891% (225/256)
# Epoch: 74 | Time Per Epoch: 00:17 | train acc: 88.55 | test acc: 89.50% | Learning Rate: 1e-05
#
# Epoch: 75
# 0 196 Loss: 0.602 | Acc: 88.882% (227/256)
# 0 40 Loss: 0.391 | Acc: 88.672% (227/256)
# Epoch: 75 | Time Per Epoch: 00:17 | train acc: 88.21 | test acc: 89.42% | Learning Rate: 1e-05
#
# Epoch: 76
# 0 196 Loss: 0.356 | Acc: 94.461% (241/256)
# 0 40 Loss: 0.397 | Acc: 88.281% (226/256)
# Epoch: 76 | Time Per Epoch: 00:16 | train acc: 89.84 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 77
# 0 196 Loss: 0.069 | Acc: 99.178% (253/256)
# 0 40 Loss: 0.389 | Acc: 89.062% (228/256)
# Epoch: 77 | Time Per Epoch: 00:16 | train acc: 89.32 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 78
# 0 196 Loss: 1.315 | Acc: 52.663% (134/256)
# 0 40 Loss: 0.397 | Acc: 88.672% (227/256)
# Epoch: 78 | Time Per Epoch: 00:17 | train acc: 89.18 | test acc: 89.43% | Learning Rate: 1e-05
#
# Epoch: 79
# 0 196 Loss: 0.018 | Acc: 99.850% (255/256)
# 0 40 Loss: 0.403 | Acc: 88.281% (226/256)
# Epoch: 79 | Time Per Epoch: 00:17 | train acc: 91.27 | test acc: 89.51% | Learning Rate: 1e-05
#
# Epoch: 80
# 0 196 Loss: 0.050 | Acc: 99.423% (254/256)
# 0 40 Loss: 0.395 | Acc: 88.672% (227/256)
# Epoch: 80 | Time Per Epoch: 00:16 | train acc: 90.86 | test acc: 89.51% | Learning Rate: 1e-05
#
# Epoch: 81
# 0 196 Loss: 0.021 | Acc: 99.807% (255/256)
# 0 40 Loss: 0.401 | Acc: 87.891% (225/256)
# Epoch: 81 | Time Per Epoch: 00:16 | train acc: 88.34 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 82
# 0 196 Loss: 0.011 | Acc: 99.955% (255/256)
# 0 40 Loss: 0.391 | Acc: 88.281% (226/256)
# Epoch: 82 | Time Per Epoch: 00:16 | train acc: 91.11 | test acc: 89.59% | Learning Rate: 1e-05
#
# Epoch: 83
# 0 196 Loss: 0.007 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.395 | Acc: 88.281% (226/256)
# Epoch: 83 | Time Per Epoch: 00:16 | train acc: 90.26 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 84
# 0 196 Loss: 0.416 | Acc: 92.915% (237/256)
# 0 40 Loss: 0.406 | Acc: 87.500% (224/256)
# Epoch: 84 | Time Per Epoch: 00:17 | train acc: 88.34 | test acc: 89.49% | Learning Rate: 1e-05
#
# Epoch: 85
# 0 196 Loss: 0.040 | Acc: 99.551% (254/256)
# 0 40 Loss: 0.386 | Acc: 87.891% (225/256)
# Epoch: 85 | Time Per Epoch: 00:16 | train acc: 88.98 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 86
# 0 196 Loss: 0.009 | Acc: 99.985% (255/256)
# 0 40 Loss: 0.392 | Acc: 87.500% (224/256)
# Epoch: 86 | Time Per Epoch: 00:16 | train acc: 91.19 | test acc: 89.49% | Learning Rate: 1e-05
#
# Epoch: 87
# 0 196 Loss: 1.298 | Acc: 52.133% (133/256)
# 0 40 Loss: 0.383 | Acc: 88.281% (226/256)
# Epoch: 87 | Time Per Epoch: 00:16 | train acc: 89.12 | test acc: 89.41% | Learning Rate: 1e-05
#
# Epoch: 88
# 0 196 Loss: 0.007 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.393 | Acc: 88.672% (227/256)
# Epoch: 88 | Time Per Epoch: 00:17 | train acc: 90.58 | test acc: 89.43% | Learning Rate: 1e-05
#
# Epoch: 89
# 0 196 Loss: 1.083 | Acc: 69.440% (177/256)
# 0 40 Loss: 0.390 | Acc: 87.891% (225/256)
# Epoch: 89 | Time Per Epoch: 00:16 | train acc: 89.73 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 90
# 0 196 Loss: 0.394 | Acc: 93.527% (239/256)
# 0 40 Loss: 0.393 | Acc: 87.500% (224/256)
# Epoch: 90 | Time Per Epoch: 00:18 | train acc: 90.97 | test acc: 89.61% | Learning Rate: 1e-05
#
# Epoch: 91
# 0 196 Loss: 1.116 | Acc: 64.957% (166/256)
# 0 40 Loss: 0.381 | Acc: 87.891% (225/256)
# Epoch: 91 | Time Per Epoch: 00:20 | train acc: 89.58 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 92
# 0 196 Loss: 0.616 | Acc: 88.419% (226/256)
# 0 40 Loss: 0.392 | Acc: 87.891% (225/256)
# Epoch: 92 | Time Per Epoch: 00:19 | train acc: 88.28 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 93
# 0 196 Loss: 0.052 | Acc: 99.389% (254/256)
# 0 40 Loss: 0.381 | Acc: 89.062% (228/256)
# Epoch: 93 | Time Per Epoch: 00:19 | train acc: 91.89 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 94
# 0 196 Loss: 1.045 | Acc: 73.583% (188/256)
# 0 40 Loss: 0.389 | Acc: 87.891% (225/256)
# Epoch: 94 | Time Per Epoch: 00:19 | train acc: 88.22 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 95
# 0 196 Loss: 0.011 | Acc: 99.986% (255/256)
# 0 40 Loss: 0.392 | Acc: 87.891% (225/256)
# Saving..
# Epoch: 95 | Time Per Epoch: 00:19 | train acc: 91.69 | test acc: 89.96% | Learning Rate: 1e-05
#
# Epoch: 96
# 0 196 Loss: 0.010 | Acc: 99.950% (255/256)
# 0 40 Loss: 0.386 | Acc: 87.500% (224/256)
# Epoch: 96 | Time Per Epoch: 00:19 | train acc: 91.04 | test acc: 89.69% | Learning Rate: 1e-05
#
# Epoch: 97
# 0 196 Loss: 1.318 | Acc: 57.606% (147/256)
# 0 40 Loss: 0.385 | Acc: 88.672% (227/256)
# Epoch: 97 | Time Per Epoch: 00:20 | train acc: 89.04 | test acc: 89.80% | Learning Rate: 1e-05
#
# Epoch: 98
# 0 196 Loss: 0.080 | Acc: 99.012% (253/256)
# 0 40 Loss: 0.397 | Acc: 89.062% (228/256)
# Epoch: 98 | Time Per Epoch: 00:19 | train acc: 89.33 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 99
# 0 196 Loss: 0.027 | Acc: 99.735% (255/256)
# 0 40 Loss: 0.402 | Acc: 87.500% (224/256)
# Epoch: 99 | Time Per Epoch: 00:19 | train acc: 88.90 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 100
# 0 196 Loss: 0.007 | Acc: 99.994% (255/256)
# 0 40 Loss: 0.396 | Acc: 88.672% (227/256)
# Epoch: 100 | Time Per Epoch: 00:19 | train acc: 91.34 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 101
# 0 196 Loss: 0.095 | Acc: 98.835% (253/256)
# 0 40 Loss: 0.394 | Acc: 89.062% (228/256)
# Epoch: 101 | Time Per Epoch: 00:19 | train acc: 89.22 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 102
# 0 196 Loss: 0.044 | Acc: 99.507% (254/256)
# 0 40 Loss: 0.390 | Acc: 88.281% (226/256)
# Epoch: 102 | Time Per Epoch: 00:19 | train acc: 90.73 | test acc: 89.71% | Learning Rate: 1e-05
#
# Epoch: 103
# 0 196 Loss: 0.796 | Acc: 83.094% (212/256)
# 0 40 Loss: 0.407 | Acc: 88.281% (226/256)
# Epoch: 103 | Time Per Epoch: 00:19 | train acc: 89.40 | test acc: 89.49% | Learning Rate: 1e-05
#
# Epoch: 104
# 0 196 Loss: 0.008 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.413 | Acc: 88.281% (226/256)
# Epoch: 104 | Time Per Epoch: 00:19 | train acc: 89.82 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 105
# 0 196 Loss: 0.012 | Acc: 99.934% (255/256)
# 0 40 Loss: 0.422 | Acc: 88.672% (227/256)
# Epoch: 105 | Time Per Epoch: 00:19 | train acc: 88.52 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 106
# 0 196 Loss: 0.052 | Acc: 99.417% (254/256)
# 0 40 Loss: 0.400 | Acc: 88.672% (227/256)
# Epoch: 106 | Time Per Epoch: 00:19 | train acc: 89.64 | test acc: 89.47% | Learning Rate: 1e-05
#
# Epoch: 107
# 0 196 Loss: 1.248 | Acc: 58.414% (149/256)
# 0 40 Loss: 0.383 | Acc: 89.062% (228/256)
# Epoch: 107 | Time Per Epoch: 00:19 | train acc: 90.19 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 108
# 0 196 Loss: 0.096 | Acc: 98.817% (252/256)
# 0 40 Loss: 0.380 | Acc: 88.281% (226/256)
# Epoch: 108 | Time Per Epoch: 00:20 | train acc: 89.94 | test acc: 89.82% | Learning Rate: 1e-05
#
# Epoch: 109
# 0 196 Loss: 0.405 | Acc: 93.223% (238/256)
# 0 40 Loss: 0.379 | Acc: 88.672% (227/256)
# Epoch: 109 | Time Per Epoch: 00:20 | train acc: 88.54 | test acc: 89.78% | Learning Rate: 1e-05
#
# Epoch: 110
# 0 196 Loss: 0.006 | Acc: 99.996% (255/256)
# 0 40 Loss: 0.392 | Acc: 89.062% (228/256)
# Epoch: 110 | Time Per Epoch: 00:19 | train acc: 92.67 | test acc: 89.66% | Learning Rate: 1e-05
#
# Epoch: 111
# 0 196 Loss: 0.354 | Acc: 94.159% (241/256)
# 0 40 Loss: 0.370 | Acc: 89.453% (229/256)
# Epoch: 111 | Time Per Epoch: 00:19 | train acc: 88.69 | test acc: 89.83% | Learning Rate: 1e-05
#
# Epoch: 112
# 0 196 Loss: 1.032 | Acc: 72.035% (184/256)
# 0 40 Loss: 0.381 | Acc: 89.062% (228/256)
# Epoch: 112 | Time Per Epoch: 00:19 | train acc: 90.75 | test acc: 89.76% | Learning Rate: 1e-05
#
# Epoch: 113
# 0 196 Loss: 0.788 | Acc: 82.947% (212/256)
# 0 40 Loss: 0.403 | Acc: 88.281% (226/256)
# Epoch: 113 | Time Per Epoch: 00:19 | train acc: 89.02 | test acc: 89.53% | Learning Rate: 1e-05
#
# Epoch: 114
# 0 196 Loss: 0.006 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.405 | Acc: 88.281% (226/256)
# Epoch: 114 | Time Per Epoch: 00:19 | train acc: 88.70 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 115
# 0 196 Loss: 0.267 | Acc: 95.956% (245/256)
# 0 40 Loss: 0.380 | Acc: 88.672% (227/256)
# Epoch: 115 | Time Per Epoch: 00:20 | train acc: 90.83 | test acc: 89.86% | Learning Rate: 1e-05
#
# Epoch: 116
# 0 196 Loss: 0.080 | Acc: 99.031% (253/256)
# 0 40 Loss: 0.426 | Acc: 88.672% (227/256)
# Epoch: 116 | Time Per Epoch: 00:19 | train acc: 89.42 | test acc: 89.23% | Learning Rate: 1e-05
#
# Epoch: 117
# 0 196 Loss: 0.071 | Acc: 99.160% (253/256)
# 0 40 Loss: 0.379 | Acc: 89.062% (228/256)
# Epoch: 117 | Time Per Epoch: 00:20 | train acc: 90.61 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 118
# 0 196 Loss: 0.452 | Acc: 92.406% (236/256)
# 0 40 Loss: 0.386 | Acc: 88.281% (226/256)
# Epoch: 118 | Time Per Epoch: 00:20 | train acc: 90.03 | test acc: 89.92% | Learning Rate: 1e-05
#
# Epoch: 119
# 0 196 Loss: 0.021 | Acc: 99.801% (255/256)
# 0 40 Loss: 0.380 | Acc: 89.844% (230/256)
# Epoch: 119 | Time Per Epoch: 00:20 | train acc: 88.47 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 120
# 0 196 Loss: 0.073 | Acc: 99.113% (253/256)
# 0 40 Loss: 0.378 | Acc: 89.453% (229/256)
# Epoch: 120 | Time Per Epoch: 00:20 | train acc: 90.14 | test acc: 89.82% | Learning Rate: 1e-05
#
# Epoch: 121
# 0 196 Loss: 0.694 | Acc: 86.549% (221/256)
# 0 40 Loss: 0.393 | Acc: 89.062% (228/256)
# Epoch: 121 | Time Per Epoch: 00:19 | train acc: 91.43 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 122
# 0 196 Loss: 1.278 | Acc: 53.618% (137/256)
# 0 40 Loss: 0.391 | Acc: 88.672% (227/256)
# Epoch: 122 | Time Per Epoch: 00:19 | train acc: 90.73 | test acc: 89.95% | Learning Rate: 1e-05
#
# Epoch: 123
# 0 196 Loss: 0.488 | Acc: 91.393% (233/256)
# 0 40 Loss: 0.378 | Acc: 89.453% (229/256)
# Epoch: 123 | Time Per Epoch: 00:19 | train acc: 90.20 | test acc: 89.93% | Learning Rate: 1e-05
#
# Epoch: 124
# 0 196 Loss: 0.297 | Acc: 95.418% (244/256)
# 0 40 Loss: 0.373 | Acc: 90.625% (232/256)
# Saving..
# Epoch: 124 | Time Per Epoch: 00:19 | train acc: 88.14 | test acc: 89.97% | Learning Rate: 1e-05
#
# Epoch: 125
# 0 196 Loss: 1.030 | Acc: 72.645% (185/256)
# 0 40 Loss: 0.379 | Acc: 89.453% (229/256)
# Epoch: 125 | Time Per Epoch: 00:20 | train acc: 90.13 | test acc: 89.69% | Learning Rate: 1e-05
#
# Epoch: 126
# 0 196 Loss: 0.708 | Acc: 85.432% (218/256)
# 0 40 Loss: 0.379 | Acc: 89.453% (229/256)
# Epoch: 126 | Time Per Epoch: 00:20 | train acc: 89.36 | test acc: 89.86% | Learning Rate: 1e-05
#
# Epoch: 127
# 0 196 Loss: 0.009 | Acc: 99.966% (255/256)
# 0 40 Loss: 0.385 | Acc: 89.453% (229/256)
# Epoch: 127 | Time Per Epoch: 00:19 | train acc: 88.89 | test acc: 89.82% | Learning Rate: 1e-05
#
# Epoch: 128
# 0 196 Loss: 0.265 | Acc: 95.967% (245/256)
# 0 40 Loss: 0.399 | Acc: 89.453% (229/256)
# Epoch: 128 | Time Per Epoch: 00:19 | train acc: 89.32 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 129
# 0 196 Loss: 0.087 | Acc: 98.947% (253/256)
# 0 40 Loss: 0.381 | Acc: 88.672% (227/256)
# Epoch: 129 | Time Per Epoch: 00:19 | train acc: 90.67 | test acc: 89.79% | Learning Rate: 1e-05
#
# Epoch: 130
# 0 196 Loss: 0.380 | Acc: 93.904% (240/256)
# 0 40 Loss: 0.383 | Acc: 88.672% (227/256)
# Epoch: 130 | Time Per Epoch: 00:19 | train acc: 89.60 | test acc: 89.65% | Learning Rate: 1e-05
#
# Epoch: 131
# 0 196 Loss: 0.061 | Acc: 99.286% (254/256)
# 0 40 Loss: 0.384 | Acc: 89.062% (228/256)
# Epoch: 131 | Time Per Epoch: 00:19 | train acc: 87.51 | test acc: 89.72% | Learning Rate: 1e-05
#
# Epoch: 132
# 0 196 Loss: 0.324 | Acc: 94.881% (242/256)
# 0 40 Loss: 0.387 | Acc: 89.453% (229/256)
# Epoch: 132 | Time Per Epoch: 00:20 | train acc: 91.68 | test acc: 89.69% | Learning Rate: 1e-05
#
# Epoch: 133
# 0 196 Loss: 0.368 | Acc: 93.921% (240/256)
# 0 40 Loss: 0.380 | Acc: 88.672% (227/256)
# Epoch: 133 | Time Per Epoch: 00:19 | train acc: 89.85 | test acc: 89.93% | Learning Rate: 1e-05
#
# Epoch: 134
# 0 196 Loss: 1.216 | Acc: 58.491% (149/256)
# 0 40 Loss: 0.379 | Acc: 89.062% (228/256)
# Epoch: 134 | Time Per Epoch: 00:20 | train acc: 90.68 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 135
# 0 196 Loss: 0.008 | Acc: 99.984% (255/256)
# 0 40 Loss: 0.381 | Acc: 89.844% (230/256)
# Epoch: 135 | Time Per Epoch: 00:19 | train acc: 90.47 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 136
# 0 196 Loss: 0.014 | Acc: 99.895% (255/256)
# 0 40 Loss: 0.373 | Acc: 89.844% (230/256)
# Epoch: 136 | Time Per Epoch: 00:19 | train acc: 90.72 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 137
# 0 196 Loss: 0.032 | Acc: 99.667% (255/256)
# 0 40 Loss: 0.374 | Acc: 90.234% (231/256)
# Epoch: 137 | Time Per Epoch: 00:19 | train acc: 90.10 | test acc: 89.86% | Learning Rate: 1e-05
#
# Epoch: 138
# 0 196 Loss: 0.008 | Acc: 99.987% (255/256)
# 0 40 Loss: 0.377 | Acc: 89.844% (230/256)
# Epoch: 138 | Time Per Epoch: 00:19 | train acc: 90.69 | test acc: 89.76% | Learning Rate: 1e-05
#
# Epoch: 139
# 0 196 Loss: 1.244 | Acc: 53.266% (136/256)
# 0 40 Loss: 0.378 | Acc: 88.672% (227/256)
# Epoch: 139 | Time Per Epoch: 00:19 | train acc: 89.18 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 140
# 0 196 Loss: 0.162 | Acc: 97.720% (250/256)
# 0 40 Loss: 0.372 | Acc: 89.453% (229/256)
# Saving..
# Epoch: 140 | Time Per Epoch: 00:19 | train acc: 90.71 | test acc: 90.00% | Learning Rate: 1e-05
#
# Epoch: 141
# 0 196 Loss: 1.264 | Acc: 51.787% (132/256)
# 0 40 Loss: 0.397 | Acc: 89.062% (228/256)
# Epoch: 141 | Time Per Epoch: 00:19 | train acc: 88.69 | test acc: 89.57% | Learning Rate: 1e-05
#
# Epoch: 142
# 0 196 Loss: 1.108 | Acc: 66.444% (170/256)
# 0 40 Loss: 0.386 | Acc: 88.672% (227/256)
# Epoch: 142 | Time Per Epoch: 00:19 | train acc: 89.66 | test acc: 89.87% | Learning Rate: 1e-05
#
# Epoch: 143
# 0 196 Loss: 0.270 | Acc: 95.834% (245/256)
# 0 40 Loss: 0.387 | Acc: 89.062% (228/256)
# Epoch: 143 | Time Per Epoch: 00:19 | train acc: 90.35 | test acc: 89.66% | Learning Rate: 1e-05
#
# Epoch: 144
# 0 196 Loss: 0.606 | Acc: 88.542% (226/256)
# 0 40 Loss: 0.383 | Acc: 88.672% (227/256)
# Epoch: 144 | Time Per Epoch: 00:19 | train acc: 88.02 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 145
# 0 196 Loss: 0.006 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.386 | Acc: 89.453% (229/256)
# Epoch: 145 | Time Per Epoch: 00:20 | train acc: 89.24 | test acc: 89.74% | Learning Rate: 1e-05
#
# Epoch: 146
# 0 196 Loss: 0.006 | Acc: 99.999% (255/256)
# 0 40 Loss: 0.377 | Acc: 88.281% (226/256)
# Epoch: 146 | Time Per Epoch: 00:20 | train acc: 89.01 | test acc: 89.90% | Learning Rate: 1e-05
#
# Epoch: 147
# 0 196 Loss: 1.014 | Acc: 71.693% (183/256)
# 0 40 Loss: 0.366 | Acc: 88.672% (227/256)
# Epoch: 147 | Time Per Epoch: 00:18 | train acc: 91.45 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 148
# 0 196 Loss: 0.007 | Acc: 99.995% (255/256)
# 0 40 Loss: 0.389 | Acc: 89.062% (228/256)
# Epoch: 148 | Time Per Epoch: 00:20 | train acc: 90.44 | test acc: 89.82% | Learning Rate: 1e-05
#
# Epoch: 149
# 0 196 Loss: 0.026 | Acc: 99.732% (255/256)
# 0 40 Loss: 0.386 | Acc: 89.844% (230/256)
# Epoch: 149 | Time Per Epoch: 00:19 | train acc: 90.71 | test acc: 89.64% | Learning Rate: 1e-05
#
# Epoch: 150
# 0 196 Loss: 0.041 | Acc: 99.541% (254/256)
# 0 40 Loss: 0.383 | Acc: 89.453% (229/256)
# Epoch: 150 | Time Per Epoch: 00:19 | train acc: 90.01 | test acc: 89.58% | Learning Rate: 1e-05
#
# Epoch: 151
# 0 196 Loss: 0.681 | Acc: 86.482% (221/256)
# 0 40 Loss: 0.383 | Acc: 90.234% (231/256)
# Epoch: 151 | Time Per Epoch: 00:19 | train acc: 90.08 | test acc: 89.48% | Learning Rate: 1e-05
#
# Epoch: 152
# 0 196 Loss: 0.084 | Acc: 98.969% (253/256)
# 0 40 Loss: 0.389 | Acc: 89.062% (228/256)
# Epoch: 152 | Time Per Epoch: 00:19 | train acc: 90.87 | test acc: 89.64% | Learning Rate: 1e-05
#
# Epoch: 153
# 0 196 Loss: 0.014 | Acc: 99.893% (255/256)
# 0 40 Loss: 0.376 | Acc: 88.281% (226/256)
# Epoch: 153 | Time Per Epoch: 00:19 | train acc: 90.89 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 154
# 0 196 Loss: 0.008 | Acc: 99.980% (255/256)
# 0 40 Loss: 0.376 | Acc: 88.281% (226/256)
# Epoch: 154 | Time Per Epoch: 00:19 | train acc: 92.14 | test acc: 89.92% | Learning Rate: 1e-05
#
# Epoch: 155
# 0 196 Loss: 0.869 | Acc: 79.089% (202/256)
# 0 40 Loss: 0.378 | Acc: 89.062% (228/256)
# Epoch: 155 | Time Per Epoch: 00:19 | train acc: 89.70 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 156
# 0 196 Loss: 1.303 | Acc: 53.019% (135/256)
# 0 40 Loss: 0.388 | Acc: 87.891% (225/256)
# Epoch: 156 | Time Per Epoch: 00:20 | train acc: 90.57 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 157
# 0 196 Loss: 0.006 | Acc: 99.996% (255/256)
# 0 40 Loss: 0.381 | Acc: 89.062% (228/256)
# Epoch: 157 | Time Per Epoch: 00:19 | train acc: 90.18 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 158
# 0 196 Loss: 0.207 | Acc: 97.120% (248/256)
# 0 40 Loss: 0.375 | Acc: 89.062% (228/256)
# Epoch: 158 | Time Per Epoch: 00:20 | train acc: 87.12 | test acc: 89.99% | Learning Rate: 1e-05
#
# Epoch: 159
# 0 196 Loss: 0.007 | Acc: 99.997% (255/256)
# 0 40 Loss: 0.373 | Acc: 89.062% (228/256)
# Epoch: 159 | Time Per Epoch: 00:19 | train acc: 90.94 | test acc: 89.60% | Learning Rate: 1e-05
#
# Epoch: 160
# 0 196 Loss: 0.008 | Acc: 99.997% (255/256)
# 0 40 Loss: 0.394 | Acc: 89.062% (228/256)
# Epoch: 160 | Time Per Epoch: 00:19 | train acc: 90.49 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 161
# 0 196 Loss: 0.040 | Acc: 99.559% (254/256)
# 0 40 Loss: 0.397 | Acc: 88.672% (227/256)
# Epoch: 161 | Time Per Epoch: 00:19 | train acc: 88.79 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 162
# 0 196 Loss: 0.008 | Acc: 99.967% (255/256)
# 0 40 Loss: 0.375 | Acc: 88.281% (226/256)
# Epoch: 162 | Time Per Epoch: 00:19 | train acc: 89.17 | test acc: 89.70% | Learning Rate: 1e-05
#
# Epoch: 163
# 0 196 Loss: 0.007 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.387 | Acc: 88.672% (227/256)
# Epoch: 163 | Time Per Epoch: 00:19 | train acc: 90.80 | test acc: 89.55% | Learning Rate: 1e-05
#
# Epoch: 164
# 0 196 Loss: 0.023 | Acc: 99.776% (255/256)
# 0 40 Loss: 0.385 | Acc: 88.672% (227/256)
# Epoch: 164 | Time Per Epoch: 00:19 | train acc: 89.52 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 165
# 0 196 Loss: 0.444 | Acc: 92.014% (235/256)
# 0 40 Loss: 0.391 | Acc: 89.453% (229/256)
# Epoch: 165 | Time Per Epoch: 00:20 | train acc: 90.56 | test acc: 89.78% | Learning Rate: 1e-05
#
# Epoch: 166
# 0 196 Loss: 1.330 | Acc: 51.414% (131/256)
# 0 40 Loss: 0.382 | Acc: 88.281% (226/256)
# Saving..
# Epoch: 166 | Time Per Epoch: 00:19 | train acc: 90.30 | test acc: 90.02% | Learning Rate: 1e-05
#
# Epoch: 167
# 0 196 Loss: 0.101 | Acc: 98.702% (252/256)
# 0 40 Loss: 0.372 | Acc: 88.281% (226/256)
# Epoch: 167 | Time Per Epoch: 00:19 | train acc: 91.09 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 168
# 0 196 Loss: 0.165 | Acc: 97.704% (250/256)
# 0 40 Loss: 0.396 | Acc: 89.062% (228/256)
# Epoch: 168 | Time Per Epoch: 00:19 | train acc: 89.94 | test acc: 89.54% | Learning Rate: 1e-05
#
# Epoch: 169
# 0 196 Loss: 0.943 | Acc: 77.524% (198/256)
# 0 40 Loss: 0.383 | Acc: 89.453% (229/256)
# Epoch: 169 | Time Per Epoch: 00:20 | train acc: 89.36 | test acc: 89.92% | Learning Rate: 1e-05
#
# Epoch: 170
# 0 196 Loss: 1.202 | Acc: 56.763% (145/256)
# 0 40 Loss: 0.375 | Acc: 88.281% (226/256)
# Epoch: 170 | Time Per Epoch: 00:19 | train acc: 91.13 | test acc: 89.74% | Learning Rate: 1e-05
#
# Epoch: 171
# 0 196 Loss: 1.326 | Acc: 50.561% (129/256)
# 0 40 Loss: 0.376 | Acc: 89.062% (228/256)
# Epoch: 171 | Time Per Epoch: 00:19 | train acc: 90.01 | test acc: 89.86% | Learning Rate: 1e-05
#
# Epoch: 172
# 0 196 Loss: 0.007 | Acc: 99.985% (255/256)
# 0 40 Loss: 0.373 | Acc: 89.844% (230/256)
# Epoch: 172 | Time Per Epoch: 00:19 | train acc: 89.74 | test acc: 89.83% | Learning Rate: 1e-05
#
# Epoch: 173
# 0 196 Loss: 0.005 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.377 | Acc: 89.062% (228/256)
# Epoch: 173 | Time Per Epoch: 00:20 | train acc: 89.37 | test acc: 89.76% | Learning Rate: 1e-05
#
# Epoch: 174
# 0 196 Loss: 1.152 | Acc: 62.420% (159/256)
# 0 40 Loss: 0.371 | Acc: 89.062% (228/256)
# Epoch: 174 | Time Per Epoch: 00:19 | train acc: 89.54 | test acc: 89.83% | Learning Rate: 1e-05
#
# Epoch: 175
# 0 196 Loss: 0.006 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.367 | Acc: 88.672% (227/256)
# Epoch: 175 | Time Per Epoch: 00:19 | train acc: 90.37 | test acc: 89.97% | Learning Rate: 1e-05
#
# Epoch: 176
# 0 196 Loss: 0.006 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.387 | Acc: 89.453% (229/256)
# Epoch: 176 | Time Per Epoch: 00:19 | train acc: 87.37 | test acc: 89.62% | Learning Rate: 1e-05
#
# Epoch: 177
# 0 196 Loss: 0.005 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.375 | Acc: 89.453% (229/256)
# Epoch: 177 | Time Per Epoch: 00:19 | train acc: 91.35 | test acc: 89.93% | Learning Rate: 1e-05
#
# Epoch: 178
# 0 196 Loss: 0.045 | Acc: 99.489% (254/256)
# 0 40 Loss: 0.413 | Acc: 89.453% (229/256)
# Epoch: 178 | Time Per Epoch: 00:19 | train acc: 89.50 | test acc: 89.63% | Learning Rate: 1e-05
#
# Epoch: 179
# 0 196 Loss: 0.043 | Acc: 99.509% (254/256)
# 0 40 Loss: 0.390 | Acc: 89.453% (229/256)
# Epoch: 179 | Time Per Epoch: 00:19 | train acc: 91.04 | test acc: 90.01% | Learning Rate: 1e-05
#
# Epoch: 180
# 0 196 Loss: 0.223 | Acc: 96.791% (247/256)
# 0 40 Loss: 0.368 | Acc: 89.844% (230/256)
# Saving..
# Epoch: 180 | Time Per Epoch: 00:19 | train acc: 89.20 | test acc: 90.04% | Learning Rate: 1e-05
#
# Epoch: 181
# 0 196 Loss: 0.957 | Acc: 75.923% (194/256)
# 0 40 Loss: 0.380 | Acc: 90.234% (231/256)
# Epoch: 181 | Time Per Epoch: 00:19 | train acc: 89.64 | test acc: 89.88% | Learning Rate: 1e-05
#
# Epoch: 182
# 0 196 Loss: 0.325 | Acc: 94.860% (242/256)
# 0 40 Loss: 0.382 | Acc: 89.062% (228/256)
# Epoch: 182 | Time Per Epoch: 00:19 | train acc: 89.87 | test acc: 89.91% | Learning Rate: 1e-05
#
# Epoch: 183
# 0 196 Loss: 0.006 | Acc: 100.000% (255/256)
# 0 40 Loss: 0.376 | Acc: 89.062% (228/256)
# Epoch: 183 | Time Per Epoch: 00:19 | train acc: 91.24 | test acc: 89.73% | Learning Rate: 1e-05
#
# Epoch: 184
# 0 196 Loss: 0.286 | Acc: 95.493% (244/256)
# 0 40 Loss: 0.383 | Acc: 89.062% (228/256)
# Saving..
# Epoch: 184 | Time Per Epoch: 00:19 | train acc: 90.16 | test acc: 90.09% | Learning Rate: 1e-05
#
# Epoch: 185
# 0 196 Loss: 1.221 | Acc: 53.766% (137/256)
# 0 40 Loss: 0.379 | Acc: 89.453% (229/256)
# Epoch: 185 | Time Per Epoch: 00:20 | train acc: 90.99 | test acc: 89.84% | Learning Rate: 1e-05
#
# Epoch: 186
# 0 196 Loss: 0.889 | Acc: 78.306% (200/256)
# 0 40 Loss: 0.403 | Acc: 89.844% (230/256)
# Epoch: 186 | Time Per Epoch: 00:19 | train acc: 87.36 | test acc: 89.68% | Learning Rate: 1e-05
#
# Epoch: 187
# 0 196 Loss: 1.285 | Acc: 54.610% (139/256)
# 0 40 Loss: 0.357 | Acc: 90.234% (231/256)
# Epoch: 187 | Time Per Epoch: 00:19 | train acc: 89.07 | test acc: 89.81% | Learning Rate: 1e-05
#
# Epoch: 188
# 0 196 Loss: 0.981 | Acc: 75.048% (192/256)
# 0 40 Loss: 0.369 | Acc: 89.844% (230/256)
# Epoch: 188 | Time Per Epoch: 00:19 | train acc: 91.30 | test acc: 89.90% | Learning Rate: 1e-05
#
# Epoch: 189
# 0 196 Loss: 0.010 | Acc: 99.931% (255/256)
# 0 40 Loss: 0.375 | Acc: 89.453% (229/256)
# Epoch: 189 | Time Per Epoch: 00:20 | train acc: 91.32 | test acc: 89.84% | Learning Rate: 1e-05
#
# Epoch: 190
# 0 196 Loss: 0.006 | Acc: 99.995% (255/256)
# 0 40 Loss: 0.376 | Acc: 89.453% (229/256)
# Saving..
# Epoch: 190 | Time Per Epoch: 00:20 | train acc: 90.71 | test acc: 90.14% | Learning Rate: 1e-05
#
# Epoch: 191
# 0 196 Loss: 0.006 | Acc: 100.000% (256/256)
# 0 40 Loss: 0.373 | Acc: 89.844% (230/256)
# Epoch: 191 | Time Per Epoch: 00:19 | train acc: 89.09 | test acc: 90.00% | Learning Rate: 1e-05
#
# Epoch: 192
# 0 196 Loss: 0.860 | Acc: 80.367% (205/256)
# 0 40 Loss: 0.384 | Acc: 89.844% (230/256)
# Epoch: 192 | Time Per Epoch: 00:19 | train acc: 88.64 | test acc: 89.97% | Learning Rate: 1e-05
#
# Epoch: 193
# 0 196 Loss: 0.185 | Acc: 97.321% (249/256)
# 0 40 Loss: 0.361 | Acc: 89.453% (229/256)
# Epoch: 193 | Time Per Epoch: 00:19 | train acc: 89.84 | test acc: 89.97% | Learning Rate: 1e-05
#
# Epoch: 194
# 0 196 Loss: 1.254 | Acc: 52.120% (133/256)
# 0 40 Loss: 0.383 | Acc: 89.844% (230/256)
# Epoch: 194 | Time Per Epoch: 00:20 | train acc: 88.25 | test acc: 89.77% | Learning Rate: 1e-05
#
# Epoch: 195
# 0 196 Loss: 1.173 | Acc: 56.430% (144/256)
# 0 40 Loss: 0.360 | Acc: 89.844% (230/256)
# Epoch: 195 | Time Per Epoch: 00:20 | train acc: 89.76 | test acc: 89.94% | Learning Rate: 1e-05
#
# Epoch: 196
# 0 196 Loss: 0.179 | Acc: 97.428% (249/256)
# 0 40 Loss: 0.362 | Acc: 89.844% (230/256)
# Epoch: 196 | Time Per Epoch: 00:20 | train acc: 89.90 | test acc: 89.91% | Learning Rate: 1e-05
#
# Epoch: 197
# 0 196 Loss: 0.007 | Acc: 99.986% (255/256)
# 0 40 Loss: 0.358 | Acc: 89.844% (230/256)
# Epoch: 197 | Time Per Epoch: 00:19 | train acc: 90.57 | test acc: 90.02% | Learning Rate: 1e-05
#
# Epoch: 198
# 0 196 Loss: 0.169 | Acc: 97.733% (250/256)
# 0 40 Loss: 0.366 | Acc: 89.844% (230/256)
# Epoch: 198 | Time Per Epoch: 00:20 | train acc: 90.21 | test acc: 90.09% | Learning Rate: 1e-05
#
# Epoch: 199
# 0 196 Loss: 0.007 | Acc: 99.987% (255/256)
# 0 40 Loss: 0.379 | Acc: 89.844% (230/256)
# Epoch: 199 | Time Per Epoch: 00:19 | train acc: 89.28 | test acc: 89.85% | Learning Rate: 1e-05
#
# Epoch: 200
# 0 196 Loss: 0.541 | Acc: 89.986% (230/256)
# 0 40 Loss: 0.374 | Acc: 89.844% (230/256)
# Epoch: 200 | Time Per Epoch: 00:19 | train acc: 89.89 | test acc: 89.94% | Learning Rate: 1e-05

# %%
# plot results
results = pd.read_csv('./results/ResNet_mixup_alpha_p2.csv', sep=',')
results.head()
# Out:
#    epoch  train loss  train acc  test loss   test acc
# 0      1    1.693873  41.297821   1.426163  50.980000
# 1      2    1.254190  59.125019   1.045818  66.949997
# 2      3    1.138694  64.690849   1.009140  67.019997
# 3      4    1.018241  69.383392   0.870733  73.529999
# 4      5    0.960086  71.911148   0.823698  73.320000

# %%
train_accuracy = results['train acc'].values
test_accuracy = results['test acc'].values

print(f"Average test Accuracy over {end_apochs} epochs: {sum(test_accuracy)//len(test_accuracy)}")
print(f"best test accuraccy over {end_apochs} epochs: {max(test_accuracy)}")
# Out:
# Average test Accuracy over 200 epochs: 87.0
# best test accuraccy over 200 epochs: 90.13999938964844

# %%
figureName = 'WithMixUp' # change figure name

plt.figure(figsize=(9, 6))
plt.plot(sorted(results['epoch'].values), train_accuracy, label='train')
plt.plot(sorted(results['epoch'].values), test_accuracy, label='test')
plt.xlabel('Number of epochs')
plt.ylabel('Accuracy')
plt.title(f'Train/Test Accuracy curve for {end_apochs} epochs')
# plt.savefig(f'/content/results/{figureName}.png')
plt.legend()
plt.show()
